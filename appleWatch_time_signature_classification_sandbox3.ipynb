# %% [markdown]
# ## $\textbf{Inferring Musical Time Signature via Apple Watch Logs of Conductor Wrist Motion}$
#
# $\textbf{Author:}\text{ Ryan Burns}$
#
# $\text{This notebook is dedicated to analysis of componentwise cross-correlation (across IMU sensors) as input feature to deep learning classifiers.}$
#
# $\textbf{Motion Class Labels:}$
#
# $\text{All class labels are defined for a right-handed user. An orchestral conductor varies their baton pattern according to 1 of 4 possible states, }$
# $\text{comprised of 3 time signature classes and a resting class (i.e., cessation of baton motion).}$
#
# $\text{0 }\leftrightarrow [1\enspace0\enspace0\enspace0]\leftrightarrow \text{REST}\Longrightarrow\text{conductor has ceased baton motion (no conducting)}$
#
# $\text{1 }\leftrightarrow [0\enspace1\enspace0\enspace0]\leftrightarrow {2/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{2}{4}}\text{ time signature}$
#
# $\text{2 }\leftrightarrow [0\enspace0\enspace1\enspace0]\leftrightarrow {3/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{3}{4}}\text{ time signature}$
#
# $\text{3 }\leftrightarrow [0\enspace0\enspace0\enspace1]\leftrightarrow {4/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{4}{4}}\text{ time signature}$
#
# $\text{For more information on musical time signatures, visit: }\textit{https://en.wikipedia.org/wiki/Time_signature}.$
#
# ![title](baton_motion.png)
#
# $\text{The baton patterns for each time signature of interest are depicted diagramatically above. We assume a tech enthusiast conductor who desires}$
# $\text{an Apple Watch app/experience for automatic discrimination between the 3 time signatures above, in addition to a catch-all }\textit{at-rest}\text{ state. We }$
# $\text{also assume that this conductor would like automatic time-signature inference to be as tempo-agnostic as possible. Be it }\textit{largo}\text{ or }\textit{prestissimo}\text{,}$
# $\text{we assume that the tempo of the musical composition of question would not fool the ideal baton pattern classifier. As such, while the amount}$
# $\text{of data collected for this analysis is still limited in its size and diversity (i.e., we can assume overfit models), efforts have been made during}$
# $\text{data collection to vary the tempo across each time signature's constituent wrist motion observations. The duration (in seconds or measures)}$
# $\text{of each time signature's wrist motion subsequence is also varied during collection. We create an aggregated dataset of independent concatenated}$
# $\text{collects for supervised learning in the code below.}$
#
# $\textbf{Note On Labeling:}$
#
# $\text{SensorLog labels are recorded in real time using the app's class label buttons for a streaming iPhone. This iPhone logs data concurrently with}$
# $\text{an Apple Watch, which also reports its own class labels. Since toggling of the Apple Watch's class labels using the SensorLog UI on the watch }$
# $\text{face would interfere with data collection of wrist motion, we use the }\textit{iPhone}\text{ to log wrist motion labels. By time-aligning the iPhone and Apple}$
# $\text{Watch streams below (i.e., using POSIX timestamps), we can readily provide wrist motion labels for the Apple Watch motion signals without}$
# $\text{interfering with their trajectory as just described. In short, real-time motion labeling is available through dual stream of Apple Watch }$
# $\text{iPhone data, where the former provides the motion observations of interest and the latter provides a mechanism for real-time motion labeling.}$
#
# $\text{We add Gaussian noise to the input signals to randomly vary input to the network, in addition to applying random dropout to a subset of}$
# $\text{the connections within the network at a fixed probability. The model is trained on a subset of data and validated on the remaining data.}$
#
# $\textbf{Motion Class Labels:}$
#
# $\text{All class labels are defined for a right-handed user. An orchestral conductor varies their baton pattern according to 1 of 4 possible states, }$
# $\text{comprised of 3 time signature classes and a resting class (i.e., cessation of baton motion).}$
#
# $\text{0 }\leftrightarrow [1\enspace0\enspace0\enspace0]\leftrightarrow \text{REST}\Longrightarrow\text{conductor has ceased baton motion (no conducting)}$
#
# $\text{1 }\leftrightarrow [0\enspace1\enspace0\enspace0]\leftrightarrow {2/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{2}{4}}\text{ time signature}$
#
# $\text{2 }\leftrightarrow [0\enspace0\enspace1\enspace0]\leftrightarrow {3/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{3}{4}}\text{ time signature}$
#
# $\text{3 }\leftrightarrow [0\enspace0\enspace0\enspace1]\leftrightarrow {4/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{4}{4}}\text{ time signature}$
#
# $\text{For more information on musical time signatures, visit: }\textit{https://en.wikipedia.org/wiki/Time_signature}.$
#
# ![title](baton_motion.png)
#
# $\text{The baton patterns for each time signature of interest are depicted diagramatically above. We assume a tech enthusiast conductor who desires}$
# $\text{an Apple Watch app/experience for automatic discrimination between the 3 time signatures above, in addition to a catch-all }\textit{at-rest}\text{ state. We }$
# $\text{also assume that this conductor would like automatic time-signature inference to be as tempo-agnostic as possible. Be it }\textit{largo}\text{ or }\textit{prestissimo}\text{,}$
# $\text{we assume that the tempo of the musical composition of question would not fool the ideal baton pattern classifier. As such, while the amount}$
# $\text{of data collected for this analysis is still limited in its size and diversity (i.e., we can assume overfit models), efforts have been made during}$
# $\text{data collection to vary the tempo across each time signature's constituent wrist motion observations. The duration (in seconds or measures)}$
# $\text{of each time signature's wrist motion subsequence is also varied during collection. We create an aggregated dataset of independent concatenated}$
# $\text{collects for supervised learning in the code below.}$
#
# $\textbf{Note On Labeling:}$
#
# $\text{SensorLog labels are recorded in real time using the app's class label buttons for a streaming iPhone. This iPhone logs data concurrently with}$
# $\text{an Apple Watch, which also reports its own class labels. Since toggling of the Apple Watch's class labels using the SensorLog UI on the watch }$
# $\text{face would interfere with data collection of wrist motion, we use the }\textit{iPhone}\text{ to log wrist motion labels. By time-aligning the iPhone and Apple}$
# $\text{Watch streams below (i.e., using POSIX timestamps), we can readily provide wrist motion labels for the Apple Watch motion signals without}$
# $\text{interfering with their trajectory as just described. In short, real-time motion labeling is available through dual stream of Apple Watch }$
# $\text{iPhone data, where the former provides the motion observations of interest and the latter provides a mechanism for real-time motion labeling.}$

# %% [markdown]
# ### $\textbf{Import Packages}$

# %%
import pandas as pd
from os import getcwd, environ;
from itertools import product as iter_prod;
from matplotlib import pyplot as plt;
from mpl_toolkits.axes_grid1 import make_axes_locatable
from numpy import array, hstack, argmax, ones, zeros, log10;
from numpy import logical_or, logical_not, expand_dims, flip;
from numpy import  abs, arange, shape, newaxis, sum, flipud;
from numpy import nan_to_num, transpose;
from scipy.signal import spectrogram;

from tensorflow.keras.models import Sequential, Model;
from tensorflow.keras.optimizers import RMSprop;
from tensorflow.keras.metrics import CategoricalAccuracy;
from tensorflow.keras.metrics import Precision, Recall, AUC;
from tensorflow.keras.layers import Dropout, LSTM, Dense, Conv2D;
from tensorflow.keras.layers import Activation, Reshape, Conv1D;
from tensorflow.keras.layers import Input, GaussianNoise, ConvLSTM2D;
from sklearn.metrics import confusion_matrix;

from SensorLogUtils import convert_iPhone_units;

environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# ### $\textbf{Class Label Definitions}$

# %%
# Ordinal motion class labels
class_table = pd.DataFrame({
    'REST': {
        'id': 'REST', 
        'description': 'no conducting / baton pattern',
        '1-hot label': [1,0,0,0],
        'ordinal label': 0
    },
    '2/4': {
        'id': '2/4', 
        'description': 'conducting pattern for a 2/4 time signature',
        '1-hot label': [0,1,0,0],
        'ordinal label': 1
    },
    '3/4': {
        'id': '3/4', 
        'description':'conducting pattern for a 3/4 time signature',
        '1-hot label': [0,0,1,0],
        'ordinal label': 2
    },
    '4/4': {
        'id': '4/4', 
        'description':'conducting pattern for a 4/4 time signature',
        '1-hot label': [0,0,0,1],
        'ordinal label': 3
    }
});

# Number of classes
C = 4;

# Print class table
class_table
# Out:
#                                         REST  \
# id                                      REST
# description    no conducting / baton pattern
# 1-hot label                     [1, 0, 0, 0]
# ordinal label                              0
#
#                                                        2/4  \
# id                                                     2/4
# description    conducting pattern for a 2/4 time signature
# 1-hot label                                   [0, 1, 0, 0]
# ordinal label                                            1
#
#                                                        3/4  \
# id                                                     3/4
# description    conducting pattern for a 3/4 time signature
# 1-hot label                                   [0, 0, 1, 0]
# ordinal label                                            2
#
#                                                        4/4
# id                                                     4/4
# description    conducting pattern for a 4/4 time signature
# 1-hot label                                   [0, 0, 0, 1]
# ordinal label                                            3

# %% [markdown]
# ### $\textbf{Specify & Load Dataset}$

# %%
################
# Specify data #
################

# Specify local data storage path
data_path = getcwd() + '/data';

# Collect file string ID
collect_IDs = [
    'time_signatures_collect1',
    'time_signatures_collect2'
];

# Build string filename corresponding to collect_ID
collect_files = [
    (data_path + '/labeled_' + collect_ID + '_appleWatch.csv')
for collect_ID in collect_IDs];

#############
# Load data #
#############

# Load and concatenate dataframes for all
# labeled collects in list collect_IDs
df = pd.concat([pd.read_csv(f, 
    error_bad_lines=False,
    warn_bad_lines=False)
    for f in collect_files
],axis=0,ignore_index=True);

# Data fields (column headers)
fields = [fd for fd in df];

# Length of dataframe
N = len(df); # (samples)

# %% [markdown]
# ### $\textbf{Select IMU Data & 1-Hot Class Labels}$

# %%
# Select input signals
x = nan_to_num(array(df[[
    'accelerometerAccelerationX(m/s^2)',
    'accelerometerAccelerationY(m/s^2)',
    'accelerometerAccelerationZ(m/s^2)',
    'motionRotationRateX(rad/s)',
    'motionRotationRateY(rad/s)',
    'motionRotationRateZ(rad/s)'
]]));

# Define 1-hot labels
y = nan_to_num(array(df[[
    
    # List all class headers in table above
    class_name for class_name in class_table
]]));

# %% [markdown]
# ### $\textbf{Specify Sliding Observation Window Parameters}$

# %%
# Number of raw sensor samples (N)
# and their dimensionality (D)
N, D = shape(x);

# Sliding obs. window length
M = 128; # (samples)

# Step size of obs. window
m = 5;  # (samples)

# Linear grid for sliding observation
# window reflecting window length & step
# size specified above, mapped to raw
# sensor samples n = M, M + m, M + 2m, ...
obs_idx = [n for n in range(M,N,m)];

# %% [markdown]
# ### $\textbf{Define Observations & Class Labels}$

# %%
# Windowed spectrogram observation sequence input to model
# X = array([
#     hstack(tuple(spectrogram(x[(n - M):n,d],
#     window='parzen',fs=100,nperseg=32,nfft=64)[2] 
#     for d in range(D))) for n in obs_idx
# ]);
from numpy import correlate
X = array([transpose([correlate(x[(n - M):n,d1],
    x[(n - M):n,d2],'full') for d1 in range(D) for d2 in range(D)]) for n in obs_idx
]);


# Overwrite N,M,D with new dimensionality
N,M,D = shape(X);

# Ground truth 1-hot window-resolution class labels
Y = array([
    [1 if c == argmax(sum(y[(n - M):n,:],0)) 
    else 0 for c in range(C)] for n in obs_idx]);

# %% [markdown]
# ### $\textbf{Training Parameters}$

# %%
# Fraction of dataset to hold 
# out for model validation
pct_validation = 0.25;

# Total number of obs.
N_obs = len(X);

# Number of training epochs
N_epoch = 250;

# Number of batches
N_batch = int(N_obs / 3);

# %% [markdown]
# ### $\textbf{Define Machine Learning Model}$

# %%
#####################################################
# Define model architecture w/ Keras functional API #
#####################################################

# Input layer - M x D observation window
input_layer = Input((M,D));

# Add Gaussian noise to M x D input
h0 = GaussianNoise(1e-4)(input_layer);
h1 = Conv1D(filters=D,kernel_size=D,
            activation='relu')(h0);
# h2 = Reshape((M*36,))(Dense(D,
#     activation='tanh')(h1));
# h3 = Dropout(0.5)(h2);
h2 = Conv1D(filters=D,kernel_size=32,
           activation='tanh')(h1);
h3 = LSTM(32,dropout=0.4,
    recurrent_dropout=0.4,
    activation='tanh')(h2);

# Output layer - C x 1 softmax class activation 
output_layer = Dense(C,activation='softmax')(h3);

# Set up Keras Model() instance
model = Model(
    inputs=input_layer,  # Model inputs
    outputs=output_layer # Model outputs
);

###########################
# Define loss & optimizer #
###########################

# Set RMSprop optimization for 
# speed-of-convergence purposes
opt = RMSprop(
    learning_rate=0.001,
    rho=0.9,
    momentum=0.001,
    epsilon=1e-07,
    name="RMSprop"
);

# Model compilation, using categorical
# cross-entropy error w/ RMSprop
model.compile(
    
    # Error/loss function
    loss='categorical_crossentropy', 
    
    # Use RMSprop
    optimizer=opt,
    
    # List metrics here
    metrics=[
        CategoricalAccuracy(),
        AUC(),
        Precision(),
        Recall()
    ]
);

# Print a summary table
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 255, 36)]         0
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 255, 36)           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 220, 36)           46692
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 189, 36)           41508
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                8832
# _________________________________________________________________
# dense (Dense)                (None, 4)                 132
# =================================================================
# Total params: 97,164
# Trainable params: 97,164
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### $\textbf{Train Machine Learning Model}$

# %%
# Model training
model.fit(
    
    # Input dataset
    x=X, # windowed observations
    y=Y, # 1-hot motion class labels
    
    # Batch size
    batch_size=N_batch,
    
    # Number of training epochs
    epochs=N_epoch,
    
    # Print progress
    verbose=1,
    
    # Set aside fraction for validation
    validation_split=pct_validation,
    
    # False for time series
    shuffle=False,
    
    # Other misc params
    sample_weight=None,
    validation_freq=1,
    max_queue_size=10,
    
    # Parallelize job across 2 workers
    workers=2,
    use_multiprocessing=True
);
# Out:
# Train on 12312 samples, validate on 4104 samples
# Epoch 1/250
# 12312/12312 [==============================] - 36s 3ms/sample - loss: 1.4112 - categorical_accuracy: 0.2897 - auc: 0.5464 - precision: 0.4237 - recall: 0.0320 - val_loss: 1.1964 - val_categorical_accuracy: 0.5699 - val_auc: 0.7653 - val_precision: 0.7517 - val_recall: 0.0266
# Epoch 2/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 1.2002 - categorical_accuracy: 0.4724 - auc: 0.7397 - precision: 0.7622 - recall: 0.0862 - val_loss: 1.0998 - val_categorical_accuracy: 0.4737 - val_auc: 0.7968 - val_precision: 0.7557 - val_recall: 0.2359
# Epoch 3/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 1.1590 - categorical_accuracy: 0.5090 - auc: 0.7629 - precision: 0.6920 - recall: 0.1741 - val_loss: 0.8985 - val_categorical_accuracy: 0.6691 - val_auc: 0.8871 - val_precision: 0.7725 - val_recall: 0.4593
# Epoch 4/250
# 12312/12312 [==============================] - 31s 3ms/sample - loss: 1.0823 - categorical_accuracy: 0.5582 - auc: 0.8020 - precision: 0.7378 - recall: 0.2413 - val_loss: 0.8938 - val_categorical_accuracy: 0.6891 - val_auc: 0.8897 - val_precision: 0.7667 - val_recall: 0.2802
# Epoch 5/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 1.0161 - categorical_accuracy: 0.5813 - auc: 0.8344 - precision: 0.7759 - recall: 0.2753 - val_loss: 0.7695 - val_categorical_accuracy: 0.7066 - val_auc: 0.9216 - val_precision: 0.8233 - val_recall: 0.5019
# Epoch 6/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.9401 - categorical_accuracy: 0.6341 - auc: 0.8600 - precision: 0.7736 - recall: 0.4096 - val_loss: 0.7561 - val_categorical_accuracy: 0.6996 - val_auc: 0.9137 - val_precision: 0.7468 - val_recall: 0.5556
# Epoch 7/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.8772 - categorical_accuracy: 0.6567 - auc: 0.8821 - precision: 0.7841 - recall: 0.4578 - val_loss: 0.7239 - val_categorical_accuracy: 0.6949 - val_auc: 0.9201 - val_precision: 0.7887 - val_recall: 0.5702
# Epoch 8/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.8390 - categorical_accuracy: 0.6809 - auc: 0.8918 - precision: 0.7892 - recall: 0.4943 - val_loss: 0.6597 - val_categorical_accuracy: 0.7446 - val_auc: 0.9370 - val_precision: 0.8018 - val_recall: 0.6594
# Epoch 9/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.7785 - categorical_accuracy: 0.7112 - auc: 0.9098 - precision: 0.8013 - recall: 0.5499 - val_loss: 0.6427 - val_categorical_accuracy: 0.7230 - val_auc: 0.9340 - val_precision: 0.8038 - val_recall: 0.5980
# Epoch 10/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.7299 - categorical_accuracy: 0.7279 - auc: 0.9195 - precision: 0.8092 - recall: 0.5932 - val_loss: 0.6116 - val_categorical_accuracy: 0.7490 - val_auc: 0.9413 - val_precision: 0.7881 - val_recall: 0.6815
# Epoch 11/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.6852 - categorical_accuracy: 0.7589 - auc: 0.9311 - precision: 0.8267 - recall: 0.6457 - val_loss: 0.5537 - val_categorical_accuracy: 0.8041 - val_auc: 0.9526 - val_precision: 0.8239 - val_recall: 0.7627
# Epoch 12/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.6629 - categorical_accuracy: 0.7717 - auc: 0.9350 - precision: 0.8283 - recall: 0.6653 - val_loss: 0.5380 - val_categorical_accuracy: 0.7958 - val_auc: 0.9513 - val_precision: 0.8147 - val_recall: 0.7714
# Epoch 13/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.6351 - categorical_accuracy: 0.7677 - auc: 0.9358 - precision: 0.8194 - recall: 0.6913 - val_loss: 0.6440 - val_categorical_accuracy: 0.7373 - val_auc: 0.9283 - val_precision: 0.7619 - val_recall: 0.7127
# Epoch 14/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.6235 - categorical_accuracy: 0.7662 - auc: 0.9353 - precision: 0.8034 - recall: 0.7068 - val_loss: 0.5249 - val_categorical_accuracy: 0.8082 - val_auc: 0.9520 - val_precision: 0.8210 - val_recall: 0.7790
# Epoch 15/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.5637 - categorical_accuracy: 0.8038 - auc: 0.9493 - precision: 0.8352 - recall: 0.7530 - val_loss: 0.4784 - val_categorical_accuracy: 0.8190 - val_auc: 0.9595 - val_precision: 0.8277 - val_recall: 0.8031
# Epoch 16/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.5248 - categorical_accuracy: 0.8207 - auc: 0.9544 - precision: 0.8466 - recall: 0.7850 - val_loss: 0.4370 - val_categorical_accuracy: 0.8411 - val_auc: 0.9664 - val_precision: 0.8566 - val_recall: 0.8294
# Epoch 17/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.5239 - categorical_accuracy: 0.8157 - auc: 0.9544 - precision: 0.8404 - recall: 0.7800 - val_loss: 0.4786 - val_categorical_accuracy: 0.8265 - val_auc: 0.9592 - val_precision: 0.8490 - val_recall: 0.8109
# Epoch 18/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.5060 - categorical_accuracy: 0.8177 - auc: 0.9577 - precision: 0.8461 - recall: 0.7812 - val_loss: 0.4547 - val_categorical_accuracy: 0.8353 - val_auc: 0.9629 - val_precision: 0.8480 - val_recall: 0.8221
# Epoch 19/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.4774 - categorical_accuracy: 0.8348 - auc: 0.9616 - precision: 0.8552 - recall: 0.8092 - val_loss: 0.4125 - val_categorical_accuracy: 0.8689 - val_auc: 0.9662 - val_precision: 0.8748 - val_recall: 0.8614
# Epoch 20/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.4417 - categorical_accuracy: 0.8535 - auc: 0.9656 - precision: 0.8710 - recall: 0.8323 - val_loss: 0.4288 - val_categorical_accuracy: 0.8531 - val_auc: 0.9668 - val_precision: 0.8595 - val_recall: 0.8465
# Epoch 21/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.4834 - categorical_accuracy: 0.8350 - auc: 0.9594 - precision: 0.8545 - recall: 0.8069 - val_loss: 0.4324 - val_categorical_accuracy: 0.8614 - val_auc: 0.9643 - val_precision: 0.8678 - val_recall: 0.8528
# Epoch 22/250
# 12312/12312 [==============================] - 2171s 176ms/sample - loss: 0.4443 - categorical_accuracy: 0.8454 - auc: 0.9650 - precision: 0.8670 - recall: 0.8262 - val_loss: 0.4415 - val_categorical_accuracy: 0.8553 - val_auc: 0.9641 - val_precision: 0.8620 - val_recall: 0.8465
# Epoch 23/250
# 12312/12312 [==============================] - 268s 22ms/sample - loss: 0.4017 - categorical_accuracy: 0.8656 - auc: 0.9703 - precision: 0.8786 - recall: 0.8508 - val_loss: 0.4277 - val_categorical_accuracy: 0.8640 - val_auc: 0.9651 - val_precision: 0.8708 - val_recall: 0.8587
# Epoch 24/250
# 12312/12312 [==============================] - 34s 3ms/sample - loss: 0.4058 - categorical_accuracy: 0.8626 - auc: 0.9700 - precision: 0.8783 - recall: 0.8456 - val_loss: 0.4111 - val_categorical_accuracy: 0.8684 - val_auc: 0.9668 - val_precision: 0.8764 - val_recall: 0.8640
# Epoch 25/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.4136 - categorical_accuracy: 0.8574 - auc: 0.9686 - precision: 0.8714 - recall: 0.8417 - val_loss: 0.4717 - val_categorical_accuracy: 0.8421 - val_auc: 0.9616 - val_precision: 0.8467 - val_recall: 0.8372
# Epoch 26/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.4056 - categorical_accuracy: 0.8617 - auc: 0.9692 - precision: 0.8725 - recall: 0.8493 - val_loss: 0.4166 - val_categorical_accuracy: 0.8748 - val_auc: 0.9656 - val_precision: 0.8790 - val_recall: 0.8723
# Epoch 27/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3781 - categorical_accuracy: 0.8773 - auc: 0.9725 - precision: 0.8896 - recall: 0.8661 - val_loss: 0.4043 - val_categorical_accuracy: 0.8860 - val_auc: 0.9655 - val_precision: 0.8894 - val_recall: 0.8799
# Epoch 28/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3620 - categorical_accuracy: 0.8855 - auc: 0.9746 - precision: 0.8957 - recall: 0.8744 - val_loss: 0.4128 - val_categorical_accuracy: 0.8821 - val_auc: 0.9647 - val_precision: 0.8867 - val_recall: 0.8774
# Epoch 29/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3669 - categorical_accuracy: 0.8791 - auc: 0.9740 - precision: 0.8896 - recall: 0.8675 - val_loss: 0.3875 - val_categorical_accuracy: 0.8850 - val_auc: 0.9699 - val_precision: 0.8909 - val_recall: 0.8811
# Epoch 30/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.3870 - categorical_accuracy: 0.8674 - auc: 0.9716 - precision: 0.8771 - recall: 0.8561 - val_loss: 0.3634 - val_categorical_accuracy: 0.8918 - val_auc: 0.9724 - val_precision: 0.8962 - val_recall: 0.8896
# Epoch 31/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3586 - categorical_accuracy: 0.8844 - auc: 0.9743 - precision: 0.8918 - recall: 0.8756 - val_loss: 0.4069 - val_categorical_accuracy: 0.8701 - val_auc: 0.9678 - val_precision: 0.8749 - val_recall: 0.8674
# Epoch 32/250
# 12312/12312 [==============================] - 36s 3ms/sample - loss: 0.3613 - categorical_accuracy: 0.8772 - auc: 0.9750 - precision: 0.8847 - recall: 0.8683 - val_loss: 0.3717 - val_categorical_accuracy: 0.8950 - val_auc: 0.9713 - val_precision: 0.8981 - val_recall: 0.8894
# Epoch 33/250
# 12312/12312 [==============================] - 34s 3ms/sample - loss: 0.3485 - categorical_accuracy: 0.8873 - auc: 0.9762 - precision: 0.8965 - recall: 0.8788 - val_loss: 0.3699 - val_categorical_accuracy: 0.8911 - val_auc: 0.9720 - val_precision: 0.8962 - val_recall: 0.8882
# Epoch 34/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.3373 - categorical_accuracy: 0.8864 - auc: 0.9773 - precision: 0.8930 - recall: 0.8795 - val_loss: 0.3766 - val_categorical_accuracy: 0.8830 - val_auc: 0.9721 - val_precision: 0.8883 - val_recall: 0.8779
# Epoch 35/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.3415 - categorical_accuracy: 0.8852 - auc: 0.9773 - precision: 0.8903 - recall: 0.8779 - val_loss: 0.3823 - val_categorical_accuracy: 0.8762 - val_auc: 0.9719 - val_precision: 0.8809 - val_recall: 0.8738
# Epoch 36/250
# 12312/12312 [==============================] - 34s 3ms/sample - loss: 0.3370 - categorical_accuracy: 0.8884 - auc: 0.9778 - precision: 0.8947 - recall: 0.8804 - val_loss: 0.3390 - val_categorical_accuracy: 0.9018 - val_auc: 0.9747 - val_precision: 0.9042 - val_recall: 0.8996
# Epoch 37/250
# 12312/12312 [==============================] - 34s 3ms/sample - loss: 0.3190 - categorical_accuracy: 0.8987 - auc: 0.9795 - precision: 0.9044 - recall: 0.8933 - val_loss: 0.3372 - val_categorical_accuracy: 0.9057 - val_auc: 0.9759 - val_precision: 0.9082 - val_recall: 0.9045
# Epoch 38/250
# 12312/12312 [==============================] - 34s 3ms/sample - loss: 0.3297 - categorical_accuracy: 0.8951 - auc: 0.9777 - precision: 0.9024 - recall: 0.8887 - val_loss: 0.3440 - val_categorical_accuracy: 0.9030 - val_auc: 0.9750 - val_precision: 0.9062 - val_recall: 0.9016
# Epoch 39/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.3152 - categorical_accuracy: 0.8957 - auc: 0.9795 - precision: 0.9016 - recall: 0.8891 - val_loss: 0.3619 - val_categorical_accuracy: 0.8879 - val_auc: 0.9731 - val_precision: 0.8897 - val_recall: 0.8845
# Epoch 40/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.3156 - categorical_accuracy: 0.8938 - auc: 0.9803 - precision: 0.8997 - recall: 0.8871 - val_loss: 0.3439 - val_categorical_accuracy: 0.8950 - val_auc: 0.9758 - val_precision: 0.8972 - val_recall: 0.8908
# Epoch 41/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.3096 - categorical_accuracy: 0.8997 - auc: 0.9801 - precision: 0.9066 - recall: 0.8937 - val_loss: 0.3734 - val_categorical_accuracy: 0.8896 - val_auc: 0.9717 - val_precision: 0.8927 - val_recall: 0.8879
# Epoch 42/250
# 12312/12312 [==============================] - 36s 3ms/sample - loss: 0.3027 - categorical_accuracy: 0.9020 - auc: 0.9813 - precision: 0.9072 - recall: 0.8960 - val_loss: 0.3631 - val_categorical_accuracy: 0.8891 - val_auc: 0.9737 - val_precision: 0.8930 - val_recall: 0.8869
# Epoch 43/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.3205 - categorical_accuracy: 0.8997 - auc: 0.9785 - precision: 0.9066 - recall: 0.8921 - val_loss: 0.3251 - val_categorical_accuracy: 0.9072 - val_auc: 0.9768 - val_precision: 0.9106 - val_recall: 0.9057
# Epoch 44/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.3026 - categorical_accuracy: 0.9011 - auc: 0.9815 - precision: 0.9071 - recall: 0.8951 - val_loss: 0.3246 - val_categorical_accuracy: 0.9159 - val_auc: 0.9756 - val_precision: 0.9191 - val_recall: 0.9130
# Epoch 45/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.2993 - categorical_accuracy: 0.9031 - auc: 0.9813 - precision: 0.9081 - recall: 0.8984 - val_loss: 0.3306 - val_categorical_accuracy: 0.9098 - val_auc: 0.9761 - val_precision: 0.9118 - val_recall: 0.9069
# Epoch 46/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.2851 - categorical_accuracy: 0.9085 - auc: 0.9832 - precision: 0.9140 - recall: 0.9045 - val_loss: 0.3458 - val_categorical_accuracy: 0.9045 - val_auc: 0.9751 - val_precision: 0.9068 - val_recall: 0.9028
# Epoch 47/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.2852 - categorical_accuracy: 0.9086 - auc: 0.9826 - precision: 0.9131 - recall: 0.9045 - val_loss: 0.3415 - val_categorical_accuracy: 0.9081 - val_auc: 0.9743 - val_precision: 0.9104 - val_recall: 0.9062
# Epoch 48/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.2881 - categorical_accuracy: 0.9076 - auc: 0.9824 - precision: 0.9135 - recall: 0.9030 - val_loss: 0.3363 - val_categorical_accuracy: 0.9057 - val_auc: 0.9759 - val_precision: 0.9077 - val_recall: 0.9038
# Epoch 49/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.2889 - categorical_accuracy: 0.9090 - auc: 0.9816 - precision: 0.9135 - recall: 0.9046 - val_loss: 0.3671 - val_categorical_accuracy: 0.8916 - val_auc: 0.9734 - val_precision: 0.8939 - val_recall: 0.8906
# Epoch 50/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.2908 - categorical_accuracy: 0.9064 - auc: 0.9822 - precision: 0.9101 - recall: 0.9019 - val_loss: 0.3277 - val_categorical_accuracy: 0.9059 - val_auc: 0.9775 - val_precision: 0.9105 - val_recall: 0.9045
# Epoch 51/250
# 12312/12312 [==============================] - 355s 29ms/sample - loss: 0.2862 - categorical_accuracy: 0.9072 - auc: 0.9823 - precision: 0.9120 - recall: 0.9019 - val_loss: 0.3470 - val_categorical_accuracy: 0.9013 - val_auc: 0.9739 - val_precision: 0.9050 - val_recall: 0.8986
# Epoch 52/250
# 12312/12312 [==============================] - 86s 7ms/sample - loss: 0.2952 - categorical_accuracy: 0.9031 - auc: 0.9822 - precision: 0.9085 - recall: 0.8951 - val_loss: 0.5340 - val_categorical_accuracy: 0.8221 - val_auc: 0.9545 - val_precision: 0.8418 - val_recall: 0.8077
# Epoch 53/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.4697 - categorical_accuracy: 0.8459 - auc: 0.9622 - precision: 0.8608 - recall: 0.8346 - val_loss: 0.3522 - val_categorical_accuracy: 0.8977 - val_auc: 0.9755 - val_precision: 0.9009 - val_recall: 0.8950
# Epoch 54/250
# 12312/12312 [==============================] - 37s 3ms/sample - loss: 0.3000 - categorical_accuracy: 0.9046 - auc: 0.9815 - precision: 0.9096 - recall: 0.8986 - val_loss: 0.3715 - val_categorical_accuracy: 0.8994 - val_auc: 0.9710 - val_precision: 0.9015 - val_recall: 0.8969
# Epoch 55/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.3057 - categorical_accuracy: 0.9033 - auc: 0.9805 - precision: 0.9096 - recall: 0.8973 - val_loss: 0.3054 - val_categorical_accuracy: 0.9172 - val_auc: 0.9790 - val_precision: 0.9197 - val_recall: 0.9152
# Epoch 56/250
# 12312/12312 [==============================] - 36s 3ms/sample - loss: 0.2818 - categorical_accuracy: 0.9098 - auc: 0.9836 - precision: 0.9166 - recall: 0.9030 - val_loss: 0.3102 - val_categorical_accuracy: 0.9174 - val_auc: 0.9787 - val_precision: 0.9200 - val_recall: 0.9159
# Epoch 57/250
# 12312/12312 [==============================] - 36s 3ms/sample - loss: 0.2701 - categorical_accuracy: 0.9156 - auc: 0.9845 - precision: 0.9202 - recall: 0.9109 - val_loss: 0.3436 - val_categorical_accuracy: 0.8994 - val_auc: 0.9774 - val_precision: 0.9012 - val_recall: 0.8981
# Epoch 58/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2722 - categorical_accuracy: 0.9126 - auc: 0.9848 - precision: 0.9180 - recall: 0.9081 - val_loss: 0.3208 - val_categorical_accuracy: 0.9169 - val_auc: 0.9769 - val_precision: 0.9201 - val_recall: 0.9147
# Epoch 59/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2574 - categorical_accuracy: 0.9172 - auc: 0.9859 - precision: 0.9219 - recall: 0.9133 - val_loss: 0.3519 - val_categorical_accuracy: 0.9062 - val_auc: 0.9737 - val_precision: 0.9102 - val_recall: 0.9035
# Epoch 60/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2610 - categorical_accuracy: 0.9158 - auc: 0.9856 - precision: 0.9196 - recall: 0.9099 - val_loss: 0.3336 - val_categorical_accuracy: 0.9118 - val_auc: 0.9755 - val_precision: 0.9161 - val_recall: 0.9096
# Epoch 61/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2531 - categorical_accuracy: 0.9183 - auc: 0.9862 - precision: 0.9214 - recall: 0.9150 - val_loss: 0.3291 - val_categorical_accuracy: 0.9094 - val_auc: 0.9768 - val_precision: 0.9128 - val_recall: 0.9084
# Epoch 62/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2520 - categorical_accuracy: 0.9190 - auc: 0.9857 - precision: 0.9231 - recall: 0.9147 - val_loss: 0.3742 - val_categorical_accuracy: 0.8918 - val_auc: 0.9737 - val_precision: 0.8927 - val_recall: 0.8896
# Epoch 63/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2755 - categorical_accuracy: 0.9024 - auc: 0.9843 - precision: 0.9053 - recall: 0.8986 - val_loss: 0.3675 - val_categorical_accuracy: 0.9003 - val_auc: 0.9720 - val_precision: 0.9022 - val_recall: 0.8989
# Epoch 64/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2598 - categorical_accuracy: 0.9162 - auc: 0.9853 - precision: 0.9194 - recall: 0.9123 - val_loss: 0.3684 - val_categorical_accuracy: 0.9040 - val_auc: 0.9702 - val_precision: 0.9070 - val_recall: 0.9033
# Epoch 65/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2876 - categorical_accuracy: 0.9066 - auc: 0.9824 - precision: 0.9134 - recall: 0.9012 - val_loss: 0.3951 - val_categorical_accuracy: 0.8901 - val_auc: 0.9711 - val_precision: 0.8928 - val_recall: 0.8889
# Epoch 66/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2720 - categorical_accuracy: 0.9140 - auc: 0.9844 - precision: 0.9185 - recall: 0.9085 - val_loss: 0.3255 - val_categorical_accuracy: 0.9135 - val_auc: 0.9766 - val_precision: 0.9166 - val_recall: 0.9106
# Epoch 67/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2547 - categorical_accuracy: 0.9186 - auc: 0.9858 - precision: 0.9232 - recall: 0.9154 - val_loss: 0.3513 - val_categorical_accuracy: 0.8979 - val_auc: 0.9758 - val_precision: 0.9034 - val_recall: 0.8960
# Epoch 68/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2526 - categorical_accuracy: 0.9189 - auc: 0.9862 - precision: 0.9241 - recall: 0.9146 - val_loss: 0.3592 - val_categorical_accuracy: 0.9030 - val_auc: 0.9724 - val_precision: 0.9075 - val_recall: 0.8984
# Epoch 69/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2624 - categorical_accuracy: 0.9146 - auc: 0.9853 - precision: 0.9198 - recall: 0.9103 - val_loss: 0.3377 - val_categorical_accuracy: 0.9103 - val_auc: 0.9743 - val_precision: 0.9136 - val_recall: 0.9074
# Epoch 70/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2387 - categorical_accuracy: 0.9245 - auc: 0.9878 - precision: 0.9294 - recall: 0.9193 - val_loss: 0.3526 - val_categorical_accuracy: 0.9113 - val_auc: 0.9727 - val_precision: 0.9126 - val_recall: 0.9084
# Epoch 71/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2605 - categorical_accuracy: 0.9158 - auc: 0.9856 - precision: 0.9204 - recall: 0.9107 - val_loss: 0.3530 - val_categorical_accuracy: 0.9101 - val_auc: 0.9727 - val_precision: 0.9127 - val_recall: 0.9091
# Epoch 72/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2530 - categorical_accuracy: 0.9202 - auc: 0.9861 - precision: 0.9242 - recall: 0.9163 - val_loss: 0.3521 - val_categorical_accuracy: 0.9089 - val_auc: 0.9738 - val_precision: 0.9107 - val_recall: 0.9072
# Epoch 73/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2357 - categorical_accuracy: 0.9258 - auc: 0.9877 - precision: 0.9297 - recall: 0.9220 - val_loss: 0.3748 - val_categorical_accuracy: 0.8994 - val_auc: 0.9732 - val_precision: 0.9012 - val_recall: 0.8977
# Epoch 74/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2636 - categorical_accuracy: 0.9122 - auc: 0.9857 - precision: 0.9159 - recall: 0.9080 - val_loss: 0.3286 - val_categorical_accuracy: 0.9111 - val_auc: 0.9767 - val_precision: 0.9138 - val_recall: 0.9096
# Epoch 75/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2327 - categorical_accuracy: 0.9258 - auc: 0.9881 - precision: 0.9307 - recall: 0.9229 - val_loss: 0.3302 - val_categorical_accuracy: 0.9069 - val_auc: 0.9774 - val_precision: 0.9090 - val_recall: 0.9055
# Epoch 76/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2339 - categorical_accuracy: 0.9245 - auc: 0.9882 - precision: 0.9290 - recall: 0.9212 - val_loss: 0.3192 - val_categorical_accuracy: 0.9150 - val_auc: 0.9771 - val_precision: 0.9168 - val_recall: 0.9125
# Epoch 77/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2466 - categorical_accuracy: 0.9210 - auc: 0.9866 - precision: 0.9256 - recall: 0.9158 - val_loss: 0.3222 - val_categorical_accuracy: 0.9064 - val_auc: 0.9786 - val_precision: 0.9094 - val_recall: 0.9050
# Epoch 78/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2416 - categorical_accuracy: 0.9253 - auc: 0.9871 - precision: 0.9280 - recall: 0.9228 - val_loss: 0.3476 - val_categorical_accuracy: 0.9062 - val_auc: 0.9745 - val_precision: 0.9081 - val_recall: 0.9050
# Epoch 79/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2584 - categorical_accuracy: 0.9141 - auc: 0.9860 - precision: 0.9174 - recall: 0.9116 - val_loss: 0.3728 - val_categorical_accuracy: 0.8996 - val_auc: 0.9709 - val_precision: 0.9014 - val_recall: 0.8981
# Epoch 80/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2495 - categorical_accuracy: 0.9219 - auc: 0.9861 - precision: 0.9257 - recall: 0.9187 - val_loss: 0.3282 - val_categorical_accuracy: 0.9157 - val_auc: 0.9757 - val_precision: 0.9172 - val_recall: 0.9147
# Epoch 81/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2270 - categorical_accuracy: 0.9270 - auc: 0.9887 - precision: 0.9309 - recall: 0.9238 - val_loss: 0.3420 - val_categorical_accuracy: 0.9057 - val_auc: 0.9768 - val_precision: 0.9081 - val_recall: 0.9033
# Epoch 82/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2325 - categorical_accuracy: 0.9269 - auc: 0.9884 - precision: 0.9306 - recall: 0.9237 - val_loss: 0.3582 - val_categorical_accuracy: 0.9028 - val_auc: 0.9745 - val_precision: 0.9044 - val_recall: 0.9011
# Epoch 83/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2279 - categorical_accuracy: 0.9295 - auc: 0.9886 - precision: 0.9328 - recall: 0.9257 - val_loss: 0.4164 - val_categorical_accuracy: 0.8808 - val_auc: 0.9719 - val_precision: 0.8838 - val_recall: 0.8801
# Epoch 84/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2571 - categorical_accuracy: 0.9162 - auc: 0.9865 - precision: 0.9199 - recall: 0.9128 - val_loss: 0.3324 - val_categorical_accuracy: 0.9123 - val_auc: 0.9767 - val_precision: 0.9158 - val_recall: 0.9118
# Epoch 85/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2302 - categorical_accuracy: 0.9270 - auc: 0.9884 - precision: 0.9309 - recall: 0.9237 - val_loss: 0.3309 - val_categorical_accuracy: 0.9167 - val_auc: 0.9753 - val_precision: 0.9184 - val_recall: 0.9157
# Epoch 86/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2258 - categorical_accuracy: 0.9302 - auc: 0.9886 - precision: 0.9332 - recall: 0.9272 - val_loss: 0.3068 - val_categorical_accuracy: 0.9223 - val_auc: 0.9773 - val_precision: 0.9235 - val_recall: 0.9213
# Epoch 87/250
# 12312/12312 [==============================] - 34s 3ms/sample - loss: 0.2250 - categorical_accuracy: 0.9277 - auc: 0.9891 - precision: 0.9305 - recall: 0.9253 - val_loss: 0.3387 - val_categorical_accuracy: 0.9125 - val_auc: 0.9753 - val_precision: 0.9144 - val_recall: 0.9111
# Epoch 88/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2561 - categorical_accuracy: 0.9209 - auc: 0.9856 - precision: 0.9239 - recall: 0.9176 - val_loss: 0.3501 - val_categorical_accuracy: 0.9089 - val_auc: 0.9738 - val_precision: 0.9119 - val_recall: 0.9055
# Epoch 89/250
# 12312/12312 [==============================] - 34s 3ms/sample - loss: 0.2487 - categorical_accuracy: 0.9222 - auc: 0.9866 - precision: 0.9256 - recall: 0.9191 - val_loss: 0.3712 - val_categorical_accuracy: 0.8940 - val_auc: 0.9735 - val_precision: 0.8969 - val_recall: 0.8928
# Epoch 90/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2558 - categorical_accuracy: 0.9147 - auc: 0.9865 - precision: 0.9192 - recall: 0.9115 - val_loss: 0.3273 - val_categorical_accuracy: 0.9128 - val_auc: 0.9762 - val_precision: 0.9164 - val_recall: 0.9113
# Epoch 91/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2262 - categorical_accuracy: 0.9297 - auc: 0.9889 - precision: 0.9335 - recall: 0.9270 - val_loss: 0.3301 - val_categorical_accuracy: 0.9145 - val_auc: 0.9754 - val_precision: 0.9173 - val_recall: 0.9137
# Epoch 92/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2337 - categorical_accuracy: 0.9243 - auc: 0.9881 - precision: 0.9281 - recall: 0.9214 - val_loss: 0.3216 - val_categorical_accuracy: 0.9196 - val_auc: 0.9766 - val_precision: 0.9218 - val_recall: 0.9186
# Epoch 93/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2099 - categorical_accuracy: 0.9342 - auc: 0.9901 - precision: 0.9369 - recall: 0.9322 - val_loss: 0.3758 - val_categorical_accuracy: 0.8952 - val_auc: 0.9747 - val_precision: 0.8972 - val_recall: 0.8935
# Epoch 94/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2568 - categorical_accuracy: 0.9177 - auc: 0.9862 - precision: 0.9217 - recall: 0.9140 - val_loss: 0.3272 - val_categorical_accuracy: 0.9135 - val_auc: 0.9773 - val_precision: 0.9161 - val_recall: 0.9125
# Epoch 95/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2242 - categorical_accuracy: 0.9291 - auc: 0.9892 - precision: 0.9323 - recall: 0.9263 - val_loss: 0.3415 - val_categorical_accuracy: 0.9113 - val_auc: 0.9744 - val_precision: 0.9144 - val_recall: 0.9108
# Epoch 96/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2209 - categorical_accuracy: 0.9328 - auc: 0.9889 - precision: 0.9355 - recall: 0.9299 - val_loss: 0.3253 - val_categorical_accuracy: 0.9128 - val_auc: 0.9744 - val_precision: 0.9160 - val_recall: 0.9113
# Epoch 97/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2196 - categorical_accuracy: 0.9314 - auc: 0.9896 - precision: 0.9346 - recall: 0.9278 - val_loss: 0.3361 - val_categorical_accuracy: 0.9089 - val_auc: 0.9729 - val_precision: 0.9113 - val_recall: 0.9064
# Epoch 98/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2223 - categorical_accuracy: 0.9297 - auc: 0.9892 - precision: 0.9326 - recall: 0.9270 - val_loss: 0.3313 - val_categorical_accuracy: 0.9089 - val_auc: 0.9760 - val_precision: 0.9117 - val_recall: 0.9062
# Epoch 99/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2259 - categorical_accuracy: 0.9275 - auc: 0.9886 - precision: 0.9307 - recall: 0.9244 - val_loss: 0.3276 - val_categorical_accuracy: 0.9140 - val_auc: 0.9757 - val_precision: 0.9172 - val_recall: 0.9118
# Epoch 100/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2224 - categorical_accuracy: 0.9300 - auc: 0.9888 - precision: 0.9329 - recall: 0.9273 - val_loss: 0.3444 - val_categorical_accuracy: 0.9128 - val_auc: 0.9746 - val_precision: 0.9169 - val_recall: 0.9115
# Epoch 101/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2169 - categorical_accuracy: 0.9309 - auc: 0.9895 - precision: 0.9345 - recall: 0.9287 - val_loss: 0.3522 - val_categorical_accuracy: 0.9072 - val_auc: 0.9743 - val_precision: 0.9097 - val_recall: 0.9059
# Epoch 102/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2461 - categorical_accuracy: 0.9198 - auc: 0.9871 - precision: 0.9233 - recall: 0.9174 - val_loss: 0.3356 - val_categorical_accuracy: 0.9074 - val_auc: 0.9776 - val_precision: 0.9115 - val_recall: 0.9057
# Epoch 103/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2301 - categorical_accuracy: 0.9285 - auc: 0.9884 - precision: 0.9316 - recall: 0.9263 - val_loss: 0.3226 - val_categorical_accuracy: 0.9140 - val_auc: 0.9772 - val_precision: 0.9163 - val_recall: 0.9125
# Epoch 104/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2186 - categorical_accuracy: 0.9340 - auc: 0.9893 - precision: 0.9368 - recall: 0.9316 - val_loss: 0.3361 - val_categorical_accuracy: 0.9101 - val_auc: 0.9768 - val_precision: 0.9127 - val_recall: 0.9091
# Epoch 105/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2147 - categorical_accuracy: 0.9352 - auc: 0.9895 - precision: 0.9374 - recall: 0.9336 - val_loss: 0.3418 - val_categorical_accuracy: 0.9145 - val_auc: 0.9751 - val_precision: 0.9181 - val_recall: 0.9123
# Epoch 106/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2061 - categorical_accuracy: 0.9363 - auc: 0.9903 - precision: 0.9406 - recall: 0.9332 - val_loss: 0.3279 - val_categorical_accuracy: 0.9108 - val_auc: 0.9767 - val_precision: 0.9141 - val_recall: 0.9096
# Epoch 107/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2130 - categorical_accuracy: 0.9361 - auc: 0.9896 - precision: 0.9391 - recall: 0.9338 - val_loss: 0.3300 - val_categorical_accuracy: 0.9159 - val_auc: 0.9779 - val_precision: 0.9194 - val_recall: 0.9140
# Epoch 108/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2134 - categorical_accuracy: 0.9329 - auc: 0.9902 - precision: 0.9366 - recall: 0.9306 - val_loss: 0.3031 - val_categorical_accuracy: 0.9228 - val_auc: 0.9800 - val_precision: 0.9249 - val_recall: 0.9211
# Epoch 109/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2358 - categorical_accuracy: 0.9278 - auc: 0.9874 - precision: 0.9301 - recall: 0.9248 - val_loss: 0.3125 - val_categorical_accuracy: 0.9218 - val_auc: 0.9787 - val_precision: 0.9227 - val_recall: 0.9193
# Epoch 110/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2156 - categorical_accuracy: 0.9362 - auc: 0.9887 - precision: 0.9385 - recall: 0.9340 - val_loss: 0.3276 - val_categorical_accuracy: 0.9120 - val_auc: 0.9780 - val_precision: 0.9146 - val_recall: 0.9103
# Epoch 111/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2144 - categorical_accuracy: 0.9328 - auc: 0.9894 - precision: 0.9377 - recall: 0.9298 - val_loss: 0.3384 - val_categorical_accuracy: 0.9055 - val_auc: 0.9766 - val_precision: 0.9084 - val_recall: 0.9035
# Epoch 112/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2231 - categorical_accuracy: 0.9292 - auc: 0.9891 - precision: 0.9329 - recall: 0.9252 - val_loss: 0.3191 - val_categorical_accuracy: 0.9169 - val_auc: 0.9782 - val_precision: 0.9200 - val_recall: 0.9157
# Epoch 113/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2270 - categorical_accuracy: 0.9265 - auc: 0.9887 - precision: 0.9309 - recall: 0.9227 - val_loss: 0.3086 - val_categorical_accuracy: 0.9193 - val_auc: 0.9788 - val_precision: 0.9223 - val_recall: 0.9167
# Epoch 114/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2033 - categorical_accuracy: 0.9332 - auc: 0.9909 - precision: 0.9366 - recall: 0.9307 - val_loss: 0.3097 - val_categorical_accuracy: 0.9142 - val_auc: 0.9803 - val_precision: 0.9177 - val_recall: 0.9125
# Epoch 115/250
# 12312/12312 [==============================] - 34s 3ms/sample - loss: 0.2065 - categorical_accuracy: 0.9364 - auc: 0.9904 - precision: 0.9397 - recall: 0.9340 - val_loss: 0.3393 - val_categorical_accuracy: 0.9133 - val_auc: 0.9782 - val_precision: 0.9154 - val_recall: 0.9120
# Epoch 116/250
# 12312/12312 [==============================] - 36s 3ms/sample - loss: 0.2000 - categorical_accuracy: 0.9384 - auc: 0.9909 - precision: 0.9417 - recall: 0.9361 - val_loss: 0.3409 - val_categorical_accuracy: 0.9111 - val_auc: 0.9767 - val_precision: 0.9138 - val_recall: 0.9091
# Epoch 117/250
# 12312/12312 [==============================] - 34s 3ms/sample - loss: 0.2083 - categorical_accuracy: 0.9362 - auc: 0.9903 - precision: 0.9387 - recall: 0.9338 - val_loss: 0.3192 - val_categorical_accuracy: 0.9133 - val_auc: 0.9799 - val_precision: 0.9164 - val_recall: 0.9113
# Epoch 118/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2085 - categorical_accuracy: 0.9353 - auc: 0.9905 - precision: 0.9380 - recall: 0.9326 - val_loss: 0.3294 - val_categorical_accuracy: 0.9223 - val_auc: 0.9758 - val_precision: 0.9231 - val_recall: 0.9208
# Epoch 119/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2111 - categorical_accuracy: 0.9339 - auc: 0.9898 - precision: 0.9366 - recall: 0.9316 - val_loss: 0.3522 - val_categorical_accuracy: 0.9067 - val_auc: 0.9753 - val_precision: 0.9081 - val_recall: 0.9052
# Epoch 120/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2010 - categorical_accuracy: 0.9371 - auc: 0.9906 - precision: 0.9398 - recall: 0.9340 - val_loss: 0.3430 - val_categorical_accuracy: 0.9103 - val_auc: 0.9731 - val_precision: 0.9124 - val_recall: 0.9086
# Epoch 121/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2157 - categorical_accuracy: 0.9305 - auc: 0.9896 - precision: 0.9340 - recall: 0.9283 - val_loss: 0.3334 - val_categorical_accuracy: 0.9125 - val_auc: 0.9756 - val_precision: 0.9145 - val_recall: 0.9094
# Epoch 122/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2015 - categorical_accuracy: 0.9349 - auc: 0.9905 - precision: 0.9373 - recall: 0.9323 - val_loss: 0.3310 - val_categorical_accuracy: 0.9115 - val_auc: 0.9777 - val_precision: 0.9146 - val_recall: 0.9103
# Epoch 123/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2089 - categorical_accuracy: 0.9326 - auc: 0.9902 - precision: 0.9349 - recall: 0.9299 - val_loss: 0.3172 - val_categorical_accuracy: 0.9232 - val_auc: 0.9760 - val_precision: 0.9249 - val_recall: 0.9215
# Epoch 124/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2072 - categorical_accuracy: 0.9327 - auc: 0.9906 - precision: 0.9356 - recall: 0.9291 - val_loss: 0.3180 - val_categorical_accuracy: 0.9223 - val_auc: 0.9767 - val_precision: 0.9237 - val_recall: 0.9203
# Epoch 125/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2008 - categorical_accuracy: 0.9357 - auc: 0.9909 - precision: 0.9387 - recall: 0.9336 - val_loss: 0.3185 - val_categorical_accuracy: 0.9237 - val_auc: 0.9776 - val_precision: 0.9265 - val_recall: 0.9215
# Epoch 126/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2040 - categorical_accuracy: 0.9358 - auc: 0.9902 - precision: 0.9382 - recall: 0.9329 - val_loss: 0.3289 - val_categorical_accuracy: 0.9162 - val_auc: 0.9764 - val_precision: 0.9175 - val_recall: 0.9154
# Epoch 127/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1967 - categorical_accuracy: 0.9405 - auc: 0.9913 - precision: 0.9423 - recall: 0.9382 - val_loss: 0.3311 - val_categorical_accuracy: 0.9115 - val_auc: 0.9760 - val_precision: 0.9141 - val_recall: 0.9096
# Epoch 128/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1940 - categorical_accuracy: 0.9398 - auc: 0.9913 - precision: 0.9429 - recall: 0.9370 - val_loss: 0.3347 - val_categorical_accuracy: 0.9196 - val_auc: 0.9750 - val_precision: 0.9217 - val_recall: 0.9179
# Epoch 129/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1897 - categorical_accuracy: 0.9415 - auc: 0.9914 - precision: 0.9443 - recall: 0.9400 - val_loss: 0.3214 - val_categorical_accuracy: 0.9154 - val_auc: 0.9783 - val_precision: 0.9171 - val_recall: 0.9137
# Epoch 130/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2047 - categorical_accuracy: 0.9345 - auc: 0.9911 - precision: 0.9372 - recall: 0.9315 - val_loss: 0.3059 - val_categorical_accuracy: 0.9267 - val_auc: 0.9776 - val_precision: 0.9272 - val_recall: 0.9252
# Epoch 131/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2036 - categorical_accuracy: 0.9372 - auc: 0.9903 - precision: 0.9408 - recall: 0.9342 - val_loss: 0.3199 - val_categorical_accuracy: 0.9223 - val_auc: 0.9777 - val_precision: 0.9240 - val_recall: 0.9208
# Epoch 132/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.1875 - categorical_accuracy: 0.9412 - auc: 0.9918 - precision: 0.9432 - recall: 0.9393 - val_loss: 0.3111 - val_categorical_accuracy: 0.9245 - val_auc: 0.9788 - val_precision: 0.9253 - val_recall: 0.9232
# Epoch 133/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2212 - categorical_accuracy: 0.9280 - auc: 0.9893 - precision: 0.9310 - recall: 0.9254 - val_loss: 0.3147 - val_categorical_accuracy: 0.9140 - val_auc: 0.9796 - val_precision: 0.9165 - val_recall: 0.9120
# Epoch 134/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1964 - categorical_accuracy: 0.9379 - auc: 0.9916 - precision: 0.9404 - recall: 0.9351 - val_loss: 0.3377 - val_categorical_accuracy: 0.9089 - val_auc: 0.9760 - val_precision: 0.9109 - val_recall: 0.9064
# Epoch 135/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1881 - categorical_accuracy: 0.9403 - auc: 0.9920 - precision: 0.9423 - recall: 0.9384 - val_loss: 0.3256 - val_categorical_accuracy: 0.9094 - val_auc: 0.9777 - val_precision: 0.9111 - val_recall: 0.9069
# Epoch 136/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1893 - categorical_accuracy: 0.9393 - auc: 0.9920 - precision: 0.9416 - recall: 0.9371 - val_loss: 0.3259 - val_categorical_accuracy: 0.9030 - val_auc: 0.9794 - val_precision: 0.9042 - val_recall: 0.9018
# Epoch 137/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2060 - categorical_accuracy: 0.9321 - auc: 0.9907 - precision: 0.9345 - recall: 0.9303 - val_loss: 0.3214 - val_categorical_accuracy: 0.9062 - val_auc: 0.9771 - val_precision: 0.9067 - val_recall: 0.9045
# Epoch 138/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1747 - categorical_accuracy: 0.9442 - auc: 0.9929 - precision: 0.9458 - recall: 0.9428 - val_loss: 0.3219 - val_categorical_accuracy: 0.9176 - val_auc: 0.9764 - val_precision: 0.9196 - val_recall: 0.9164
# Epoch 139/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1752 - categorical_accuracy: 0.9461 - auc: 0.9926 - precision: 0.9477 - recall: 0.9444 - val_loss: 0.3448 - val_categorical_accuracy: 0.9115 - val_auc: 0.9747 - val_precision: 0.9143 - val_recall: 0.9094
# Epoch 140/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1934 - categorical_accuracy: 0.9416 - auc: 0.9912 - precision: 0.9433 - recall: 0.9398 - val_loss: 0.3426 - val_categorical_accuracy: 0.9101 - val_auc: 0.9761 - val_precision: 0.9128 - val_recall: 0.9084
# Epoch 141/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1849 - categorical_accuracy: 0.9440 - auc: 0.9922 - precision: 0.9453 - recall: 0.9419 - val_loss: 0.3493 - val_categorical_accuracy: 0.9059 - val_auc: 0.9756 - val_precision: 0.9077 - val_recall: 0.9033
# Epoch 142/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1845 - categorical_accuracy: 0.9421 - auc: 0.9919 - precision: 0.9440 - recall: 0.9403 - val_loss: 0.3224 - val_categorical_accuracy: 0.9145 - val_auc: 0.9778 - val_precision: 0.9156 - val_recall: 0.9125
# Epoch 143/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1836 - categorical_accuracy: 0.9414 - auc: 0.9922 - precision: 0.9440 - recall: 0.9401 - val_loss: 0.3274 - val_categorical_accuracy: 0.9172 - val_auc: 0.9763 - val_precision: 0.9183 - val_recall: 0.9150
# Epoch 144/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.1820 - categorical_accuracy: 0.9452 - auc: 0.9918 - precision: 0.9467 - recall: 0.9427 - val_loss: 0.3452 - val_categorical_accuracy: 0.9196 - val_auc: 0.9752 - val_precision: 0.9221 - val_recall: 0.9174
# Epoch 145/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1901 - categorical_accuracy: 0.9419 - auc: 0.9913 - precision: 0.9443 - recall: 0.9400 - val_loss: 0.3334 - val_categorical_accuracy: 0.9145 - val_auc: 0.9761 - val_precision: 0.9159 - val_recall: 0.9128
# Epoch 146/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.1848 - categorical_accuracy: 0.9436 - auc: 0.9920 - precision: 0.9457 - recall: 0.9415 - val_loss: 0.3537 - val_categorical_accuracy: 0.9094 - val_auc: 0.9752 - val_precision: 0.9106 - val_recall: 0.9081
# Epoch 147/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2073 - categorical_accuracy: 0.9364 - auc: 0.9902 - precision: 0.9395 - recall: 0.9340 - val_loss: 0.3281 - val_categorical_accuracy: 0.9159 - val_auc: 0.9755 - val_precision: 0.9164 - val_recall: 0.9133
# Epoch 148/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1903 - categorical_accuracy: 0.9412 - auc: 0.9915 - precision: 0.9432 - recall: 0.9397 - val_loss: 0.3124 - val_categorical_accuracy: 0.9230 - val_auc: 0.9774 - val_precision: 0.9251 - val_recall: 0.9208
# Epoch 149/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.1899 - categorical_accuracy: 0.9407 - auc: 0.9914 - precision: 0.9424 - recall: 0.9389 - val_loss: 0.3232 - val_categorical_accuracy: 0.9174 - val_auc: 0.9774 - val_precision: 0.9197 - val_recall: 0.9159
# Epoch 150/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1758 - categorical_accuracy: 0.9460 - auc: 0.9927 - precision: 0.9481 - recall: 0.9444 - val_loss: 0.3357 - val_categorical_accuracy: 0.9184 - val_auc: 0.9757 - val_precision: 0.9207 - val_recall: 0.9167
# Epoch 151/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.1800 - categorical_accuracy: 0.9447 - auc: 0.9922 - precision: 0.9467 - recall: 0.9430 - val_loss: 0.3305 - val_categorical_accuracy: 0.9181 - val_auc: 0.9742 - val_precision: 0.9196 - val_recall: 0.9169
# Epoch 152/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1879 - categorical_accuracy: 0.9436 - auc: 0.9916 - precision: 0.9454 - recall: 0.9425 - val_loss: 0.3310 - val_categorical_accuracy: 0.9201 - val_auc: 0.9740 - val_precision: 0.9234 - val_recall: 0.9189
# Epoch 153/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1828 - categorical_accuracy: 0.9436 - auc: 0.9921 - precision: 0.9458 - recall: 0.9420 - val_loss: 0.3228 - val_categorical_accuracy: 0.9252 - val_auc: 0.9750 - val_precision: 0.9277 - val_recall: 0.9228
# Epoch 154/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1939 - categorical_accuracy: 0.9398 - auc: 0.9913 - precision: 0.9418 - recall: 0.9379 - val_loss: 0.3386 - val_categorical_accuracy: 0.9211 - val_auc: 0.9736 - val_precision: 0.9217 - val_recall: 0.9206
# Epoch 155/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2199 - categorical_accuracy: 0.9341 - auc: 0.9880 - precision: 0.9367 - recall: 0.9314 - val_loss: 0.3335 - val_categorical_accuracy: 0.9179 - val_auc: 0.9758 - val_precision: 0.9185 - val_recall: 0.9167
# Epoch 156/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1896 - categorical_accuracy: 0.9402 - auc: 0.9912 - precision: 0.9427 - recall: 0.9388 - val_loss: 0.3279 - val_categorical_accuracy: 0.9220 - val_auc: 0.9759 - val_precision: 0.9228 - val_recall: 0.9206
# Epoch 157/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1898 - categorical_accuracy: 0.9405 - auc: 0.9919 - precision: 0.9425 - recall: 0.9388 - val_loss: 0.3266 - val_categorical_accuracy: 0.9247 - val_auc: 0.9754 - val_precision: 0.9254 - val_recall: 0.9220
# Epoch 158/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1901 - categorical_accuracy: 0.9393 - auc: 0.9917 - precision: 0.9421 - recall: 0.9375 - val_loss: 0.3309 - val_categorical_accuracy: 0.9213 - val_auc: 0.9766 - val_precision: 0.9248 - val_recall: 0.9198
# Epoch 159/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1897 - categorical_accuracy: 0.9432 - auc: 0.9916 - precision: 0.9453 - recall: 0.9405 - val_loss: 0.3267 - val_categorical_accuracy: 0.9240 - val_auc: 0.9765 - val_precision: 0.9255 - val_recall: 0.9228
# Epoch 160/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1763 - categorical_accuracy: 0.9462 - auc: 0.9926 - precision: 0.9478 - recall: 0.9444 - val_loss: 0.3294 - val_categorical_accuracy: 0.9230 - val_auc: 0.9764 - val_precision: 0.9241 - val_recall: 0.9223
# Epoch 161/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.1843 - categorical_accuracy: 0.9427 - auc: 0.9924 - precision: 0.9447 - recall: 0.9405 - val_loss: 0.3403 - val_categorical_accuracy: 0.9162 - val_auc: 0.9772 - val_precision: 0.9170 - val_recall: 0.9157
# Epoch 162/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.1764 - categorical_accuracy: 0.9470 - auc: 0.9923 - precision: 0.9488 - recall: 0.9459 - val_loss: 0.3885 - val_categorical_accuracy: 0.8879 - val_auc: 0.9752 - val_precision: 0.8896 - val_recall: 0.8872
# Epoch 163/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2180 - categorical_accuracy: 0.9302 - auc: 0.9897 - precision: 0.9326 - recall: 0.9284 - val_loss: 0.3477 - val_categorical_accuracy: 0.9018 - val_auc: 0.9758 - val_precision: 0.9032 - val_recall: 0.9006
# Epoch 164/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1962 - categorical_accuracy: 0.9375 - auc: 0.9911 - precision: 0.9392 - recall: 0.9353 - val_loss: 0.3533 - val_categorical_accuracy: 0.9028 - val_auc: 0.9753 - val_precision: 0.9036 - val_recall: 0.9003
# Epoch 165/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.1915 - categorical_accuracy: 0.9401 - auc: 0.9916 - precision: 0.9422 - recall: 0.9379 - val_loss: 0.3412 - val_categorical_accuracy: 0.9135 - val_auc: 0.9744 - val_precision: 0.9154 - val_recall: 0.9120
# Epoch 166/250
# ...
# Epoch 196/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1668 - categorical_accuracy: 0.9477 - auc: 0.9932 - precision: 0.9494 - recall: 0.9462 - val_loss: 0.3140 - val_categorical_accuracy: 0.9262 - val_auc: 0.9765 - val_precision: 0.9274 - val_recall: 0.9250
# Epoch 197/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1608 - categorical_accuracy: 0.9508 - auc: 0.9940 - precision: 0.9529 - recall: 0.9491 - val_loss: 0.3080 - val_categorical_accuracy: 0.9252 - val_auc: 0.9783 - val_precision: 0.9262 - val_recall: 0.9240
# Epoch 198/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1682 - categorical_accuracy: 0.9484 - auc: 0.9934 - precision: 0.9500 - recall: 0.9474 - val_loss: 0.3135 - val_categorical_accuracy: 0.9223 - val_auc: 0.9777 - val_precision: 0.9238 - val_recall: 0.9218
# Epoch 199/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1785 - categorical_accuracy: 0.9449 - auc: 0.9927 - precision: 0.9458 - recall: 0.9433 - val_loss: 0.3108 - val_categorical_accuracy: 0.9279 - val_auc: 0.9772 - val_precision: 0.9294 - val_recall: 0.9269
# Epoch 200/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1666 - categorical_accuracy: 0.9486 - auc: 0.9934 - precision: 0.9504 - recall: 0.9470 - val_loss: 0.3823 - val_categorical_accuracy: 0.8999 - val_auc: 0.9741 - val_precision: 0.9009 - val_recall: 0.8994
# Epoch 201/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1806 - categorical_accuracy: 0.9423 - auc: 0.9923 - precision: 0.9444 - recall: 0.9402 - val_loss: 0.3588 - val_categorical_accuracy: 0.9086 - val_auc: 0.9733 - val_precision: 0.9090 - val_recall: 0.9081
# Epoch 202/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1748 - categorical_accuracy: 0.9439 - auc: 0.9924 - precision: 0.9457 - recall: 0.9425 - val_loss: 0.3487 - val_categorical_accuracy: 0.9179 - val_auc: 0.9735 - val_precision: 0.9187 - val_recall: 0.9172
# Epoch 203/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1619 - categorical_accuracy: 0.9519 - auc: 0.9931 - precision: 0.9532 - recall: 0.9503 - val_loss: 0.3432 - val_categorical_accuracy: 0.9198 - val_auc: 0.9745 - val_precision: 0.9205 - val_recall: 0.9196
# Epoch 204/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1653 - categorical_accuracy: 0.9493 - auc: 0.9935 - precision: 0.9511 - recall: 0.9482 - val_loss: 0.3585 - val_categorical_accuracy: 0.9193 - val_auc: 0.9729 - val_precision: 0.9202 - val_recall: 0.9186
# Epoch 205/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1649 - categorical_accuracy: 0.9505 - auc: 0.9929 - precision: 0.9524 - recall: 0.9494 - val_loss: 0.3452 - val_categorical_accuracy: 0.9179 - val_auc: 0.9752 - val_precision: 0.9189 - val_recall: 0.9169
# Epoch 206/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1631 - categorical_accuracy: 0.9513 - auc: 0.9933 - precision: 0.9528 - recall: 0.9504 - val_loss: 0.4038 - val_categorical_accuracy: 0.9089 - val_auc: 0.9677 - val_precision: 0.9099 - val_recall: 0.9079
# Epoch 207/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1892 - categorical_accuracy: 0.9435 - auc: 0.9913 - precision: 0.9457 - recall: 0.9412 - val_loss: 0.3147 - val_categorical_accuracy: 0.9267 - val_auc: 0.9776 - val_precision: 0.9271 - val_recall: 0.9262
# Epoch 208/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1732 - categorical_accuracy: 0.9466 - auc: 0.9928 - precision: 0.9478 - recall: 0.9449 - val_loss: 0.3481 - val_categorical_accuracy: 0.9225 - val_auc: 0.9738 - val_precision: 0.9234 - val_recall: 0.9220
# Epoch 209/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1667 - categorical_accuracy: 0.9508 - auc: 0.9928 - precision: 0.9520 - recall: 0.9498 - val_loss: 0.3820 - val_categorical_accuracy: 0.8952 - val_auc: 0.9751 - val_precision: 0.8959 - val_recall: 0.8950
# Epoch 210/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1874 - categorical_accuracy: 0.9405 - auc: 0.9917 - precision: 0.9415 - recall: 0.9394 - val_loss: 0.3361 - val_categorical_accuracy: 0.9147 - val_auc: 0.9765 - val_precision: 0.9155 - val_recall: 0.9137
# Epoch 211/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1609 - categorical_accuracy: 0.9527 - auc: 0.9932 - precision: 0.9538 - recall: 0.9514 - val_loss: 0.3402 - val_categorical_accuracy: 0.9184 - val_auc: 0.9749 - val_precision: 0.9205 - val_recall: 0.9172
# Epoch 212/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1671 - categorical_accuracy: 0.9503 - auc: 0.9931 - precision: 0.9521 - recall: 0.9487 - val_loss: 0.3858 - val_categorical_accuracy: 0.9074 - val_auc: 0.9712 - val_precision: 0.9098 - val_recall: 0.9067
# Epoch 213/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1664 - categorical_accuracy: 0.9504 - auc: 0.9933 - precision: 0.9516 - recall: 0.9492 - val_loss: 0.4167 - val_categorical_accuracy: 0.8977 - val_auc: 0.9652 - val_precision: 0.8987 - val_recall: 0.8972
# Epoch 214/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1919 - categorical_accuracy: 0.9430 - auc: 0.9908 - precision: 0.9443 - recall: 0.9416 - val_loss: 0.3291 - val_categorical_accuracy: 0.9230 - val_auc: 0.9762 - val_precision: 0.9245 - val_recall: 0.9218
# Epoch 215/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1734 - categorical_accuracy: 0.9491 - auc: 0.9922 - precision: 0.9510 - recall: 0.9474 - val_loss: 0.3342 - val_categorical_accuracy: 0.9259 - val_auc: 0.9756 - val_precision: 0.9270 - val_recall: 0.9250
# Epoch 216/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1678 - categorical_accuracy: 0.9492 - auc: 0.9930 - precision: 0.9514 - recall: 0.9478 - val_loss: 0.3359 - val_categorical_accuracy: 0.9157 - val_auc: 0.9775 - val_precision: 0.9178 - val_recall: 0.9147
# Epoch 217/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1597 - categorical_accuracy: 0.9504 - auc: 0.9936 - precision: 0.9515 - recall: 0.9493 - val_loss: 0.3834 - val_categorical_accuracy: 0.9106 - val_auc: 0.9713 - val_precision: 0.9126 - val_recall: 0.9106
# Epoch 218/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1700 - categorical_accuracy: 0.9496 - auc: 0.9926 - precision: 0.9517 - recall: 0.9481 - val_loss: 0.3967 - val_categorical_accuracy: 0.9038 - val_auc: 0.9694 - val_precision: 0.9054 - val_recall: 0.9028
# Epoch 219/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1845 - categorical_accuracy: 0.9440 - auc: 0.9914 - precision: 0.9454 - recall: 0.9429 - val_loss: 0.3798 - val_categorical_accuracy: 0.9033 - val_auc: 0.9720 - val_precision: 0.9047 - val_recall: 0.9018
# Epoch 220/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1649 - categorical_accuracy: 0.9499 - auc: 0.9935 - precision: 0.9517 - recall: 0.9485 - val_loss: 0.3491 - val_categorical_accuracy: 0.9172 - val_auc: 0.9735 - val_precision: 0.9200 - val_recall: 0.9159
# Epoch 221/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1628 - categorical_accuracy: 0.9509 - auc: 0.9937 - precision: 0.9517 - recall: 0.9492 - val_loss: 0.3962 - val_categorical_accuracy: 0.9050 - val_auc: 0.9661 - val_precision: 0.9078 - val_recall: 0.9040
# Epoch 222/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1768 - categorical_accuracy: 0.9460 - auc: 0.9927 - precision: 0.9481 - recall: 0.9431 - val_loss: 0.3830 - val_categorical_accuracy: 0.9140 - val_auc: 0.9686 - val_precision: 0.9151 - val_recall: 0.9135
# Epoch 223/250
# 12312/12312 [==============================] - 1164s 95ms/sample - loss: 0.1773 - categorical_accuracy: 0.9427 - auc: 0.9927 - precision: 0.9466 - recall: 0.9413 - val_loss: 0.4666 - val_categorical_accuracy: 0.8874 - val_auc: 0.9638 - val_precision: 0.8876 - val_recall: 0.8867
# Epoch 224/250
# 12312/12312 [==============================] - 31s 3ms/sample - loss: 0.2657 - categorical_accuracy: 0.9173 - auc: 0.9855 - precision: 0.9201 - recall: 0.9141 - val_loss: 0.3755 - val_categorical_accuracy: 0.9101 - val_auc: 0.9702 - val_precision: 0.9114 - val_recall: 0.9098
# Epoch 225/250
# 12312/12312 [==============================] - 31s 3ms/sample - loss: 0.2087 - categorical_accuracy: 0.9332 - auc: 0.9906 - precision: 0.9349 - recall: 0.9319 - val_loss: 0.3583 - val_categorical_accuracy: 0.9169 - val_auc: 0.9736 - val_precision: 0.9183 - val_recall: 0.9169
# Epoch 226/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1846 - categorical_accuracy: 0.9436 - auc: 0.9915 - precision: 0.9454 - recall: 0.9423 - val_loss: 0.3379 - val_categorical_accuracy: 0.9206 - val_auc: 0.9749 - val_precision: 0.9212 - val_recall: 0.9203
# Epoch 227/250
# 12312/12312 [==============================] - 31s 3ms/sample - loss: 0.1666 - categorical_accuracy: 0.9495 - auc: 0.9933 - precision: 0.9507 - recall: 0.9483 - val_loss: 0.3637 - val_categorical_accuracy: 0.9157 - val_auc: 0.9734 - val_precision: 0.9169 - val_recall: 0.9145
# Epoch 228/250
# 12312/12312 [==============================] - 31s 3ms/sample - loss: 0.1810 - categorical_accuracy: 0.9444 - auc: 0.9920 - precision: 0.9461 - recall: 0.9431 - val_loss: 0.3493 - val_categorical_accuracy: 0.9164 - val_auc: 0.9752 - val_precision: 0.9175 - val_recall: 0.9162
# Epoch 229/250
# 12312/12312 [==============================] - 31s 3ms/sample - loss: 0.1683 - categorical_accuracy: 0.9497 - auc: 0.9929 - precision: 0.9512 - recall: 0.9486 - val_loss: 0.3578 - val_categorical_accuracy: 0.9179 - val_auc: 0.9717 - val_precision: 0.9192 - val_recall: 0.9174
# Epoch 230/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1757 - categorical_accuracy: 0.9454 - auc: 0.9928 - precision: 0.9469 - recall: 0.9439 - val_loss: 0.3248 - val_categorical_accuracy: 0.9215 - val_auc: 0.9777 - val_precision: 0.9224 - val_recall: 0.9208
# Epoch 231/250
# 12312/12312 [==============================] - 31s 3ms/sample - loss: 0.1664 - categorical_accuracy: 0.9496 - auc: 0.9930 - precision: 0.9510 - recall: 0.9483 - val_loss: 0.3647 - val_categorical_accuracy: 0.9189 - val_auc: 0.9701 - val_precision: 0.9197 - val_recall: 0.9186
# Epoch 232/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1688 - categorical_accuracy: 0.9485 - auc: 0.9928 - precision: 0.9504 - recall: 0.9472 - val_loss: 0.3556 - val_categorical_accuracy: 0.9181 - val_auc: 0.9733 - val_precision: 0.9188 - val_recall: 0.9176
# Epoch 233/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1713 - categorical_accuracy: 0.9489 - auc: 0.9921 - precision: 0.9499 - recall: 0.9479 - val_loss: 0.4236 - val_categorical_accuracy: 0.9077 - val_auc: 0.9663 - val_precision: 0.9089 - val_recall: 0.9067
# Epoch 234/250
# 12312/12312 [==============================] - 31s 3ms/sample - loss: 0.2213 - categorical_accuracy: 0.9342 - auc: 0.9879 - precision: 0.9367 - recall: 0.9321 - val_loss: 0.3411 - val_categorical_accuracy: 0.9176 - val_auc: 0.9724 - val_precision: 0.9192 - val_recall: 0.9174
# Epoch 235/250
# 12312/12312 [==============================] - 31s 3ms/sample - loss: 0.1689 - categorical_accuracy: 0.9491 - auc: 0.9930 - precision: 0.9505 - recall: 0.9474 - val_loss: 0.3370 - val_categorical_accuracy: 0.9169 - val_auc: 0.9754 - val_precision: 0.9170 - val_recall: 0.9154
# Epoch 236/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1769 - categorical_accuracy: 0.9449 - auc: 0.9928 - precision: 0.9463 - recall: 0.9440 - val_loss: 0.3646 - val_categorical_accuracy: 0.9008 - val_auc: 0.9736 - val_precision: 0.9021 - val_recall: 0.9006
# Epoch 237/250
# 12312/12312 [==============================] - 31s 3ms/sample - loss: 0.1815 - categorical_accuracy: 0.9437 - auc: 0.9921 - precision: 0.9455 - recall: 0.9427 - val_loss: 0.3344 - val_categorical_accuracy: 0.9259 - val_auc: 0.9736 - val_precision: 0.9263 - val_recall: 0.9247
# Epoch 238/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1686 - categorical_accuracy: 0.9492 - auc: 0.9929 - precision: 0.9505 - recall: 0.9476 - val_loss: 0.3804 - val_categorical_accuracy: 0.9016 - val_auc: 0.9713 - val_precision: 0.9023 - val_recall: 0.9006
# Epoch 239/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.1917 - categorical_accuracy: 0.9416 - auc: 0.9911 - precision: 0.9438 - recall: 0.9410 - val_loss: 0.3910 - val_categorical_accuracy: 0.8962 - val_auc: 0.9706 - val_precision: 0.8969 - val_recall: 0.8947
# Epoch 240/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.2033 - categorical_accuracy: 0.9382 - auc: 0.9904 - precision: 0.9398 - recall: 0.9366 - val_loss: 0.3730 - val_categorical_accuracy: 0.8989 - val_auc: 0.9745 - val_precision: 0.9019 - val_recall: 0.8981
# Epoch 241/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1836 - categorical_accuracy: 0.9431 - auc: 0.9921 - precision: 0.9448 - recall: 0.9414 - val_loss: 0.3605 - val_categorical_accuracy: 0.9086 - val_auc: 0.9759 - val_precision: 0.9108 - val_recall: 0.9079
# Epoch 242/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1871 - categorical_accuracy: 0.9414 - auc: 0.9918 - precision: 0.9427 - recall: 0.9402 - val_loss: 0.3374 - val_categorical_accuracy: 0.9113 - val_auc: 0.9777 - val_precision: 0.9137 - val_recall: 0.9108
# Epoch 243/250
# 12312/12312 [==============================] - 35s 3ms/sample - loss: 0.1924 - categorical_accuracy: 0.9374 - auc: 0.9913 - precision: 0.9396 - recall: 0.9362 - val_loss: 0.3893 - val_categorical_accuracy: 0.9016 - val_auc: 0.9711 - val_precision: 0.9038 - val_recall: 0.8999
# Epoch 244/250
# 12312/12312 [==============================] - 31s 3ms/sample - loss: 0.1915 - categorical_accuracy: 0.9394 - auc: 0.9919 - precision: 0.9413 - recall: 0.9379 - val_loss: 0.3485 - val_categorical_accuracy: 0.9103 - val_auc: 0.9762 - val_precision: 0.9145 - val_recall: 0.9094
# Epoch 245/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1993 - categorical_accuracy: 0.9374 - auc: 0.9910 - precision: 0.9396 - recall: 0.9358 - val_loss: 0.3171 - val_categorical_accuracy: 0.9174 - val_auc: 0.9799 - val_precision: 0.9187 - val_recall: 0.9174
# Epoch 246/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1893 - categorical_accuracy: 0.9410 - auc: 0.9917 - precision: 0.9427 - recall: 0.9392 - val_loss: 0.3253 - val_categorical_accuracy: 0.9130 - val_auc: 0.9796 - val_precision: 0.9145 - val_recall: 0.9123
# Epoch 247/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1790 - categorical_accuracy: 0.9440 - auc: 0.9923 - precision: 0.9450 - recall: 0.9428 - val_loss: 0.3105 - val_categorical_accuracy: 0.9225 - val_auc: 0.9783 - val_precision: 0.9250 - val_recall: 0.9223
# Epoch 248/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1700 - categorical_accuracy: 0.9479 - auc: 0.9927 - precision: 0.9493 - recall: 0.9466 - val_loss: 0.3132 - val_categorical_accuracy: 0.9247 - val_auc: 0.9773 - val_precision: 0.9262 - val_recall: 0.9240
# Epoch 249/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1707 - categorical_accuracy: 0.9463 - auc: 0.9931 - precision: 0.9482 - recall: 0.9449 - val_loss: 0.3163 - val_categorical_accuracy: 0.9245 - val_auc: 0.9768 - val_precision: 0.9253 - val_recall: 0.9235
# Epoch 250/250
# 12312/12312 [==============================] - 31s 3ms/sample - loss: 0.1617 - categorical_accuracy: 0.9522 - auc: 0.9934 - precision: 0.9533 - recall: 0.9505 - val_loss: 0.3195 - val_categorical_accuracy: 0.9189 - val_auc: 0.9762 - val_precision: 0.9206 - val_recall: 0.9186

# %% [markdown]
# ### $\textbf{Metrics vs. Training Epoch}$

# %%
# %matplotlib notebook

# Text legend labels for training set curves
train_set_lbl = ('Training Set (' + 
    str(int(100 * (1 - pct_validation))) + '%)');
    
# Text legend labels for validation set curves
val_set_lbl = ('Training Set (' + 
    str(int(100 * (1 - pct_validation))) + '%)');

# New figure
loss_fig = plt.figure(figsize=(9.9,12));

#############
# Loss plot #
#############
ax1 = plt.subplot(5,1,1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Linear grid of training epochs
epochs = arange(0,N_epoch);

# Cross-entropy error (dB) - training set
plt.plot(epochs,10 * log10(
    model.history.history['loss']),
    '.-',c='g',alpha=0.5,
    label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,10 * log10(
    model.history.history['val_loss']),
    '.-',c='k',alpha=0.5,
    label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Cross-Entropy Error vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Error${}_{\varepsilon}$ (dB)',fontsize=14);

# Legend
plt.legend();

#################
# Accuracy plot #
#################
plt.subplot(5,1,2,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['categorical_accuracy'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_categorical_accuracy'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Categorical Accuracy vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Accuracy${}_{\varepsilon}$ ($\times100\%$)',fontsize=14);

# Legend
plt.legend();

##################
# Precision plot #
##################
plt.subplot(5,1,3,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['precision'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_precision'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]); 

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Precision${}_{\varepsilon}$',fontsize=14);

# Legend
plt.legend();

###############
# Recall plot #
###############
plt.subplot(5,1,4,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['recall'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_recall'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Recall vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Recall${}_{\varepsilon}$',fontsize=14);

# Legend
plt.legend();

############
# AUC plot #
############
plt.subplot(5,1,5,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['auc'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_auc'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Area Under ROC Curve vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'AUC${}_{\varepsilon}$',fontsize=14);

# Legend
plt.legend();

# Optimize layout
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="989.9">

# %% [markdown]
# ### $\textbf{Pass Entire Dataset (i.e., Train }\cup\textbf{ Validation) to Model}$

# %%
# C x 1 class prediction for entire dataset
Y_hat = model.predict(
    X,                        # Input data
    batch_size=N_batch,       # Batch size
);

# Cast 1-hot class labels as ordinal labels
y_hat = argmax(Y_hat,axis=1); # Predictions
y_true = argmax(Y,axis=1);    # Ground truth

# %% [markdown]
# ### $\textbf{Confusion Matrix Using Predictions Output Above}$

# %%
#########################
#    Compute Matrix:    #
#########################

# Use the sklearn confusion matrix function
confusion_mat = confusion_matrix(y_true,y_hat,
    labels=[c for c in range(C)],sample_weight=None);

#########################
#   Confusion Plotter:  # - adapated from online example
#########################

def plot_confusion_matrix(C,classes,normalize=False,
            title='Confusion matrix',cmap=plt.cm.Greens):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    
    # Let epsilon > 0 be small...
    epsilon = 1e-7;
    
    # Normalization of confusion matrix C
    if normalize:
        C = C.astype('float') / (epsilon + C.sum(axis=1)[:, newaxis]);

    # Print the matrix C
    print(C);
    
    # Image representation
    ax = plt.gca();   # <-- grab current axes
    C = flipud(C);    # <-- flip horizontally for visualization
    im = ax.imshow(C,cmap=cmap);
    
    # Colorbar
    colorbar(im);
    
    # Title
    plt.title(title,fontsize=20,weight="bold");
    
    # Tick labels
    tick_marks = arange(len(classes));
    plt.xticks(tick_marks, classes, rotation=45,fontweight="bold");
    
    # Overwrite default y-axis limits
    plt.ylim([-0.5,len(classes)-0.5]);

    # Text labels in tiles (i.e., elements)
    fmt = '.2f' if normalize else 'd'
    thresh = C.max() / 2.
    for i, j in iter_prod(range(C.shape[0]), range(C.shape[1])):
        plt.text(j, i, format(C[i, j], fmt),
                 horizontalalignment="center",weight="bold",
                 color="white" if C[i, j] > thresh else "black")

    # x-axis labels
    plt.ylabel('True label',fontsize=16,weight="bold");
    
    # y-axis labels
    plt.xlabel('Predicted label',fontsize=16,weight="bold");
    
    # Set axis layout
    plt.tight_layout();
    
#########################
#    Scale Colorbar:    # - found this online
#########################

def colorbar(mappable):
    last_axes = plt.gca()
    ax = mappable.axes
    fig = ax.figure
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    cbar = fig.colorbar(mappable, cax=cax)
    plt.sca(last_axes)
    return cbar

#########################
#    Visualization:     #
#########################

conf_fig = plt.figure(figsize=(9.9,9.9));
plot_confusion_matrix(
    confusion_mat, 
    classes=[clss for clss in class_table],
    normalize=True,
    title='Confusion Matrix',
    cmap=plt.cm.Greens);
# Out:
# <img src="data:image/png;base64,..." width="989.9">
# [[0.9826561  0.00891972 0.00272547 0.00569871]
#  [0.02105263 0.9687218  0.00330827 0.00691729]
#  [0.00986436 0.00419236 0.95191122 0.03403206]
#  [0.0156     0.0044     0.0808     0.8992    ]]
