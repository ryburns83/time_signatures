# %% [markdown]
# ## $\textbf{Inferring Musical Time Signature via Apple Watch Logs of Conductor Wrist Motion}$
#
# $\textbf{Author:}\text{ Ryan Burns}$
#
# $\text{This notebook is dedicated to analysis of componentwise cross-correlation (across IMU sensors) as input feature to deep learning classifiers.}$
#
# $\textbf{Motion Class Labels:}$
#
# $\text{All class labels are defined for a right-handed user. An orchestral conductor varies their baton pattern according to 1 of 4 possible states, }$
# $\text{comprised of 3 time signature classes and a resting class (i.e., cessation of baton motion).}$
#
# $\text{0 }\leftrightarrow [1\enspace0\enspace0\enspace0]\leftrightarrow \text{REST}\Longrightarrow\text{conductor has ceased baton motion (no conducting)}$
#
# $\text{1 }\leftrightarrow [0\enspace1\enspace0\enspace0]\leftrightarrow {2/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{2}{4}}\text{ time signature}$
#
# $\text{2 }\leftrightarrow [0\enspace0\enspace1\enspace0]\leftrightarrow {3/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{3}{4}}\text{ time signature}$
#
# $\text{3 }\leftrightarrow [0\enspace0\enspace0\enspace1]\leftrightarrow {4/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{4}{4}}\text{ time signature}$
#
# $\text{For more information on musical time signatures, visit: }\textit{https://en.wikipedia.org/wiki/Time_signature}.$
#
# ![title](baton_motion.png)
#
# $\text{The baton patterns for each time signature of interest are depicted diagramatically above. We assume a tech enthusiast conductor who desires}$
# $\text{an Apple Watch app/experience for automatic discrimination between the 3 time signatures above, in addition to a catch-all }\textit{at-rest}\text{ state. We }$
# $\text{also assume that this conductor would like automatic time-signature inference to be as tempo-agnostic as possible. Be it }\textit{largo}\text{ or }\textit{prestissimo}\text{,}$
# $\text{we assume that the tempo of the musical composition of question would not fool the ideal baton pattern classifier. As such, while the amount}$
# $\text{of data collected for this analysis is still limited in its size and diversity (i.e., we can assume overfit models), efforts have been made during}$
# $\text{data collection to vary the tempo across each time signature's constituent wrist motion observations. The duration (in seconds or measures)}$
# $\text{of each time signature's wrist motion subsequence is also varied during collection. We create an aggregated dataset of independent concatenated}$
# $\text{collects for supervised learning in the code below.}$
#
# $\textbf{Note On Labeling:}$
#
# $\text{SensorLog labels are recorded in real time using the app's class label buttons for a streaming iPhone. This iPhone logs data concurrently with}$
# $\text{an Apple Watch, which also reports its own class labels. Since toggling of the Apple Watch's class labels using the SensorLog UI on the watch }$
# $\text{face would interfere with data collection of wrist motion, we use the }\textit{iPhone}\text{ to log wrist motion labels. By time-aligning the iPhone and Apple}$
# $\text{Watch streams below (i.e., using POSIX timestamps), we can readily provide wrist motion labels for the Apple Watch motion signals without}$
# $\text{interfering with their trajectory as just described. In short, real-time motion labeling is available through dual stream of Apple Watch }$
# $\text{iPhone data, where the former provides the motion observations of interest and the latter provides a mechanism for real-time motion labeling.}$
#
# $\text{We add Gaussian noise to the input signals to randomly vary input to the network, in addition to applying random dropout to a subset of}$
# $\text{the connections within the network at a fixed probability. The model is trained on a subset of data and validated on the remaining data.}$
#
# $\textbf{Motion Class Labels:}$
#
# $\text{All class labels are defined for a right-handed user. An orchestral conductor varies their baton pattern according to 1 of 4 possible states, }$
# $\text{comprised of 3 time signature classes and a resting class (i.e., cessation of baton motion).}$
#
# $\text{0 }\leftrightarrow [1\enspace0\enspace0\enspace0]\leftrightarrow \text{REST}\Longrightarrow\text{conductor has ceased baton motion (no conducting)}$
#
# $\text{1 }\leftrightarrow [0\enspace1\enspace0\enspace0]\leftrightarrow {2/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{2}{4}}\text{ time signature}$
#
# $\text{2 }\leftrightarrow [0\enspace0\enspace1\enspace0]\leftrightarrow {3/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{3}{4}}\text{ time signature}$
#
# $\text{3 }\leftrightarrow [0\enspace0\enspace0\enspace1]\leftrightarrow {4/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{4}{4}}\text{ time signature}$
#
# $\text{For more information on musical time signatures, visit: }\textit{https://en.wikipedia.org/wiki/Time_signature}.$
#
# ![title](baton_motion.png)
#
# $\text{The baton patterns for each time signature of interest are depicted diagramatically above. We assume a tech enthusiast conductor who desires}$
# $\text{an Apple Watch app/experience for automatic discrimination between the 3 time signatures above, in addition to a catch-all }\textit{at-rest}\text{ state. We }$
# $\text{also assume that this conductor would like automatic time-signature inference to be as tempo-agnostic as possible. Be it }\textit{largo}\text{ or }\textit{prestissimo}\text{,}$
# $\text{we assume that the tempo of the musical composition of question would not fool the ideal baton pattern classifier. As such, while the amount}$
# $\text{of data collected for this analysis is still limited in its size and diversity (i.e., we can assume overfit models), efforts have been made during}$
# $\text{data collection to vary the tempo across each time signature's constituent wrist motion observations. The duration (in seconds or measures)}$
# $\text{of each time signature's wrist motion subsequence is also varied during collection. We create an aggregated dataset of independent concatenated}$
# $\text{collects for supervised learning in the code below.}$
#
# $\textbf{Note On Labeling:}$
#
# $\text{SensorLog labels are recorded in real time using the app's class label buttons for a streaming iPhone. This iPhone logs data concurrently with}$
# $\text{an Apple Watch, which also reports its own class labels. Since toggling of the Apple Watch's class labels using the SensorLog UI on the watch }$
# $\text{face would interfere with data collection of wrist motion, we use the }\textit{iPhone}\text{ to log wrist motion labels. By time-aligning the iPhone and Apple}$
# $\text{Watch streams below (i.e., using POSIX timestamps), we can readily provide wrist motion labels for the Apple Watch motion signals without}$
# $\text{interfering with their trajectory as just described. In short, real-time motion labeling is available through dual stream of Apple Watch }$
# $\text{iPhone data, where the former provides the motion observations of interest and the latter provides a mechanism for real-time motion labeling.}$

# %% [markdown]
# ### $\textbf{Import Packages}$

# %%
import pandas as pd
from os import getcwd, environ;
from itertools import product as iter_prod;
from matplotlib import pyplot as plt;
from mpl_toolkits.axes_grid1 import make_axes_locatable
from numpy import array, hstack, argmax, ones, zeros, log10;
from numpy import logical_or, logical_not, expand_dims, flip;
from numpy import  abs, arange, shape, newaxis, sum, flipud;
from numpy import nan_to_num, transpose;
from scipy.signal import spectrogram;

from tensorflow.keras.models import Sequential, Model;
from tensorflow.keras.optimizers import RMSprop;
from tensorflow.keras.metrics import CategoricalAccuracy;
from tensorflow.keras.metrics import Precision, Recall, AUC;
from tensorflow.keras.layers import Dropout, LSTM, Dense, Conv2D;
from tensorflow.keras.layers import Activation, Reshape, Conv1D;
from tensorflow.keras.layers import Input, GaussianNoise, ConvLSTM2D;
from sklearn.metrics import confusion_matrix;

from SensorLogUtils import convert_iPhone_units;

environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# ### $\textbf{Class Label Definitions}$

# %%
# Ordinal motion class labels
class_table = pd.DataFrame({
    'REST': {
        'id': 'REST', 
        'description': 'no conducting / baton pattern',
        '1-hot label': [1,0,0,0],
        'ordinal label': 0
    },
    '2/4': {
        'id': '2/4', 
        'description': 'conducting pattern for a 2/4 time signature',
        '1-hot label': [0,1,0,0],
        'ordinal label': 1
    },
    '3/4': {
        'id': '3/4', 
        'description':'conducting pattern for a 3/4 time signature',
        '1-hot label': [0,0,1,0],
        'ordinal label': 2
    },
    '4/4': {
        'id': '4/4', 
        'description':'conducting pattern for a 4/4 time signature',
        '1-hot label': [0,0,0,1],
        'ordinal label': 3
    }
});

# Number of classes
C = 4;

# Print class table
class_table
# Out:
#                                         REST  \
# id                                      REST
# description    no conducting / baton pattern
# 1-hot label                     [1, 0, 0, 0]
# ordinal label                              0
#
#                                                        2/4  \
# id                                                     2/4
# description    conducting pattern for a 2/4 time signature
# 1-hot label                                   [0, 1, 0, 0]
# ordinal label                                            1
#
#                                                        3/4  \
# id                                                     3/4
# description    conducting pattern for a 3/4 time signature
# 1-hot label                                   [0, 0, 1, 0]
# ordinal label                                            2
#
#                                                        4/4
# id                                                     4/4
# description    conducting pattern for a 4/4 time signature
# 1-hot label                                   [0, 0, 0, 1]
# ordinal label                                            3

# %% [markdown]
# ### $\textbf{Specify & Load Dataset}$

# %%
################
# Specify data #
################

# Specify local data storage path
data_path = getcwd() + '/data';

# Collect file string ID
collect_IDs = [
    'time_signatures_collect1',
    'time_signatures_collect2'
];

# Build string filename corresponding to collect_ID
collect_files = [
    (data_path + '/labeled_' + collect_ID + '_appleWatch.csv')
for collect_ID in collect_IDs];

#############
# Load data #
#############

# Load and concatenate dataframes for all
# labeled collects in list collect_IDs
df = pd.concat([pd.read_csv(f, 
    error_bad_lines=False,
    warn_bad_lines=False)
    for f in collect_files
],axis=0,ignore_index=True);

# Data fields (column headers)
fields = [fd for fd in df];

# Length of dataframe
N = len(df); # (samples)

# %% [markdown]
# ### $\textbf{Select IMU Data & 1-Hot Class Labels}$

# %%
# Select input signals
x = nan_to_num(array(df[[
    'accelerometerAccelerationX(m/s^2)',
    'accelerometerAccelerationY(m/s^2)',
    'accelerometerAccelerationZ(m/s^2)',
    'motionRotationRateX(rad/s)',
    'motionRotationRateY(rad/s)',
    'motionRotationRateZ(rad/s)'
]]));

# Define 1-hot labels
y = nan_to_num(array(df[[
    
    # List all class headers in table above
    class_name for class_name in class_table
]]));

# %% [markdown]
# ### $\textbf{Specify Sliding Observation Window Parameters}$

# %%
# Number of raw sensor samples (N)
# and their dimensionality (D)
N, D = shape(x);

# Sliding obs. window length
M = 128; # (samples)

# Step size of obs. window
m = 5;  # (samples)

# Linear grid for sliding observation
# window reflecting window length & step
# size specified above, mapped to raw
# sensor samples n = M, M + m, M + 2m, ...
obs_idx = [n for n in range(M,N,m)];

# %% [markdown]
# ### $\textbf{Define Observations & Class Labels}$

# %%
# Windowed spectrogram observation sequence input to model
# X = array([
#     hstack(tuple(spectrogram(x[(n - M):n,d],
#     window='parzen',fs=100,nperseg=32,nfft=64)[2] 
#     for d in range(D))) for n in obs_idx
# ]);
from numpy import correlate
X = array([transpose([correlate(x[(n - M):n,d1],
    x[(n - M):n,d2],'full') for d1 in range(D) for d2 in range(D)]) for n in obs_idx
]);


# Overwrite N,M,D with new dimensionality
N,M,D = shape(X);

# Ground truth 1-hot window-resolution class labels
Y = array([
    [1 if c == argmax(sum(y[(n - M):n,:],0)) 
    else 0 for c in range(C)] for n in obs_idx]);

# %% [markdown]
# ### $\textbf{Training Parameters}$

# %%
# Fraction of dataset to hold 
# out for model validation
pct_validation = 0.25;

# Total number of obs.
N_obs = len(X);

# Number of training epochs
N_epoch = 250;

# Number of batches
N_batch = int(N_obs / 3);

# %% [markdown]
# ### $\textbf{Define Machine Learning Model}$

# %%
#####################################################
# Define model architecture w/ Keras functional API #
#####################################################

# Input layer - M x D observation window
input_layer = Input((M,D));

# Add Gaussian noise to M x D input
h0 = GaussianNoise(1e-4)(input_layer);
h1 = Conv1D(filters=D,kernel_size=D,
            activation='relu')(h0);
# h2 = Reshape((M*36,))(Dense(D,
#     activation='tanh')(h1));
# h3 = Dropout(0.5)(h2);
h2 = Conv1D(filters=D,kernel_size=32,
           activation='tanh')(h1);
h3 = LSTM(32,dropout=0.4,
    recurrent_dropout=0.4,
    activation='tanh')(h2);

# Output layer - C x 1 softmax class activation 
output_layer = Dense(C,activation='softmax')(h3);

# Set up Keras Model() instance
model = Model(
    inputs=input_layer,  # Model inputs
    outputs=output_layer # Model outputs
);

###########################
# Define loss & optimizer #
###########################

# Set RMSprop optimization for 
# speed-of-convergence purposes
opt = RMSprop(
    learning_rate=0.001,
    rho=0.9,
    momentum=0.001,
    epsilon=1e-07,
    name="RMSprop"
);

# Model compilation, using categorical
# cross-entropy error w/ RMSprop
model.compile(
    
    # Error/loss function
    loss='categorical_crossentropy', 
    
    # Use RMSprop
    optimizer=opt,
    
    # List metrics here
    metrics=[
        CategoricalAccuracy(),
        AUC(),
        Precision(),
        Recall()
    ]
);

# Print a summary table
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 255, 36)]         0
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 255, 36)           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 220, 36)           46692
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 189, 36)           41508
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                8832
# _________________________________________________________________
# dense (Dense)                (None, 4)                 132
# =================================================================
# Total params: 97,164
# Trainable params: 97,164
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### $\textbf{Train Machine Learning Model}$

# %%
# Model training
model.fit(
    
    # Input dataset
    x=X, # windowed observations
    y=Y, # 1-hot motion class labels
    
    # Batch size
    batch_size=N_batch,
    
    # Number of training epochs
    epochs=N_epoch,
    
    # Print progress
    verbose=1,
    
    # Set aside fraction for validation
    validation_split=pct_validation,
    
    # False for time series
    shuffle=False,
    
    # Other misc params
    sample_weight=None,
    validation_freq=1,
    max_queue_size=10,
    
    # Parallelize job across 2 workers
    workers=2,
    use_multiprocessing=True
);
# Out:
# Train on 12312 samples, validate on 4104 samples
# Epoch 1/250
# 12312/12312 [==============================] - 36s 3ms/sample - loss: 1.4207 - categorical_accuracy: 0.2766 - auc: 0.5332 - precision: 0.3345 - recall: 0.0075 - val_loss: 1.2809 - val_categorical_accuracy: 0.3475 - val_auc: 0.6691 - val_precision: 0.5695 - val_recall: 0.1628
# Epoch 2/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 1.3038 - categorical_accuracy: 0.4080 - auc: 0.6565 - precision: 0.5527 - recall: 0.0507 - val_loss: 1.0581 - val_categorical_accuracy: 0.7061 - val_auc: 0.8557 - val_precision: 0.8706 - val_recall: 0.1213
# Epoch 3/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 1.1569 - categorical_accuracy: 0.5190 - auc: 0.7753 - precision: 0.7065 - recall: 0.0964 - val_loss: 1.0415 - val_categorical_accuracy: 0.5261 - val_auc: 0.8130 - val_precision: 0.5735 - val_recall: 0.3784
# Epoch 4/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 1.1868 - categorical_accuracy: 0.4865 - auc: 0.7406 - precision: 0.5149 - recall: 0.1571 - val_loss: 0.8685 - val_categorical_accuracy: 0.7522 - val_auc: 0.9114 - val_precision: 0.8286 - val_recall: 0.2897
# Epoch 5/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 1.0648 - categorical_accuracy: 0.5743 - auc: 0.8187 - precision: 0.7494 - recall: 0.2108 - val_loss: 0.8177 - val_categorical_accuracy: 0.7334 - val_auc: 0.9094 - val_precision: 0.8045 - val_recall: 0.5777
# Epoch 6/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.9558 - categorical_accuracy: 0.6663 - auc: 0.8734 - precision: 0.8105 - recall: 0.3200 - val_loss: 0.7306 - val_categorical_accuracy: 0.7478 - val_auc: 0.9333 - val_precision: 0.8473 - val_recall: 0.6272
# Epoch 7/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.8834 - categorical_accuracy: 0.7050 - auc: 0.8964 - precision: 0.8285 - recall: 0.4309 - val_loss: 0.6811 - val_categorical_accuracy: 0.7658 - val_auc: 0.9368 - val_precision: 0.8216 - val_recall: 0.6847
# Epoch 8/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.8117 - categorical_accuracy: 0.7302 - auc: 0.9100 - precision: 0.8331 - recall: 0.5416 - val_loss: 0.6036 - val_categorical_accuracy: 0.7997 - val_auc: 0.9503 - val_precision: 0.8445 - val_recall: 0.7478
# Epoch 9/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.7649 - categorical_accuracy: 0.7421 - auc: 0.9178 - precision: 0.8329 - recall: 0.6027 - val_loss: 0.5635 - val_categorical_accuracy: 0.8190 - val_auc: 0.9558 - val_precision: 0.8604 - val_recall: 0.7597
# Epoch 10/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.7148 - categorical_accuracy: 0.7599 - auc: 0.9277 - precision: 0.8285 - recall: 0.6406 - val_loss: 0.5460 - val_categorical_accuracy: 0.8116 - val_auc: 0.9540 - val_precision: 0.8546 - val_recall: 0.7593
# Epoch 11/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.6797 - categorical_accuracy: 0.7663 - auc: 0.9332 - precision: 0.8315 - recall: 0.6646 - val_loss: 0.5896 - val_categorical_accuracy: 0.7685 - val_auc: 0.9419 - val_precision: 0.7850 - val_recall: 0.7517
# Epoch 12/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.6541 - categorical_accuracy: 0.7690 - auc: 0.9339 - precision: 0.8272 - recall: 0.6987 - val_loss: 0.5301 - val_categorical_accuracy: 0.8163 - val_auc: 0.9538 - val_precision: 0.8468 - val_recall: 0.7788
# Epoch 13/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.5995 - categorical_accuracy: 0.7979 - auc: 0.9460 - precision: 0.8482 - recall: 0.7323 - val_loss: 0.5217 - val_categorical_accuracy: 0.8119 - val_auc: 0.9535 - val_precision: 0.8271 - val_recall: 0.7865
# Epoch 14/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.5765 - categorical_accuracy: 0.7987 - auc: 0.9482 - precision: 0.8354 - recall: 0.7401 - val_loss: 0.4808 - val_categorical_accuracy: 0.8492 - val_auc: 0.9574 - val_precision: 0.8638 - val_recall: 0.8316
# Epoch 15/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.5532 - categorical_accuracy: 0.8057 - auc: 0.9509 - precision: 0.8387 - recall: 0.7614 - val_loss: 0.4985 - val_categorical_accuracy: 0.8204 - val_auc: 0.9548 - val_precision: 0.8280 - val_recall: 0.8095
# Epoch 16/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.5136 - categorical_accuracy: 0.8259 - auc: 0.9552 - precision: 0.8526 - recall: 0.7967 - val_loss: 0.4943 - val_categorical_accuracy: 0.8209 - val_auc: 0.9566 - val_precision: 0.8317 - val_recall: 0.8082
# Epoch 17/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.4994 - categorical_accuracy: 0.8233 - auc: 0.9580 - precision: 0.8475 - recall: 0.7958 - val_loss: 0.4639 - val_categorical_accuracy: 0.8445 - val_auc: 0.9600 - val_precision: 0.8522 - val_recall: 0.8289
# Epoch 18/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.5048 - categorical_accuracy: 0.8306 - auc: 0.9555 - precision: 0.8532 - recall: 0.8004 - val_loss: 0.4362 - val_categorical_accuracy: 0.8489 - val_auc: 0.9639 - val_precision: 0.8564 - val_recall: 0.8416
# Epoch 19/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.5170 - categorical_accuracy: 0.8108 - auc: 0.9538 - precision: 0.8359 - recall: 0.7804 - val_loss: 0.4947 - val_categorical_accuracy: 0.8197 - val_auc: 0.9569 - val_precision: 0.8284 - val_recall: 0.8126
# Epoch 20/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.5093 - categorical_accuracy: 0.8232 - auc: 0.9547 - precision: 0.8476 - recall: 0.7995 - val_loss: 0.4747 - val_categorical_accuracy: 0.8319 - val_auc: 0.9597 - val_precision: 0.8409 - val_recall: 0.8214
# Epoch 21/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.4906 - categorical_accuracy: 0.8274 - auc: 0.9580 - precision: 0.8515 - recall: 0.8017 - val_loss: 0.4799 - val_categorical_accuracy: 0.8136 - val_auc: 0.9587 - val_precision: 0.8309 - val_recall: 0.8043
# Epoch 22/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.4689 - categorical_accuracy: 0.8296 - auc: 0.9617 - precision: 0.8517 - recall: 0.8061 - val_loss: 0.4115 - val_categorical_accuracy: 0.8618 - val_auc: 0.9668 - val_precision: 0.8673 - val_recall: 0.8570
# Epoch 23/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.4417 - categorical_accuracy: 0.8531 - auc: 0.9646 - precision: 0.8717 - recall: 0.8318 - val_loss: 0.4707 - val_categorical_accuracy: 0.8523 - val_auc: 0.9559 - val_precision: 0.8587 - val_recall: 0.8399
# Epoch 24/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.4873 - categorical_accuracy: 0.8302 - auc: 0.9578 - precision: 0.8535 - recall: 0.8033 - val_loss: 0.4080 - val_categorical_accuracy: 0.8618 - val_auc: 0.9659 - val_precision: 0.8665 - val_recall: 0.8575
# Epoch 25/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.4213 - categorical_accuracy: 0.8589 - auc: 0.9672 - precision: 0.8712 - recall: 0.8397 - val_loss: 0.4635 - val_categorical_accuracy: 0.8540 - val_auc: 0.9583 - val_precision: 0.8594 - val_recall: 0.8472
# Epoch 26/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.4296 - categorical_accuracy: 0.8535 - auc: 0.9654 - precision: 0.8671 - recall: 0.8376 - val_loss: 0.4350 - val_categorical_accuracy: 0.8506 - val_auc: 0.9602 - val_precision: 0.8728 - val_recall: 0.8377
# Epoch 27/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.4702 - categorical_accuracy: 0.8362 - auc: 0.9595 - precision: 0.8547 - recall: 0.8154 - val_loss: 0.4468 - val_categorical_accuracy: 0.8489 - val_auc: 0.9635 - val_precision: 0.8553 - val_recall: 0.8443
# Epoch 28/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.4007 - categorical_accuracy: 0.8601 - auc: 0.9697 - precision: 0.8740 - recall: 0.8497 - val_loss: 0.3945 - val_categorical_accuracy: 0.8784 - val_auc: 0.9687 - val_precision: 0.8834 - val_recall: 0.8748
# Epoch 29/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3897 - categorical_accuracy: 0.8691 - auc: 0.9709 - precision: 0.8800 - recall: 0.8584 - val_loss: 0.3779 - val_categorical_accuracy: 0.8823 - val_auc: 0.9706 - val_precision: 0.8881 - val_recall: 0.8799
# Epoch 30/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3675 - categorical_accuracy: 0.8780 - auc: 0.9740 - precision: 0.8880 - recall: 0.8670 - val_loss: 0.3657 - val_categorical_accuracy: 0.8862 - val_auc: 0.9724 - val_precision: 0.8923 - val_recall: 0.8801
# Epoch 31/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3548 - categorical_accuracy: 0.8802 - auc: 0.9756 - precision: 0.8890 - recall: 0.8696 - val_loss: 0.3675 - val_categorical_accuracy: 0.8886 - val_auc: 0.9706 - val_precision: 0.8923 - val_recall: 0.8845
# Epoch 32/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3636 - categorical_accuracy: 0.8760 - auc: 0.9748 - precision: 0.8861 - recall: 0.8635 - val_loss: 0.3803 - val_categorical_accuracy: 0.8862 - val_auc: 0.9693 - val_precision: 0.8904 - val_recall: 0.8828
# Epoch 33/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3407 - categorical_accuracy: 0.8866 - auc: 0.9766 - precision: 0.8953 - recall: 0.8784 - val_loss: 0.4205 - val_categorical_accuracy: 0.8740 - val_auc: 0.9661 - val_precision: 0.8783 - val_recall: 0.8704
# Epoch 34/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3443 - categorical_accuracy: 0.8880 - auc: 0.9766 - precision: 0.8957 - recall: 0.8782 - val_loss: 0.4239 - val_categorical_accuracy: 0.8653 - val_auc: 0.9654 - val_precision: 0.8695 - val_recall: 0.8606
# Epoch 35/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3445 - categorical_accuracy: 0.8845 - auc: 0.9766 - precision: 0.8934 - recall: 0.8774 - val_loss: 0.4517 - val_categorical_accuracy: 0.8492 - val_auc: 0.9647 - val_precision: 0.8525 - val_recall: 0.8462
# Epoch 36/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3439 - categorical_accuracy: 0.8851 - auc: 0.9763 - precision: 0.8914 - recall: 0.8770 - val_loss: 0.5180 - val_categorical_accuracy: 0.8409 - val_auc: 0.9507 - val_precision: 0.8467 - val_recall: 0.8358
# Epoch 37/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3497 - categorical_accuracy: 0.8824 - auc: 0.9757 - precision: 0.8910 - recall: 0.8722 - val_loss: 0.3926 - val_categorical_accuracy: 0.8787 - val_auc: 0.9701 - val_precision: 0.8834 - val_recall: 0.8748
# Epoch 38/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3410 - categorical_accuracy: 0.8892 - auc: 0.9771 - precision: 0.8974 - recall: 0.8781 - val_loss: 0.3775 - val_categorical_accuracy: 0.8843 - val_auc: 0.9710 - val_precision: 0.8871 - val_recall: 0.8811
# Epoch 39/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3411 - categorical_accuracy: 0.8879 - auc: 0.9762 - precision: 0.8955 - recall: 0.8804 - val_loss: 0.3554 - val_categorical_accuracy: 0.8952 - val_auc: 0.9731 - val_precision: 0.8993 - val_recall: 0.8925
# Epoch 40/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3676 - categorical_accuracy: 0.8772 - auc: 0.9735 - precision: 0.8838 - recall: 0.8692 - val_loss: 0.4001 - val_categorical_accuracy: 0.8777 - val_auc: 0.9703 - val_precision: 0.8817 - val_recall: 0.8752
# Epoch 41/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3155 - categorical_accuracy: 0.8990 - auc: 0.9794 - precision: 0.9065 - recall: 0.8908 - val_loss: 0.3751 - val_categorical_accuracy: 0.8901 - val_auc: 0.9706 - val_precision: 0.8934 - val_recall: 0.8884
# Epoch 42/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3138 - categorical_accuracy: 0.9008 - auc: 0.9793 - precision: 0.9081 - recall: 0.8951 - val_loss: 0.3683 - val_categorical_accuracy: 0.8896 - val_auc: 0.9722 - val_precision: 0.8931 - val_recall: 0.8874
# Epoch 43/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3023 - categorical_accuracy: 0.9033 - auc: 0.9805 - precision: 0.9099 - recall: 0.8987 - val_loss: 0.4670 - val_categorical_accuracy: 0.8579 - val_auc: 0.9639 - val_precision: 0.8598 - val_recall: 0.8550
# Epoch 44/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3576 - categorical_accuracy: 0.8788 - auc: 0.9748 - precision: 0.8868 - recall: 0.8693 - val_loss: 0.3795 - val_categorical_accuracy: 0.8889 - val_auc: 0.9711 - val_precision: 0.8928 - val_recall: 0.8865
# Epoch 45/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3097 - categorical_accuracy: 0.9007 - auc: 0.9801 - precision: 0.9056 - recall: 0.8943 - val_loss: 0.3515 - val_categorical_accuracy: 0.9018 - val_auc: 0.9731 - val_precision: 0.9034 - val_recall: 0.9001
# Epoch 46/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3075 - categorical_accuracy: 0.9036 - auc: 0.9801 - precision: 0.9091 - recall: 0.8975 - val_loss: 0.3863 - val_categorical_accuracy: 0.8933 - val_auc: 0.9690 - val_precision: 0.8968 - val_recall: 0.8896
# Epoch 47/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3106 - categorical_accuracy: 0.8998 - auc: 0.9801 - precision: 0.9073 - recall: 0.8921 - val_loss: 0.3453 - val_categorical_accuracy: 0.8994 - val_auc: 0.9737 - val_precision: 0.9027 - val_recall: 0.8977
# Epoch 48/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2871 - categorical_accuracy: 0.9079 - auc: 0.9821 - precision: 0.9121 - recall: 0.9034 - val_loss: 0.3492 - val_categorical_accuracy: 0.8977 - val_auc: 0.9731 - val_precision: 0.8993 - val_recall: 0.8962
# Epoch 49/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2997 - categorical_accuracy: 0.9064 - auc: 0.9806 - precision: 0.9107 - recall: 0.9024 - val_loss: 0.3669 - val_categorical_accuracy: 0.8884 - val_auc: 0.9739 - val_precision: 0.8934 - val_recall: 0.8840
# Epoch 50/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2880 - categorical_accuracy: 0.9085 - auc: 0.9824 - precision: 0.9132 - recall: 0.9029 - val_loss: 0.3408 - val_categorical_accuracy: 0.9067 - val_auc: 0.9748 - val_precision: 0.9107 - val_recall: 0.9050
# Epoch 51/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2819 - categorical_accuracy: 0.9109 - auc: 0.9830 - precision: 0.9161 - recall: 0.9068 - val_loss: 0.4047 - val_categorical_accuracy: 0.8855 - val_auc: 0.9669 - val_precision: 0.8879 - val_recall: 0.8838
# Epoch 52/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2849 - categorical_accuracy: 0.9090 - auc: 0.9821 - precision: 0.9127 - recall: 0.9048 - val_loss: 0.3642 - val_categorical_accuracy: 0.9020 - val_auc: 0.9704 - val_precision: 0.9047 - val_recall: 0.8996
# Epoch 53/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2830 - categorical_accuracy: 0.9068 - auc: 0.9829 - precision: 0.9114 - recall: 0.9040 - val_loss: 0.3158 - val_categorical_accuracy: 0.9098 - val_auc: 0.9774 - val_precision: 0.9115 - val_recall: 0.9086
# Epoch 54/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2775 - categorical_accuracy: 0.9118 - auc: 0.9833 - precision: 0.9148 - recall: 0.9091 - val_loss: 0.3411 - val_categorical_accuracy: 0.8950 - val_auc: 0.9765 - val_precision: 0.8977 - val_recall: 0.8916
# Epoch 55/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2894 - categorical_accuracy: 0.9042 - auc: 0.9827 - precision: 0.9093 - recall: 0.8998 - val_loss: 0.4093 - val_categorical_accuracy: 0.8964 - val_auc: 0.9611 - val_precision: 0.8977 - val_recall: 0.8942
# Epoch 56/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2772 - categorical_accuracy: 0.9125 - auc: 0.9829 - precision: 0.9156 - recall: 0.9091 - val_loss: 0.3194 - val_categorical_accuracy: 0.9135 - val_auc: 0.9767 - val_precision: 0.9163 - val_recall: 0.9120
# Epoch 57/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2591 - categorical_accuracy: 0.9202 - auc: 0.9851 - precision: 0.9232 - recall: 0.9168 - val_loss: 0.3135 - val_categorical_accuracy: 0.9106 - val_auc: 0.9775 - val_precision: 0.9124 - val_recall: 0.9106
# Epoch 58/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2602 - categorical_accuracy: 0.9205 - auc: 0.9849 - precision: 0.9250 - recall: 0.9163 - val_loss: 0.3218 - val_categorical_accuracy: 0.9062 - val_auc: 0.9771 - val_precision: 0.9075 - val_recall: 0.9057
# Epoch 59/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2594 - categorical_accuracy: 0.9198 - auc: 0.9852 - precision: 0.9238 - recall: 0.9151 - val_loss: 0.3675 - val_categorical_accuracy: 0.8874 - val_auc: 0.9713 - val_precision: 0.8899 - val_recall: 0.8865
# Epoch 60/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3348 - categorical_accuracy: 0.8924 - auc: 0.9779 - precision: 0.9016 - recall: 0.8842 - val_loss: 0.3616 - val_categorical_accuracy: 0.8950 - val_auc: 0.9721 - val_precision: 0.8975 - val_recall: 0.8942
# Epoch 61/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3011 - categorical_accuracy: 0.8960 - auc: 0.9820 - precision: 0.9015 - recall: 0.8905 - val_loss: 0.2951 - val_categorical_accuracy: 0.9191 - val_auc: 0.9794 - val_precision: 0.9210 - val_recall: 0.9179
# Epoch 62/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2787 - categorical_accuracy: 0.9089 - auc: 0.9839 - precision: 0.9149 - recall: 0.9040 - val_loss: 0.3916 - val_categorical_accuracy: 0.8908 - val_auc: 0.9698 - val_precision: 0.8928 - val_recall: 0.8886
# Epoch 63/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3007 - categorical_accuracy: 0.8997 - auc: 0.9820 - precision: 0.9042 - recall: 0.8953 - val_loss: 0.3319 - val_categorical_accuracy: 0.9030 - val_auc: 0.9767 - val_precision: 0.9064 - val_recall: 0.9011
# Epoch 64/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2812 - categorical_accuracy: 0.9065 - auc: 0.9838 - precision: 0.9115 - recall: 0.9014 - val_loss: 0.3120 - val_categorical_accuracy: 0.9081 - val_auc: 0.9780 - val_precision: 0.9116 - val_recall: 0.9067
# Epoch 65/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2768 - categorical_accuracy: 0.9108 - auc: 0.9840 - precision: 0.9158 - recall: 0.9066 - val_loss: 0.3091 - val_categorical_accuracy: 0.9111 - val_auc: 0.9783 - val_precision: 0.9128 - val_recall: 0.9077
# Epoch 66/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2505 - categorical_accuracy: 0.9167 - auc: 0.9868 - precision: 0.9215 - recall: 0.9126 - val_loss: 0.3617 - val_categorical_accuracy: 0.8821 - val_auc: 0.9742 - val_precision: 0.8839 - val_recall: 0.8813
# Epoch 67/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2635 - categorical_accuracy: 0.9143 - auc: 0.9852 - precision: 0.9176 - recall: 0.9103 - val_loss: 0.4121 - val_categorical_accuracy: 0.8784 - val_auc: 0.9675 - val_precision: 0.8802 - val_recall: 0.8772
# Epoch 68/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2588 - categorical_accuracy: 0.9167 - auc: 0.9859 - precision: 0.9213 - recall: 0.9133 - val_loss: 0.3715 - val_categorical_accuracy: 0.8767 - val_auc: 0.9754 - val_precision: 0.8773 - val_recall: 0.8745
# Epoch 69/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2661 - categorical_accuracy: 0.9111 - auc: 0.9850 - precision: 0.9140 - recall: 0.9089 - val_loss: 0.3807 - val_categorical_accuracy: 0.8835 - val_auc: 0.9735 - val_precision: 0.8854 - val_recall: 0.8828
# Epoch 70/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2561 - categorical_accuracy: 0.9154 - auc: 0.9863 - precision: 0.9199 - recall: 0.9129 - val_loss: 0.3569 - val_categorical_accuracy: 0.8950 - val_auc: 0.9740 - val_precision: 0.8973 - val_recall: 0.8938
# Epoch 71/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2586 - categorical_accuracy: 0.9152 - auc: 0.9857 - precision: 0.9184 - recall: 0.9119 - val_loss: 0.3248 - val_categorical_accuracy: 0.9074 - val_auc: 0.9784 - val_precision: 0.9100 - val_recall: 0.9062
# Epoch 72/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2634 - categorical_accuracy: 0.9167 - auc: 0.9853 - precision: 0.9205 - recall: 0.9128 - val_loss: 0.3304 - val_categorical_accuracy: 0.9025 - val_auc: 0.9775 - val_precision: 0.9061 - val_recall: 0.9006
# Epoch 73/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2801 - categorical_accuracy: 0.9090 - auc: 0.9839 - precision: 0.9141 - recall: 0.9044 - val_loss: 0.3524 - val_categorical_accuracy: 0.8996 - val_auc: 0.9754 - val_precision: 0.9025 - val_recall: 0.8981
# Epoch 74/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2462 - categorical_accuracy: 0.9183 - auc: 0.9875 - precision: 0.9235 - recall: 0.9135 - val_loss: 0.4193 - val_categorical_accuracy: 0.8689 - val_auc: 0.9723 - val_precision: 0.8717 - val_recall: 0.8674
# Epoch 75/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2569 - categorical_accuracy: 0.9163 - auc: 0.9863 - precision: 0.9206 - recall: 0.9128 - val_loss: 0.4730 - val_categorical_accuracy: 0.8821 - val_auc: 0.9542 - val_precision: 0.8848 - val_recall: 0.8811
# Epoch 76/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2652 - categorical_accuracy: 0.9172 - auc: 0.9845 - precision: 0.9210 - recall: 0.9131 - val_loss: 0.3670 - val_categorical_accuracy: 0.8930 - val_auc: 0.9734 - val_precision: 0.8960 - val_recall: 0.8901
# Epoch 77/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2502 - categorical_accuracy: 0.9193 - auc: 0.9863 - precision: 0.9238 - recall: 0.9156 - val_loss: 0.3518 - val_categorical_accuracy: 0.8925 - val_auc: 0.9750 - val_precision: 0.8953 - val_recall: 0.8913
# Epoch 78/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2352 - categorical_accuracy: 0.9249 - auc: 0.9883 - precision: 0.9285 - recall: 0.9211 - val_loss: 0.3232 - val_categorical_accuracy: 0.9052 - val_auc: 0.9789 - val_precision: 0.9086 - val_recall: 0.9033
# Epoch 79/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2430 - categorical_accuracy: 0.9233 - auc: 0.9875 - precision: 0.9281 - recall: 0.9198 - val_loss: 0.3133 - val_categorical_accuracy: 0.9137 - val_auc: 0.9780 - val_precision: 0.9161 - val_recall: 0.9120
# Epoch 80/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2342 - categorical_accuracy: 0.9245 - auc: 0.9883 - precision: 0.9282 - recall: 0.9221 - val_loss: 0.3269 - val_categorical_accuracy: 0.9025 - val_auc: 0.9772 - val_precision: 0.9062 - val_recall: 0.9016
# Epoch 81/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2433 - categorical_accuracy: 0.9237 - auc: 0.9869 - precision: 0.9283 - recall: 0.9191 - val_loss: 0.3242 - val_categorical_accuracy: 0.9001 - val_auc: 0.9792 - val_precision: 0.9025 - val_recall: 0.8996
# Epoch 82/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2361 - categorical_accuracy: 0.9276 - auc: 0.9878 - precision: 0.9306 - recall: 0.9243 - val_loss: 0.3142 - val_categorical_accuracy: 0.9154 - val_auc: 0.9778 - val_precision: 0.9187 - val_recall: 0.9113
# Epoch 83/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2275 - categorical_accuracy: 0.9284 - auc: 0.9887 - precision: 0.9323 - recall: 0.9254 - val_loss: 0.3070 - val_categorical_accuracy: 0.9186 - val_auc: 0.9788 - val_precision: 0.9204 - val_recall: 0.9179
# Epoch 84/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2192 - categorical_accuracy: 0.9340 - auc: 0.9886 - precision: 0.9375 - recall: 0.9324 - val_loss: 0.3539 - val_categorical_accuracy: 0.9120 - val_auc: 0.9702 - val_precision: 0.9131 - val_recall: 0.9113
# Epoch 85/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2432 - categorical_accuracy: 0.9212 - auc: 0.9867 - precision: 0.9250 - recall: 0.9185 - val_loss: 0.3456 - val_categorical_accuracy: 0.9008 - val_auc: 0.9765 - val_precision: 0.9029 - val_recall: 0.8999
# Epoch 86/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2381 - categorical_accuracy: 0.9246 - auc: 0.9875 - precision: 0.9281 - recall: 0.9219 - val_loss: 0.3100 - val_categorical_accuracy: 0.9167 - val_auc: 0.9791 - val_precision: 0.9189 - val_recall: 0.9162
# Epoch 87/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2349 - categorical_accuracy: 0.9265 - auc: 0.9878 - precision: 0.9312 - recall: 0.9235 - val_loss: 0.3261 - val_categorical_accuracy: 0.9120 - val_auc: 0.9754 - val_precision: 0.9142 - val_recall: 0.9111
# Epoch 88/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2244 - categorical_accuracy: 0.9302 - auc: 0.9885 - precision: 0.9341 - recall: 0.9264 - val_loss: 0.3503 - val_categorical_accuracy: 0.9011 - val_auc: 0.9766 - val_precision: 0.9029 - val_recall: 0.8999
# Epoch 89/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2471 - categorical_accuracy: 0.9202 - auc: 0.9873 - precision: 0.9247 - recall: 0.9176 - val_loss: 0.3120 - val_categorical_accuracy: 0.9145 - val_auc: 0.9778 - val_precision: 0.9166 - val_recall: 0.9135
# Epoch 90/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2446 - categorical_accuracy: 0.9225 - auc: 0.9870 - precision: 0.9277 - recall: 0.9189 - val_loss: 0.3765 - val_categorical_accuracy: 0.8886 - val_auc: 0.9753 - val_precision: 0.8906 - val_recall: 0.8867
# Epoch 91/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2534 - categorical_accuracy: 0.9197 - auc: 0.9866 - precision: 0.9254 - recall: 0.9142 - val_loss: 0.3514 - val_categorical_accuracy: 0.8952 - val_auc: 0.9764 - val_precision: 0.8973 - val_recall: 0.8942
# Epoch 92/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2514 - categorical_accuracy: 0.9189 - auc: 0.9869 - precision: 0.9250 - recall: 0.9141 - val_loss: 0.3391 - val_categorical_accuracy: 0.9042 - val_auc: 0.9781 - val_precision: 0.9050 - val_recall: 0.9030
# Epoch 93/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2532 - categorical_accuracy: 0.9218 - auc: 0.9860 - precision: 0.9251 - recall: 0.9188 - val_loss: 0.3321 - val_categorical_accuracy: 0.9103 - val_auc: 0.9754 - val_precision: 0.9112 - val_recall: 0.9096
# Epoch 94/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2359 - categorical_accuracy: 0.9276 - auc: 0.9876 - precision: 0.9307 - recall: 0.9245 - val_loss: 0.3192 - val_categorical_accuracy: 0.9152 - val_auc: 0.9770 - val_precision: 0.9174 - val_recall: 0.9142
# Epoch 95/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2316 - categorical_accuracy: 0.9270 - auc: 0.9881 - precision: 0.9314 - recall: 0.9237 - val_loss: 0.3988 - val_categorical_accuracy: 0.8884 - val_auc: 0.9734 - val_precision: 0.8923 - val_recall: 0.8867
# Epoch 96/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2498 - categorical_accuracy: 0.9168 - auc: 0.9873 - precision: 0.9200 - recall: 0.9138 - val_loss: 0.3375 - val_categorical_accuracy: 0.9081 - val_auc: 0.9767 - val_precision: 0.9092 - val_recall: 0.9072
# Epoch 97/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2257 - categorical_accuracy: 0.9277 - auc: 0.9887 - precision: 0.9321 - recall: 0.9238 - val_loss: 0.3456 - val_categorical_accuracy: 0.8960 - val_auc: 0.9765 - val_precision: 0.8981 - val_recall: 0.8935
# Epoch 98/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2371 - categorical_accuracy: 0.9219 - auc: 0.9882 - precision: 0.9269 - recall: 0.9172 - val_loss: 0.3350 - val_categorical_accuracy: 0.9111 - val_auc: 0.9757 - val_precision: 0.9125 - val_recall: 0.9098
# Epoch 99/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2309 - categorical_accuracy: 0.9268 - auc: 0.9883 - precision: 0.9303 - recall: 0.9236 - val_loss: 0.3615 - val_categorical_accuracy: 0.8994 - val_auc: 0.9748 - val_precision: 0.9002 - val_recall: 0.8989
# Epoch 100/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2399 - categorical_accuracy: 0.9221 - auc: 0.9880 - precision: 0.9261 - recall: 0.9176 - val_loss: 0.3560 - val_categorical_accuracy: 0.9011 - val_auc: 0.9753 - val_precision: 0.9050 - val_recall: 0.9006
# Epoch 101/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2324 - categorical_accuracy: 0.9226 - auc: 0.9890 - precision: 0.9271 - recall: 0.9187 - val_loss: 0.3044 - val_categorical_accuracy: 0.9215 - val_auc: 0.9798 - val_precision: 0.9234 - val_recall: 0.9196
# Epoch 102/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2251 - categorical_accuracy: 0.9288 - auc: 0.9887 - precision: 0.9325 - recall: 0.9241 - val_loss: 0.3709 - val_categorical_accuracy: 0.9077 - val_auc: 0.9720 - val_precision: 0.9111 - val_recall: 0.9069
# Epoch 103/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2438 - categorical_accuracy: 0.9219 - auc: 0.9868 - precision: 0.9252 - recall: 0.9181 - val_loss: 0.3354 - val_categorical_accuracy: 0.9101 - val_auc: 0.9759 - val_precision: 0.9120 - val_recall: 0.9089
# Epoch 104/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2209 - categorical_accuracy: 0.9298 - auc: 0.9886 - precision: 0.9335 - recall: 0.9262 - val_loss: 0.3685 - val_categorical_accuracy: 0.8904 - val_auc: 0.9735 - val_precision: 0.8940 - val_recall: 0.8894
# Epoch 105/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2180 - categorical_accuracy: 0.9334 - auc: 0.9885 - precision: 0.9352 - recall: 0.9302 - val_loss: 0.3809 - val_categorical_accuracy: 0.8925 - val_auc: 0.9727 - val_precision: 0.8948 - val_recall: 0.8916
# Epoch 106/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2235 - categorical_accuracy: 0.9268 - auc: 0.9888 - precision: 0.9297 - recall: 0.9254 - val_loss: 0.3564 - val_categorical_accuracy: 0.9033 - val_auc: 0.9742 - val_precision: 0.9048 - val_recall: 0.9028
# Epoch 107/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2207 - categorical_accuracy: 0.9311 - auc: 0.9885 - precision: 0.9337 - recall: 0.9285 - val_loss: 0.3483 - val_categorical_accuracy: 0.9091 - val_auc: 0.9744 - val_precision: 0.9110 - val_recall: 0.9084
# Epoch 108/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2111 - categorical_accuracy: 0.9384 - auc: 0.9885 - precision: 0.9405 - recall: 0.9358 - val_loss: 0.3403 - val_categorical_accuracy: 0.9042 - val_auc: 0.9769 - val_precision: 0.9059 - val_recall: 0.9030
# Epoch 109/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2046 - categorical_accuracy: 0.9364 - auc: 0.9897 - precision: 0.9387 - recall: 0.9342 - val_loss: 0.3267 - val_categorical_accuracy: 0.9167 - val_auc: 0.9771 - val_precision: 0.9190 - val_recall: 0.9152
# Epoch 110/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2053 - categorical_accuracy: 0.9379 - auc: 0.9895 - precision: 0.9413 - recall: 0.9356 - val_loss: 0.3088 - val_categorical_accuracy: 0.9235 - val_auc: 0.9787 - val_precision: 0.9255 - val_recall: 0.9232
# Epoch 111/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2072 - categorical_accuracy: 0.9349 - auc: 0.9899 - precision: 0.9382 - recall: 0.9322 - val_loss: 0.3228 - val_categorical_accuracy: 0.9154 - val_auc: 0.9774 - val_precision: 0.9172 - val_recall: 0.9150
# Epoch 112/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2092 - categorical_accuracy: 0.9362 - auc: 0.9895 - precision: 0.9385 - recall: 0.9331 - val_loss: 0.3353 - val_categorical_accuracy: 0.9118 - val_auc: 0.9764 - val_precision: 0.9137 - val_recall: 0.9103
# Epoch 113/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2941 - categorical_accuracy: 0.9074 - auc: 0.9812 - precision: 0.9114 - recall: 0.9040 - val_loss: 0.3702 - val_categorical_accuracy: 0.8960 - val_auc: 0.9752 - val_precision: 0.8980 - val_recall: 0.8950
# Epoch 114/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2559 - categorical_accuracy: 0.9166 - auc: 0.9865 - precision: 0.9190 - recall: 0.9136 - val_loss: 0.3679 - val_categorical_accuracy: 0.8916 - val_auc: 0.9751 - val_precision: 0.8944 - val_recall: 0.8894
# Epoch 115/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2361 - categorical_accuracy: 0.9245 - auc: 0.9882 - precision: 0.9271 - recall: 0.9223 - val_loss: 0.3366 - val_categorical_accuracy: 0.9077 - val_auc: 0.9771 - val_precision: 0.9096 - val_recall: 0.9067
# Epoch 116/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2295 - categorical_accuracy: 0.9267 - auc: 0.9885 - precision: 0.9296 - recall: 0.9238 - val_loss: 0.3690 - val_categorical_accuracy: 0.8972 - val_auc: 0.9767 - val_precision: 0.8991 - val_recall: 0.8950
# Epoch 117/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2454 - categorical_accuracy: 0.9219 - auc: 0.9872 - precision: 0.9249 - recall: 0.9185 - val_loss: 0.3010 - val_categorical_accuracy: 0.9198 - val_auc: 0.9791 - val_precision: 0.9207 - val_recall: 0.9191
# Epoch 118/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2282 - categorical_accuracy: 0.9271 - auc: 0.9885 - precision: 0.9302 - recall: 0.9244 - val_loss: 0.3398 - val_categorical_accuracy: 0.9047 - val_auc: 0.9763 - val_precision: 0.9057 - val_recall: 0.9033
# Epoch 119/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2324 - categorical_accuracy: 0.9254 - auc: 0.9879 - precision: 0.9276 - recall: 0.9227 - val_loss: 0.3275 - val_categorical_accuracy: 0.9128 - val_auc: 0.9759 - val_precision: 0.9142 - val_recall: 0.9118
# Epoch 120/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2194 - categorical_accuracy: 0.9326 - auc: 0.9886 - precision: 0.9351 - recall: 0.9304 - val_loss: 0.3208 - val_categorical_accuracy: 0.9111 - val_auc: 0.9787 - val_precision: 0.9119 - val_recall: 0.9106
# Epoch 121/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2192 - categorical_accuracy: 0.9316 - auc: 0.9892 - precision: 0.9342 - recall: 0.9295 - val_loss: 0.3471 - val_categorical_accuracy: 0.9001 - val_auc: 0.9768 - val_precision: 0.9015 - val_recall: 0.8991
# Epoch 122/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2284 - categorical_accuracy: 0.9284 - auc: 0.9886 - precision: 0.9307 - recall: 0.9258 - val_loss: 0.3237 - val_categorical_accuracy: 0.9118 - val_auc: 0.9756 - val_precision: 0.9124 - val_recall: 0.9113
# Epoch 123/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2204 - categorical_accuracy: 0.9328 - auc: 0.9887 - precision: 0.9354 - recall: 0.9306 - val_loss: 0.3133 - val_categorical_accuracy: 0.9137 - val_auc: 0.9762 - val_precision: 0.9154 - val_recall: 0.9128
# Epoch 124/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2227 - categorical_accuracy: 0.9297 - auc: 0.9889 - precision: 0.9315 - recall: 0.9272 - val_loss: 0.3041 - val_categorical_accuracy: 0.9211 - val_auc: 0.9778 - val_precision: 0.9212 - val_recall: 0.9198
# Epoch 125/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2068 - categorical_accuracy: 0.9375 - auc: 0.9896 - precision: 0.9399 - recall: 0.9357 - val_loss: 0.3442 - val_categorical_accuracy: 0.8996 - val_auc: 0.9768 - val_precision: 0.9012 - val_recall: 0.8984
# Epoch 126/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2082 - categorical_accuracy: 0.9364 - auc: 0.9898 - precision: 0.9388 - recall: 0.9347 - val_loss: 0.3260 - val_categorical_accuracy: 0.9018 - val_auc: 0.9778 - val_precision: 0.9055 - val_recall: 0.9011
# Epoch 127/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2038 - categorical_accuracy: 0.9361 - auc: 0.9904 - precision: 0.9390 - recall: 0.9329 - val_loss: 0.3519 - val_categorical_accuracy: 0.9011 - val_auc: 0.9740 - val_precision: 0.9028 - val_recall: 0.8981
# Epoch 128/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2095 - categorical_accuracy: 0.9319 - auc: 0.9902 - precision: 0.9351 - recall: 0.9296 - val_loss: 0.3428 - val_categorical_accuracy: 0.9086 - val_auc: 0.9752 - val_precision: 0.9125 - val_recall: 0.9067
# Epoch 129/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2072 - categorical_accuracy: 0.9353 - auc: 0.9897 - precision: 0.9372 - recall: 0.9334 - val_loss: 0.3470 - val_categorical_accuracy: 0.9106 - val_auc: 0.9721 - val_precision: 0.9116 - val_recall: 0.9098
# Epoch 130/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2282 - categorical_accuracy: 0.9298 - auc: 0.9879 - precision: 0.9333 - recall: 0.9276 - val_loss: 0.3077 - val_categorical_accuracy: 0.9196 - val_auc: 0.9785 - val_precision: 0.9213 - val_recall: 0.9181
# Epoch 131/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2076 - categorical_accuracy: 0.9330 - auc: 0.9901 - precision: 0.9363 - recall: 0.9305 - val_loss: 0.3349 - val_categorical_accuracy: 0.9094 - val_auc: 0.9768 - val_precision: 0.9110 - val_recall: 0.9079
# Epoch 132/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2141 - categorical_accuracy: 0.9335 - auc: 0.9896 - precision: 0.9363 - recall: 0.9309 - val_loss: 0.3328 - val_categorical_accuracy: 0.9077 - val_auc: 0.9786 - val_precision: 0.9098 - val_recall: 0.9067
# Epoch 133/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2004 - categorical_accuracy: 0.9353 - auc: 0.9908 - precision: 0.9382 - recall: 0.9323 - val_loss: 0.3193 - val_categorical_accuracy: 0.9135 - val_auc: 0.9786 - val_precision: 0.9146 - val_recall: 0.9130
# Epoch 134/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1981 - categorical_accuracy: 0.9374 - auc: 0.9911 - precision: 0.9405 - recall: 0.9352 - val_loss: 0.3198 - val_categorical_accuracy: 0.9133 - val_auc: 0.9802 - val_precision: 0.9156 - val_recall: 0.9125
# Epoch 135/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1997 - categorical_accuracy: 0.9385 - auc: 0.9909 - precision: 0.9412 - recall: 0.9357 - val_loss: 0.3207 - val_categorical_accuracy: 0.9184 - val_auc: 0.9776 - val_precision: 0.9192 - val_recall: 0.9174
# Epoch 136/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2053 - categorical_accuracy: 0.9353 - auc: 0.9902 - precision: 0.9376 - recall: 0.9328 - val_loss: 0.6439 - val_categorical_accuracy: 0.8304 - val_auc: 0.9510 - val_precision: 0.8333 - val_recall: 0.8292
# Epoch 137/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.3117 - categorical_accuracy: 0.9040 - auc: 0.9798 - precision: 0.9090 - recall: 0.8998 - val_loss: 0.3398 - val_categorical_accuracy: 0.9094 - val_auc: 0.9764 - val_precision: 0.9115 - val_recall: 0.9084
# Epoch 138/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2207 - categorical_accuracy: 0.9290 - auc: 0.9893 - precision: 0.9331 - recall: 0.9258 - val_loss: 0.3412 - val_categorical_accuracy: 0.9069 - val_auc: 0.9756 - val_precision: 0.9085 - val_recall: 0.9052
# Epoch 139/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2066 - categorical_accuracy: 0.9312 - auc: 0.9905 - precision: 0.9353 - recall: 0.9283 - val_loss: 0.3496 - val_categorical_accuracy: 0.9008 - val_auc: 0.9742 - val_precision: 0.9034 - val_recall: 0.8996
# Epoch 140/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2226 - categorical_accuracy: 0.9248 - auc: 0.9891 - precision: 0.9295 - recall: 0.9224 - val_loss: 0.3457 - val_categorical_accuracy: 0.8972 - val_auc: 0.9758 - val_precision: 0.9001 - val_recall: 0.8955
# Epoch 141/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2433 - categorical_accuracy: 0.9148 - auc: 0.9881 - precision: 0.9187 - recall: 0.9119 - val_loss: 0.3651 - val_categorical_accuracy: 0.9006 - val_auc: 0.9707 - val_precision: 0.9042 - val_recall: 0.8994
# Epoch 142/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2126 - categorical_accuracy: 0.9340 - auc: 0.9897 - precision: 0.9364 - recall: 0.9317 - val_loss: 0.3527 - val_categorical_accuracy: 0.9047 - val_auc: 0.9760 - val_precision: 0.9066 - val_recall: 0.9040
# Epoch 143/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1965 - categorical_accuracy: 0.9381 - auc: 0.9906 - precision: 0.9411 - recall: 0.9363 - val_loss: 0.3171 - val_categorical_accuracy: 0.9232 - val_auc: 0.9767 - val_precision: 0.9250 - val_recall: 0.9228
# Epoch 144/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1982 - categorical_accuracy: 0.9397 - auc: 0.9904 - precision: 0.9429 - recall: 0.9374 - val_loss: 0.3313 - val_categorical_accuracy: 0.9081 - val_auc: 0.9759 - val_precision: 0.9101 - val_recall: 0.9079
# Epoch 145/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2006 - categorical_accuracy: 0.9362 - auc: 0.9909 - precision: 0.9394 - recall: 0.9329 - val_loss: 0.3231 - val_categorical_accuracy: 0.9174 - val_auc: 0.9770 - val_precision: 0.9191 - val_recall: 0.9167
# Epoch 146/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1946 - categorical_accuracy: 0.9405 - auc: 0.9910 - precision: 0.9430 - recall: 0.9378 - val_loss: 0.3361 - val_categorical_accuracy: 0.9130 - val_auc: 0.9759 - val_precision: 0.9151 - val_recall: 0.9118
# Epoch 147/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1974 - categorical_accuracy: 0.9402 - auc: 0.9903 - precision: 0.9434 - recall: 0.9377 - val_loss: 0.3147 - val_categorical_accuracy: 0.9186 - val_auc: 0.9784 - val_precision: 0.9195 - val_recall: 0.9162
# Epoch 148/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2023 - categorical_accuracy: 0.9366 - auc: 0.9906 - precision: 0.9390 - recall: 0.9349 - val_loss: 0.3108 - val_categorical_accuracy: 0.9218 - val_auc: 0.9758 - val_precision: 0.9249 - val_recall: 0.9215
# Epoch 149/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2031 - categorical_accuracy: 0.9363 - auc: 0.9903 - precision: 0.9388 - recall: 0.9340 - val_loss: 0.3616 - val_categorical_accuracy: 0.9045 - val_auc: 0.9729 - val_precision: 0.9051 - val_recall: 0.9035
# Epoch 150/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2010 - categorical_accuracy: 0.9374 - auc: 0.9906 - precision: 0.9407 - recall: 0.9337 - val_loss: 0.3226 - val_categorical_accuracy: 0.9186 - val_auc: 0.9758 - val_precision: 0.9207 - val_recall: 0.9169
# Epoch 151/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1943 - categorical_accuracy: 0.9394 - auc: 0.9913 - precision: 0.9432 - recall: 0.9366 - val_loss: 0.3577 - val_categorical_accuracy: 0.9052 - val_auc: 0.9751 - val_precision: 0.9058 - val_recall: 0.9040
# Epoch 152/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2207 - categorical_accuracy: 0.9327 - auc: 0.9887 - precision: 0.9355 - recall: 0.9306 - val_loss: 0.3226 - val_categorical_accuracy: 0.9198 - val_auc: 0.9778 - val_precision: 0.9202 - val_recall: 0.9189
# Epoch 153/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1922 - categorical_accuracy: 0.9418 - auc: 0.9907 - precision: 0.9441 - recall: 0.9398 - val_loss: 0.3198 - val_categorical_accuracy: 0.9193 - val_auc: 0.9795 - val_precision: 0.9202 - val_recall: 0.9186
# Epoch 154/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1972 - categorical_accuracy: 0.9413 - auc: 0.9906 - precision: 0.9426 - recall: 0.9385 - val_loss: 0.3346 - val_categorical_accuracy: 0.9191 - val_auc: 0.9749 - val_precision: 0.9206 - val_recall: 0.9176
# Epoch 155/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1948 - categorical_accuracy: 0.9427 - auc: 0.9905 - precision: 0.9453 - recall: 0.9413 - val_loss: 0.3573 - val_categorical_accuracy: 0.9006 - val_auc: 0.9764 - val_precision: 0.9035 - val_recall: 0.8989
# Epoch 156/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2060 - categorical_accuracy: 0.9375 - auc: 0.9900 - precision: 0.9396 - recall: 0.9353 - val_loss: 0.3055 - val_categorical_accuracy: 0.9252 - val_auc: 0.9772 - val_precision: 0.9270 - val_recall: 0.9247
# Epoch 157/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1884 - categorical_accuracy: 0.9445 - auc: 0.9914 - precision: 0.9460 - recall: 0.9432 - val_loss: 0.3252 - val_categorical_accuracy: 0.9084 - val_auc: 0.9772 - val_precision: 0.9094 - val_recall: 0.9074
# Epoch 158/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1930 - categorical_accuracy: 0.9429 - auc: 0.9911 - precision: 0.9447 - recall: 0.9416 - val_loss: 0.3742 - val_categorical_accuracy: 0.9077 - val_auc: 0.9697 - val_precision: 0.9094 - val_recall: 0.9072
# Epoch 159/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2065 - categorical_accuracy: 0.9366 - auc: 0.9896 - precision: 0.9396 - recall: 0.9342 - val_loss: 0.3593 - val_categorical_accuracy: 0.8962 - val_auc: 0.9755 - val_precision: 0.8976 - val_recall: 0.8952
# Epoch 160/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2549 - categorical_accuracy: 0.9160 - auc: 0.9865 - precision: 0.9197 - recall: 0.9131 - val_loss: 0.3164 - val_categorical_accuracy: 0.9050 - val_auc: 0.9798 - val_precision: 0.9060 - val_recall: 0.9045
# Epoch 161/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1942 - categorical_accuracy: 0.9377 - auc: 0.9916 - precision: 0.9402 - recall: 0.9358 - val_loss: 0.3280 - val_categorical_accuracy: 0.9038 - val_auc: 0.9801 - val_precision: 0.9054 - val_recall: 0.9030
# Epoch 162/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2024 - categorical_accuracy: 0.9339 - auc: 0.9912 - precision: 0.9359 - recall: 0.9316 - val_loss: 0.2909 - val_categorical_accuracy: 0.9198 - val_auc: 0.9802 - val_precision: 0.9207 - val_recall: 0.9189
# Epoch 163/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2165 - categorical_accuracy: 0.9332 - auc: 0.9888 - precision: 0.9353 - recall: 0.9303 - val_loss: 0.3182 - val_categorical_accuracy: 0.9142 - val_auc: 0.9765 - val_precision: 0.9155 - val_recall: 0.9137
# Epoch 164/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2063 - categorical_accuracy: 0.9327 - auc: 0.9903 - precision: 0.9356 - recall: 0.9295 - val_loss: 0.2994 - val_categorical_accuracy: 0.9191 - val_auc: 0.9781 - val_precision: 0.9215 - val_recall: 0.9176
# Epoch 165/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2143 - categorical_accuracy: 0.9321 - auc: 0.9894 - precision: 0.9348 - recall: 0.9297 - val_loss: 0.3032 - val_categorical_accuracy: 0.9147 - val_auc: 0.9783 - val_precision: 0.9181 - val_recall: 0.9128
# Epoch 166/250
# ...
# Epoch 196/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2107 - categorical_accuracy: 0.9317 - auc: 0.9900 - precision: 0.9329 - recall: 0.9297 - val_loss: 0.3582 - val_categorical_accuracy: 0.9018 - val_auc: 0.9770 - val_precision: 0.9028 - val_recall: 0.9008
# Epoch 197/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2002 - categorical_accuracy: 0.9386 - auc: 0.9904 - precision: 0.9406 - recall: 0.9372 - val_loss: 0.3243 - val_categorical_accuracy: 0.9115 - val_auc: 0.9797 - val_precision: 0.9128 - val_recall: 0.9103
# Epoch 198/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1946 - categorical_accuracy: 0.9426 - auc: 0.9903 - precision: 0.9444 - recall: 0.9408 - val_loss: 0.3701 - val_categorical_accuracy: 0.8986 - val_auc: 0.9750 - val_precision: 0.8996 - val_recall: 0.8969
# Epoch 199/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1951 - categorical_accuracy: 0.9408 - auc: 0.9907 - precision: 0.9425 - recall: 0.9389 - val_loss: 0.3941 - val_categorical_accuracy: 0.8740 - val_auc: 0.9722 - val_precision: 0.8763 - val_recall: 0.8731
# Epoch 200/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2025 - categorical_accuracy: 0.9353 - auc: 0.9905 - precision: 0.9380 - recall: 0.9331 - val_loss: 0.3825 - val_categorical_accuracy: 0.8904 - val_auc: 0.9732 - val_precision: 0.8926 - val_recall: 0.8889
# Epoch 201/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1904 - categorical_accuracy: 0.9429 - auc: 0.9911 - precision: 0.9453 - recall: 0.9409 - val_loss: 0.3592 - val_categorical_accuracy: 0.9052 - val_auc: 0.9744 - val_precision: 0.9070 - val_recall: 0.9028
# Epoch 202/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1854 - categorical_accuracy: 0.9432 - auc: 0.9917 - precision: 0.9449 - recall: 0.9415 - val_loss: 0.3954 - val_categorical_accuracy: 0.8921 - val_auc: 0.9726 - val_precision: 0.8939 - val_recall: 0.8913
# Epoch 203/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1827 - categorical_accuracy: 0.9438 - auc: 0.9923 - precision: 0.9460 - recall: 0.9416 - val_loss: 0.3640 - val_categorical_accuracy: 0.9055 - val_auc: 0.9748 - val_precision: 0.9073 - val_recall: 0.9040
# Epoch 204/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1827 - categorical_accuracy: 0.9470 - auc: 0.9911 - precision: 0.9482 - recall: 0.9457 - val_loss: 0.3408 - val_categorical_accuracy: 0.9094 - val_auc: 0.9775 - val_precision: 0.9127 - val_recall: 0.9072
# Epoch 205/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1788 - categorical_accuracy: 0.9453 - auc: 0.9918 - precision: 0.9465 - recall: 0.9440 - val_loss: 0.4268 - val_categorical_accuracy: 0.8850 - val_auc: 0.9689 - val_precision: 0.8856 - val_recall: 0.8845
# Epoch 206/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1852 - categorical_accuracy: 0.9444 - auc: 0.9916 - precision: 0.9462 - recall: 0.9423 - val_loss: 0.3254 - val_categorical_accuracy: 0.9164 - val_auc: 0.9779 - val_precision: 0.9193 - val_recall: 0.9133
# Epoch 207/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1840 - categorical_accuracy: 0.9447 - auc: 0.9913 - precision: 0.9460 - recall: 0.9430 - val_loss: 0.3590 - val_categorical_accuracy: 0.9013 - val_auc: 0.9760 - val_precision: 0.9016 - val_recall: 0.8999
# Epoch 208/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2005 - categorical_accuracy: 0.9372 - auc: 0.9907 - precision: 0.9391 - recall: 0.9349 - val_loss: 0.3189 - val_categorical_accuracy: 0.9157 - val_auc: 0.9778 - val_precision: 0.9183 - val_recall: 0.9142
# Epoch 209/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1752 - categorical_accuracy: 0.9492 - auc: 0.9923 - precision: 0.9504 - recall: 0.9472 - val_loss: 0.3354 - val_categorical_accuracy: 0.9203 - val_auc: 0.9741 - val_precision: 0.9223 - val_recall: 0.9198
# Epoch 210/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1843 - categorical_accuracy: 0.9426 - auc: 0.9918 - precision: 0.9440 - recall: 0.9413 - val_loss: 0.3255 - val_categorical_accuracy: 0.9167 - val_auc: 0.9776 - val_precision: 0.9184 - val_recall: 0.9157
# Epoch 211/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1781 - categorical_accuracy: 0.9449 - auc: 0.9926 - precision: 0.9471 - recall: 0.9436 - val_loss: 0.3360 - val_categorical_accuracy: 0.9003 - val_auc: 0.9783 - val_precision: 0.9045 - val_recall: 0.8996
# Epoch 212/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1803 - categorical_accuracy: 0.9440 - auc: 0.9925 - precision: 0.9456 - recall: 0.9423 - val_loss: 0.3224 - val_categorical_accuracy: 0.9196 - val_auc: 0.9785 - val_precision: 0.9206 - val_recall: 0.9181
# Epoch 213/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1836 - categorical_accuracy: 0.9435 - auc: 0.9919 - precision: 0.9448 - recall: 0.9416 - val_loss: 0.3283 - val_categorical_accuracy: 0.9115 - val_auc: 0.9792 - val_precision: 0.9132 - val_recall: 0.9106
# Epoch 214/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1877 - categorical_accuracy: 0.9428 - auc: 0.9914 - precision: 0.9449 - recall: 0.9414 - val_loss: 0.3141 - val_categorical_accuracy: 0.9133 - val_auc: 0.9798 - val_precision: 0.9145 - val_recall: 0.9118
# Epoch 215/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1915 - categorical_accuracy: 0.9405 - auc: 0.9913 - precision: 0.9427 - recall: 0.9388 - val_loss: 0.3211 - val_categorical_accuracy: 0.9157 - val_auc: 0.9817 - val_precision: 0.9176 - val_recall: 0.9147
# Epoch 216/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1986 - categorical_accuracy: 0.9403 - auc: 0.9903 - precision: 0.9416 - recall: 0.9384 - val_loss: 0.3528 - val_categorical_accuracy: 0.9050 - val_auc: 0.9784 - val_precision: 0.9065 - val_recall: 0.9050
# Epoch 217/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1686 - categorical_accuracy: 0.9493 - auc: 0.9929 - precision: 0.9512 - recall: 0.9482 - val_loss: 0.3515 - val_categorical_accuracy: 0.9152 - val_auc: 0.9736 - val_precision: 0.9176 - val_recall: 0.9140
# Epoch 218/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1683 - categorical_accuracy: 0.9515 - auc: 0.9927 - precision: 0.9531 - recall: 0.9501 - val_loss: 0.3755 - val_categorical_accuracy: 0.9084 - val_auc: 0.9726 - val_precision: 0.9101 - val_recall: 0.9077
# Epoch 219/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1961 - categorical_accuracy: 0.9421 - auc: 0.9906 - precision: 0.9443 - recall: 0.9399 - val_loss: 0.4231 - val_categorical_accuracy: 0.8760 - val_auc: 0.9724 - val_precision: 0.8769 - val_recall: 0.8750
# Epoch 220/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1999 - categorical_accuracy: 0.9375 - auc: 0.9910 - precision: 0.9398 - recall: 0.9350 - val_loss: 0.3540 - val_categorical_accuracy: 0.8986 - val_auc: 0.9779 - val_precision: 0.8999 - val_recall: 0.8977
# Epoch 221/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1747 - categorical_accuracy: 0.9479 - auc: 0.9925 - precision: 0.9492 - recall: 0.9465 - val_loss: 0.3595 - val_categorical_accuracy: 0.9033 - val_auc: 0.9760 - val_precision: 0.9052 - val_recall: 0.9023
# Epoch 222/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1732 - categorical_accuracy: 0.9488 - auc: 0.9923 - precision: 0.9507 - recall: 0.9474 - val_loss: 0.3548 - val_categorical_accuracy: 0.9028 - val_auc: 0.9784 - val_precision: 0.9041 - val_recall: 0.9023
# Epoch 223/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1778 - categorical_accuracy: 0.9472 - auc: 0.9921 - precision: 0.9492 - recall: 0.9447 - val_loss: 0.3405 - val_categorical_accuracy: 0.9089 - val_auc: 0.9780 - val_precision: 0.9108 - val_recall: 0.9084
# Epoch 224/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1725 - categorical_accuracy: 0.9476 - auc: 0.9925 - precision: 0.9495 - recall: 0.9463 - val_loss: 0.3576 - val_categorical_accuracy: 0.9050 - val_auc: 0.9768 - val_precision: 0.9062 - val_recall: 0.9040
# Epoch 225/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1808 - categorical_accuracy: 0.9470 - auc: 0.9916 - precision: 0.9488 - recall: 0.9443 - val_loss: 0.3535 - val_categorical_accuracy: 0.9108 - val_auc: 0.9769 - val_precision: 0.9116 - val_recall: 0.9098
# Epoch 226/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1792 - categorical_accuracy: 0.9475 - auc: 0.9919 - precision: 0.9500 - recall: 0.9450 - val_loss: 0.3686 - val_categorical_accuracy: 0.9008 - val_auc: 0.9789 - val_precision: 0.9019 - val_recall: 0.9003
# Epoch 227/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2130 - categorical_accuracy: 0.9315 - auc: 0.9904 - precision: 0.9339 - recall: 0.9290 - val_loss: 0.3635 - val_categorical_accuracy: 0.8984 - val_auc: 0.9783 - val_precision: 0.9007 - val_recall: 0.8969
# Epoch 228/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1809 - categorical_accuracy: 0.9418 - auc: 0.9924 - precision: 0.9439 - recall: 0.9394 - val_loss: 0.3534 - val_categorical_accuracy: 0.8996 - val_auc: 0.9782 - val_precision: 0.9012 - val_recall: 0.8977
# Epoch 229/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1734 - categorical_accuracy: 0.9466 - auc: 0.9926 - precision: 0.9490 - recall: 0.9445 - val_loss: 0.3489 - val_categorical_accuracy: 0.9047 - val_auc: 0.9763 - val_precision: 0.9069 - val_recall: 0.9047
# Epoch 230/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1692 - categorical_accuracy: 0.9493 - auc: 0.9928 - precision: 0.9508 - recall: 0.9479 - val_loss: 0.3440 - val_categorical_accuracy: 0.9113 - val_auc: 0.9749 - val_precision: 0.9123 - val_recall: 0.9103
# Epoch 231/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1738 - categorical_accuracy: 0.9485 - auc: 0.9924 - precision: 0.9502 - recall: 0.9474 - val_loss: 0.3425 - val_categorical_accuracy: 0.9103 - val_auc: 0.9768 - val_precision: 0.9116 - val_recall: 0.9094
# Epoch 232/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1729 - categorical_accuracy: 0.9495 - auc: 0.9924 - precision: 0.9511 - recall: 0.9486 - val_loss: 0.3549 - val_categorical_accuracy: 0.9040 - val_auc: 0.9777 - val_precision: 0.9054 - val_recall: 0.9030
# Epoch 233/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1748 - categorical_accuracy: 0.9453 - auc: 0.9924 - precision: 0.9465 - recall: 0.9442 - val_loss: 0.3549 - val_categorical_accuracy: 0.9030 - val_auc: 0.9746 - val_precision: 0.9041 - val_recall: 0.9023
# Epoch 234/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1795 - categorical_accuracy: 0.9454 - auc: 0.9920 - precision: 0.9474 - recall: 0.9444 - val_loss: 0.3727 - val_categorical_accuracy: 0.9030 - val_auc: 0.9714 - val_precision: 0.9040 - val_recall: 0.9018
# Epoch 235/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1980 - categorical_accuracy: 0.9372 - auc: 0.9907 - precision: 0.9387 - recall: 0.9354 - val_loss: 0.4034 - val_categorical_accuracy: 0.8933 - val_auc: 0.9709 - val_precision: 0.8949 - val_recall: 0.8923
# Epoch 236/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.2034 - categorical_accuracy: 0.9362 - auc: 0.9903 - precision: 0.9385 - recall: 0.9340 - val_loss: 0.3736 - val_categorical_accuracy: 0.8928 - val_auc: 0.9756 - val_precision: 0.8940 - val_recall: 0.8921
# Epoch 237/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1773 - categorical_accuracy: 0.9444 - auc: 0.9924 - precision: 0.9464 - recall: 0.9428 - val_loss: 0.4382 - val_categorical_accuracy: 0.8757 - val_auc: 0.9712 - val_precision: 0.8781 - val_recall: 0.8743
# Epoch 238/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1879 - categorical_accuracy: 0.9418 - auc: 0.9918 - precision: 0.9425 - recall: 0.9406 - val_loss: 0.3640 - val_categorical_accuracy: 0.9025 - val_auc: 0.9752 - val_precision: 0.9034 - val_recall: 0.9006
# Epoch 239/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1754 - categorical_accuracy: 0.9492 - auc: 0.9920 - precision: 0.9500 - recall: 0.9481 - val_loss: 0.3465 - val_categorical_accuracy: 0.9084 - val_auc: 0.9772 - val_precision: 0.9093 - val_recall: 0.9067
# Epoch 240/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1635 - categorical_accuracy: 0.9517 - auc: 0.9930 - precision: 0.9529 - recall: 0.9503 - val_loss: 0.3408 - val_categorical_accuracy: 0.9077 - val_auc: 0.9777 - val_precision: 0.9087 - val_recall: 0.9067
# Epoch 241/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1633 - categorical_accuracy: 0.9505 - auc: 0.9930 - precision: 0.9516 - recall: 0.9492 - val_loss: 0.3363 - val_categorical_accuracy: 0.9169 - val_auc: 0.9750 - val_precision: 0.9175 - val_recall: 0.9154
# Epoch 242/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1782 - categorical_accuracy: 0.9435 - auc: 0.9922 - precision: 0.9448 - recall: 0.9427 - val_loss: 0.3306 - val_categorical_accuracy: 0.9140 - val_auc: 0.9764 - val_precision: 0.9152 - val_recall: 0.9128
# Epoch 243/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1669 - categorical_accuracy: 0.9507 - auc: 0.9931 - precision: 0.9519 - recall: 0.9493 - val_loss: 0.3358 - val_categorical_accuracy: 0.9147 - val_auc: 0.9763 - val_precision: 0.9155 - val_recall: 0.9135
# Epoch 244/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1778 - categorical_accuracy: 0.9444 - auc: 0.9927 - precision: 0.9460 - recall: 0.9427 - val_loss: 0.3257 - val_categorical_accuracy: 0.9174 - val_auc: 0.9777 - val_precision: 0.9189 - val_recall: 0.9162
# Epoch 245/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1682 - categorical_accuracy: 0.9480 - auc: 0.9932 - precision: 0.9499 - recall: 0.9469 - val_loss: 0.3534 - val_categorical_accuracy: 0.9098 - val_auc: 0.9735 - val_precision: 0.9115 - val_recall: 0.9084
# Epoch 246/250
# 12312/12312 [==============================] - 33s 3ms/sample - loss: 0.1929 - categorical_accuracy: 0.9371 - auc: 0.9916 - precision: 0.9394 - recall: 0.9345 - val_loss: 0.3377 - val_categorical_accuracy: 0.9130 - val_auc: 0.9741 - val_precision: 0.9151 - val_recall: 0.9118
# Epoch 247/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1654 - categorical_accuracy: 0.9530 - auc: 0.9930 - precision: 0.9548 - recall: 0.9520 - val_loss: 0.3334 - val_categorical_accuracy: 0.9162 - val_auc: 0.9749 - val_precision: 0.9186 - val_recall: 0.9154
# Epoch 248/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1649 - categorical_accuracy: 0.9515 - auc: 0.9927 - precision: 0.9535 - recall: 0.9504 - val_loss: 0.3504 - val_categorical_accuracy: 0.9064 - val_auc: 0.9753 - val_precision: 0.9070 - val_recall: 0.9052
# Epoch 249/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1628 - categorical_accuracy: 0.9517 - auc: 0.9934 - precision: 0.9532 - recall: 0.9505 - val_loss: 0.3342 - val_categorical_accuracy: 0.9157 - val_auc: 0.9750 - val_precision: 0.9167 - val_recall: 0.9142
# Epoch 250/250
# 12312/12312 [==============================] - 32s 3ms/sample - loss: 0.1731 - categorical_accuracy: 0.9471 - auc: 0.9924 - precision: 0.9487 - recall: 0.9456 - val_loss: 0.3560 - val_categorical_accuracy: 0.9079 - val_auc: 0.9757 - val_precision: 0.9087 - val_recall: 0.9069

# %% [markdown]
# ### $\textbf{Metrics vs. Training Epoch}$

# %%
# %matplotlib notebook

# Text legend labels for training set curves
train_set_lbl = ('Training Set (' + 
    str(int(100 * (1 - pct_validation))) + '%)');
    
# Text legend labels for validation set curves
val_set_lbl = ('Training Set (' + 
    str(int(100 * (1 - pct_validation))) + '%)');

# New figure
loss_fig = plt.figure(figsize=(9.9,12));

#############
# Loss plot #
#############
ax1 = plt.subplot(5,1,1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Linear grid of training epochs
epochs = arange(0,N_epoch);

# Cross-entropy error (dB) - training set
plt.plot(epochs,10 * log10(
    model.history.history['loss']),
    '.-',c='g',alpha=0.5,
    label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,10 * log10(
    model.history.history['val_loss']),
    '.-',c='k',alpha=0.5,
    label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Cross-Entropy Error vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Error${}_{\varepsilon}$ (dB)',fontsize=14);

# Legend
plt.legend();

#################
# Accuracy plot #
#################
plt.subplot(5,1,2,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['categorical_accuracy'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_categorical_accuracy'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Categorical Accuracy vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Accuracy${}_{\varepsilon}$ ($\times100\%$)',fontsize=14);

# Legend
plt.legend();

##################
# Precision plot #
##################
plt.subplot(5,1,3,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['precision'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_precision'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]); 

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Precision${}_{\varepsilon}$',fontsize=14);

# Legend
plt.legend();

###############
# Recall plot #
###############
plt.subplot(5,1,4,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['recall'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_recall'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Recall vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Recall${}_{\varepsilon}$',fontsize=14);

# Legend
plt.legend();

############
# AUC plot #
############
plt.subplot(5,1,5,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['auc'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_auc'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Area Under ROC Curve vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'AUC${}_{\varepsilon}$',fontsize=14);

# Legend
plt.legend();

# Optimize layout
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="989.9">

# %% [markdown]
# ### $\textbf{Pass Entire Dataset (i.e., Train }\cup\textbf{ Validation) to Model}$

# %%
# C x 1 class prediction for entire dataset
Y_hat = model.predict(
    X,                        # Input data
    batch_size=N_batch,       # Batch size
);

# Cast 1-hot class labels as ordinal labels
y_hat = argmax(Y_hat,axis=1); # Predictions
y_true = argmax(Y,axis=1);    # Ground truth

# %% [markdown]
# ### $\textbf{Confusion Matrix Using Predictions Output Above}$

# %%
#########################
#    Compute Matrix:    #
#########################

# Use the sklearn confusion matrix function
confusion_mat = confusion_matrix(y_true,y_hat,
    labels=[c for c in range(C)],sample_weight=None);

#########################
#   Confusion Plotter:  # - adapated from online example
#########################

def plot_confusion_matrix(C,classes,normalize=False,
            title='Confusion matrix',cmap=plt.cm.Greens):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    
    # Let epsilon > 0 be small...
    epsilon = 1e-7;
    
    # Normalization of confusion matrix C
    if normalize:
        C = C.astype('float') / (epsilon + C.sum(axis=1)[:, newaxis]);

    # Print the matrix C
    print(C);
    
    # Image representation
    ax = plt.gca();   # <-- grab current axes
    C = flipud(C);    # <-- flip horizontally for visualization
    im = ax.imshow(C,cmap=cmap);
    
    # Colorbar
    colorbar(im);
    
    # Title
    plt.title(title,fontsize=20,weight="bold");
    
    # Tick labels
    tick_marks = arange(len(classes));
    plt.xticks(tick_marks, classes, rotation=45,fontweight="bold");
    
    # Overwrite default y-axis limits
    plt.ylim([-0.5,len(classes)-0.5]);

    # Text labels in tiles (i.e., elements)
    fmt = '.2f' if normalize else 'd'
    thresh = C.max() / 2.
    for i, j in iter_prod(range(C.shape[0]), range(C.shape[1])):
        plt.text(j, i, format(C[i, j], fmt),
                 horizontalalignment="center",weight="bold",
                 color="white" if C[i, j] > thresh else "black")

    # x-axis labels
    plt.ylabel('True label',fontsize=16,weight="bold");
    
    # y-axis labels
    plt.xlabel('Predicted label',fontsize=16,weight="bold");
    
    # Set axis layout
    plt.tight_layout();
    
#########################
#    Scale Colorbar:    # - found this online
#########################

def colorbar(mappable):
    last_axes = plt.gca()
    ax = mappable.axes
    fig = ax.figure
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    cbar = fig.colorbar(mappable, cax=cax)
    plt.sca(last_axes)
    return cbar

#########################
#    Visualization:     #
#########################

conf_fig = plt.figure(figsize=(9.9,9.9));
plot_confusion_matrix(
    confusion_mat, 
    classes=[clss for clss in class_table],
    normalize=True,
    title='Confusion Matrix',
    cmap=plt.cm.Greens);
# Out:
# <img src="data:image/png;base64,..." width="989.9">
# [[0.98166501 0.00891972 0.00396432 0.00545094]
#  [0.02586466 0.96541353 0.00390977 0.00481203]
#  [0.00986436 0.00320592 0.95191122 0.0350185 ]
#  [0.0212     0.0044     0.0878     0.8866    ]]
