# %% [markdown]
# ## $\textbf{Inferring Musical Time Signature via Apple Watch Logs of Conductor Wrist Motion}$
#
# $\textbf{Author:}\text{ Ryan Burns}$
#
# $\text{When conducting a chamber group or orchestra, a musical conductor uses a designated baton pattern for each possible time signature a musical}$
# $\text{score could be written in. Suppose someone were to wear an Apple Watch on their right wrist while conducting, (assume watch IMU data is}$
# $\text{logged at 100 Hz). It is not unreasonable to suspect that we could train a machine learning model to predict the time signature corresponding }$
# $\text{to particular wrist motion patterns. A small amount of data is studied to prove this concept using }\textit{long short-term memory (LSTM)}\text{ networks.}$
# $\text{For a great overview of LSTM and other recurrent units, see: }\textit{https://colah.github.io/posts/2015-08-Understanding-LSTMs/}\text{. While intended }$
# $\text{for sequential data (e.g., the quasi-cyclostationary wrist motions of a conductor), we also admit that this is a small amount of training and }$
# $\text{validation data, so the generalization performance of these models across a variety of conductors, time signatures, and tempos could prove}$
# $\text{quite poor. With generalization performance being a concern, we a couple techniques to hopefully mitigate some amount of overfitting. }$
#
# $\text{We add Gaussian noise to the input signals to randomly vary input to the network, in addition to applying random dropout to a subset of}$
# $\text{the connections within the network at a fixed probability. The model is trained on a subset of data and validated on the remaining data.}$
#
# $\text{This specific deep learning architecture is comprised of a single convolutional layer fed to a dense hyperbolic tangent layer for feature,}$
# $\text{extraction preceding the long short-term memory layer. The LSTM units make use of both types of dropout available (ordinary and recurrent)}$
# $\text{as measures to reduce overfitting. A multidimensional sliding window is applied to the accelerometer, gyroscope, and IMU-fused watch}$
# $\text{orientation quaternion at the input layer of the network.}$
#
# $\textbf{Motion Class Labels:}$
#
# $\text{All class labels are defined for a right-handed user. An orchestral conductor varies their baton pattern according to 1 of 4 possible states, }$
# $\text{comprised of 3 time signature classes and a resting class (i.e., cessation of baton motion).}$
#
# $\text{0 }\leftrightarrow [1\enspace0\enspace0\enspace0]\leftrightarrow \text{REST}\Longrightarrow\text{conductor has ceased baton motion (no conducting)}$
#
# $\text{1 }\leftrightarrow [0\enspace1\enspace0\enspace0]\leftrightarrow {2/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{2}{4}}\text{ time signature}$
#
# $\text{2 }\leftrightarrow [0\enspace0\enspace1\enspace0]\leftrightarrow {3/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{3}{4}}\text{ time signature}$
#
# $\text{3 }\leftrightarrow [0\enspace0\enspace0\enspace1]\leftrightarrow {4/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{4}{4}}\text{ time signature}$
#
# $\text{For more information on musical time signatures, visit: }\textit{https://en.wikipedia.org/wiki/Time_signature}.$
#
# ![title](baton_motion.png)
#
# $\text{The baton patterns for each time signature of interest are depicted diagramatically above. We assume a tech enthusiast conductor who desires}$
# $\text{an Apple Watch app/experience for automatic discrimination between the 3 time signatures above, in addition to a catch-all }\textit{at-rest}\text{ state. We }$
# $\text{also assume that this conductor would like automatic time-signature inference to be as tempo-agnostic as possible. Be it }\textit{largo}\text{ or }\textit{prestissimo}\text{,}$
# $\text{we assume that the tempo of the musical composition of question would not fool the ideal baton pattern classifier. As such, while the amount}$
# $\text{of data collected for this analysis is still limited in its size and diversity (i.e., we can assume overfit models), efforts have been made during}$
# $\text{data collection to vary the tempo across each time signature's constituent wrist motion observations. The duration (in seconds or measures)}$
# $\text{of each time signature's wrist motion subsequence is also varied during collection. We create an aggregated dataset of independent concatenated}$
# $\text{collects for supervised learning in the code below.}$
#
# $\textbf{Note On Labeling:}$
#
# $\text{SensorLog labels are recorded in real time using the app's class label buttons for a streaming iPhone. This iPhone logs data concurrently with}$
# $\text{an Apple Watch, which also reports its own class labels. Since toggling of the Apple Watch's class labels using the SensorLog UI on the watch }$
# $\text{face would interfere with data collection of wrist motion, we use the }\textit{iPhone}\text{ to log wrist motion labels. By time-aligning the iPhone and Apple}$
# $\text{Watch streams below (i.e., using POSIX timestamps), we can readily provide wrist motion labels for the Apple Watch motion signals without}$
# $\text{interfering with their trajectory as just described. In short, real-time motion labeling is available through dual stream of Apple Watch }$
# $\text{iPhone data, where the former provides the motion observations of interest and the latter provides a mechanism for real-time motion labeling.}$

# %% [markdown]
# ### $\textbf{Import Packages}$

# %%
import pandas as pd
from os import getcwd, environ;
from itertools import product as iter_prod;
from matplotlib import pyplot as plt;
from mpl_toolkits.axes_grid1 import make_axes_locatable
from numpy import array, hstack, argmax, ones, zeros, log10;
from numpy import logical_or, logical_not, expand_dims, flip;
from numpy import  abs, arange, shape, newaxis, sum, flipud;
from numpy import nan_to_num, transpose;
from scipy.signal import spectrogram;

from tensorflow.keras.models import Sequential, Model;
from tensorflow.keras.optimizers import RMSprop;
from tensorflow.keras.metrics import CategoricalAccuracy;
from tensorflow.keras.metrics import Precision, Recall, AUC;
from tensorflow.keras.layers import Dropout, LSTM, Dense, Conv2D;
from tensorflow.keras.layers import Activation, Reshape, Conv1D;
from tensorflow.keras.layers import Input, GaussianNoise, ConvLSTM2D;
from sklearn.metrics import confusion_matrix;

from SensorLogUtils import convert_iPhone_units;

environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# ### $\textbf{Class Label Definitions}$

# %%
# Ordinal motion class labels
class_table = pd.DataFrame({
    'REST': {
        'id': 'REST', 
        'description': 'no conducting / baton pattern',
        '1-hot label': [1,0,0,0],
        'ordinal label': 0
    },
    '2/4': {
        'id': '2/4', 
        'description': 'conducting pattern for a 2/4 time signature',
        '1-hot label': [0,1,0,0],
        'ordinal label': 1
    },
    '3/4': {
        'id': '3/4', 
        'description':'conducting pattern for a 3/4 time signature',
        '1-hot label': [0,0,1,0],
        'ordinal label': 2
    },
    '4/4': {
        'id': '4/4', 
        'description':'conducting pattern for a 4/4 time signature',
        '1-hot label': [0,0,0,1],
        'ordinal label': 3
    }
});

# Number of classes
C = 4;

# Print class table
class_table
# Out:
#                                         REST  \
# id                                      REST
# description    no conducting / baton pattern
# 1-hot label                     [1, 0, 0, 0]
# ordinal label                              0
#
#                                                        2/4  \
# id                                                     2/4
# description    conducting pattern for a 2/4 time signature
# 1-hot label                                   [0, 1, 0, 0]
# ordinal label                                            1
#
#                                                        3/4  \
# id                                                     3/4
# description    conducting pattern for a 3/4 time signature
# 1-hot label                                   [0, 0, 1, 0]
# ordinal label                                            2
#
#                                                        4/4
# id                                                     4/4
# description    conducting pattern for a 4/4 time signature
# 1-hot label                                   [0, 0, 0, 1]
# ordinal label                                            3

# %% [markdown]
# ### $\textbf{Specify & Load Dataset}$

# %%
################
# Specify data #
################

# Specify local data storage path
data_path = getcwd() + '/data';

# Collect file string ID
collect_IDs = [
    'time_signatures_collect1',
    'time_signatures_collect2'
];

# Build string filename corresponding to collect_ID
collect_files = [
    (data_path + '/labeled_' + collect_ID + '_appleWatch.csv')
for collect_ID in collect_IDs];

#############
# Load data #
#############

# Load and concatenate dataframes for all
# labeled collects in list collect_IDs
df = pd.concat([pd.read_csv(f, 
    error_bad_lines=False,
    warn_bad_lines=False)
    for f in collect_files
],axis=0,ignore_index=True);

# Data fields (column headers)
fields = [fd for fd in df];

# Length of dataframe
N = len(df); # (samples)

# %% [markdown]
# ### $\textbf{Select IMU Data & 1-Hot Class Labels}$

# %%
# Select input signals
x = nan_to_num(array(df[[
    'accelerometerAccelerationX(m/s^2)',
    'accelerometerAccelerationY(m/s^2)',
    'accelerometerAccelerationZ(m/s^2)',
    'motionRotationRateX(rad/s)',
    'motionRotationRateY(rad/s)',
    'motionRotationRateZ(rad/s)'
]]));

# Define 1-hot labels
y = nan_to_num(array(df[[
    
    # List all class headers in table above
    class_name for class_name in class_table
]]));

# %% [markdown]
# ### $\textbf{Specify Sliding Observation Window Parameters}$

# %%
# Number of raw sensor samples (N)
# and their dimensionality (D)
N, D = shape(x);

# Sliding obs. window length
M = 256; # (samples)

# Step size of obs. window
m = 4;  # (samples)

# Linear grid for sliding observation
# window reflecting window length & step
# size specified above, mapped to raw
# sensor samples n = M, M + m, M + 2m, ...
obs_idx = [n for n in range(M,N,m)];

# %% [markdown]
# ### $\textbf{Define Observations & Class Labels}$

# %%
# Windowed spectrogram observation sequence input to model
# X = array([
#     hstack(tuple(spectrogram(x[(n - M):n,d],
#     window='parzen',fs=100,nperseg=32,nfft=256)[2] 
#     for d in range(D))) for n in obs_idx
# ]);

X = array([[spectrogram(x[(n - M):n,d],
    window='parzen',fs=100,
    nperseg=32,nfft=256)[2] 
    for d in range(D)] for n in obs_idx
]);

# Overwrite N,M,D with new dimensionality
N,K,M,D = shape(X);

# Ground truth 1-hot window-resolution class labels
Y = array([
    [1 if c == argmax(sum(y[(n - M):n,:],0)) 
    else 0 for c in range(C)] for n in obs_idx]);

# %% [markdown]
# ### $\textbf{Training Parameters}$

# %%
# Fraction of dataset to hold 
# out for model validation
pct_validation = 0.2;

# Total number of obs.
N_obs = len(X);

# Number of training epochs
N_epoch = 500;

# Number of batches
N_batch = int(N_obs / 3);

# %% [markdown]
# ### $\textbf{Define Machine Learning Model}$

# %%
#####################################################
# Define model architecture w/ Keras functional API #
#####################################################

# Input layer - M x D observation window
input_layer = Input((K,M,D));

# Add Gaussian noise to M x D input
h0 = GaussianNoise(1e-3)(input_layer);

# Convolutional layer
h1 = Conv2D(filters=M,
    kernel_size=(3,M),
    activation='relu')(h0);

# Dense hyperbolic tangent activation layer
h2 = Dense(32,activation='tanh')(h1);

h3 = Dropout(0.5)(h2);
h4 = Reshape((4,32))(h3);

h5 = Conv1D(32,3,activation='tanh')(h4);

# Long short-term memory layer
h6 = LSTM(16,activation='tanh',
    dropout=0.5,
    recurrent_dropout=0.5)(h5);

# Output layer - C x 1 softmax class activation 
output_layer = Dense(C,activation='softmax')(h6);

# Set up Keras Model() instance
model = Model(
    inputs=input_layer,  # Model inputs
    outputs=output_layer # Model outputs
);

###########################
# Define loss & optimizer #
###########################

# Set RMSprop optimization for 
# speed-of-convergence purposes
opt = RMSprop(
    learning_rate=0.001,
    rho=0.9,
    momentum=0.001,
    epsilon=1e-07,
    name="RMSprop"
);

# Model compilation, using categorical
# cross-entropy error w/ RMSprop
model.compile(
    
    # Error/loss function
    loss='categorical_crossentropy', 
    
    # Use RMSprop
    optimizer=opt,
    
    # List metrics here
    metrics=[
        CategoricalAccuracy(),
        AUC(),
        Precision(),
        Recall()
    ]
);

# Print a summary table
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 6, 129, 9)]       0
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 6, 129, 9)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 4, 1, 129)         449436
# _________________________________________________________________
# dense (Dense)                (None, 4, 1, 32)          4160
# _________________________________________________________________
# dropout (Dropout)            (None, 4, 1, 32)          0
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 32)             0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 2, 32)             3104
# _________________________________________________________________
# lstm (LSTM)                  (None, 16)                3136
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 459,904
# Trainable params: 459,904
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### $\textbf{Train Machine Learning Model}$

# %%
# Model training
model.fit(
    
    # Input dataset
    x=X, # windowed observations
    y=Y, # 1-hot motion class labels
    
    # Batch size
    batch_size=N_batch,
    
    # Number of training epochs
    epochs=N_epoch,
    
    # Print progress
    verbose=1,
    
    # Set aside fraction for validation
    validation_split=pct_validation,
    
    # False for time series
    shuffle=False,
    
    # Other misc params
    sample_weight=None,
    validation_freq=1,
    max_queue_size=10,
    
    # Parallelize job across 2 workers
    workers=2,
    use_multiprocessing=True
);
# Out:
# Train on 16390 samples, validate on 4098 samples
# Epoch 1/500
# 16390/16390 [==============================] - 14s 852us/sample - loss: 1.3750 - categorical_accuracy: 0.3312 - auc: 0.5526 - precision: 0.2800 - recall: 4.2709e-04 - val_loss: 1.2792 - val_categorical_accuracy: 0.4126 - val_auc: 0.6744 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/500
# 16390/16390 [==============================] - 9s 557us/sample - loss: 1.3240 - categorical_accuracy: 0.4167 - auc: 0.6323 - precision: 0.3214 - recall: 5.4912e-04 - val_loss: 1.2440 - val_categorical_accuracy: 0.4419 - val_auc: 0.7035 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/500
# 16390/16390 [==============================] - 9s 557us/sample - loss: 1.2883 - categorical_accuracy: 0.4380 - auc: 0.6717 - precision: 0.3056 - recall: 6.7114e-04 - val_loss: 1.2014 - val_categorical_accuracy: 0.4741 - val_auc: 0.7287 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/500
# 16390/16390 [==============================] - 9s 574us/sample - loss: 1.2490 - categorical_accuracy: 0.4727 - auc: 0.7084 - precision: 0.4054 - recall: 9.1519e-04 - val_loss: 1.1738 - val_categorical_accuracy: 0.4932 - val_auc: 0.7432 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/500
# 16390/16390 [==============================] - 9s 546us/sample - loss: 1.2208 - categorical_accuracy: 0.4860 - auc: 0.7316 - precision: 0.4884 - recall: 0.0013 - val_loss: 1.1505 - val_categorical_accuracy: 0.4956 - val_auc: 0.7501 - val_precision: 0.5000 - val_recall: 4.8804e-04
# Epoch 6/500
# 16390/16390 [==============================] - 9s 550us/sample - loss: 1.1927 - categorical_accuracy: 0.5010 - auc: 0.7506 - precision: 0.5806 - recall: 0.0033 - val_loss: 1.1170 - val_categorical_accuracy: 0.5139 - val_auc: 0.7602 - val_precision: 0.5750 - val_recall: 0.0056
# Epoch 7/500
# 16390/16390 [==============================] - 9s 561us/sample - loss: 1.1686 - categorical_accuracy: 0.5013 - auc: 0.7648 - precision: 0.7308 - recall: 0.0070 - val_loss: 1.0895 - val_categorical_accuracy: 0.5444 - val_auc: 0.7815 - val_precision: 0.7619 - val_recall: 0.0156
# Epoch 8/500
# 16390/16390 [==============================] - 9s 558us/sample - loss: 1.1440 - categorical_accuracy: 0.5183 - auc: 0.7823 - precision: 0.7931 - recall: 0.0112 - val_loss: 1.0618 - val_categorical_accuracy: 0.5339 - val_auc: 0.8102 - val_precision: 0.8000 - val_recall: 0.0303
# Epoch 9/500
# 16390/16390 [==============================] - 9s 565us/sample - loss: 1.1133 - categorical_accuracy: 0.5327 - auc: 0.8032 - precision: 0.8190 - recall: 0.0221 - val_loss: 1.0427 - val_categorical_accuracy: 0.5112 - val_auc: 0.8233 - val_precision: 0.8562 - val_recall: 0.0334
# Epoch 10/500
# 16390/16390 [==============================] - 9s 563us/sample - loss: 1.1016 - categorical_accuracy: 0.5252 - auc: 0.8047 - precision: 0.7771 - recall: 0.0302 - val_loss: 1.0062 - val_categorical_accuracy: 0.6027 - val_auc: 0.8686 - val_precision: 0.8477 - val_recall: 0.0408
# Epoch 11/500
# 16390/16390 [==============================] - 10s 582us/sample - loss: 1.0685 - categorical_accuracy: 0.5463 - auc: 0.8261 - precision: 0.8669 - recall: 0.0489 - val_loss: 0.9811 - val_categorical_accuracy: 0.5608 - val_auc: 0.8630 - val_precision: 0.8217 - val_recall: 0.0517
# Epoch 12/500
# 16390/16390 [==============================] - 9s 558us/sample - loss: 1.0411 - categorical_accuracy: 0.5586 - auc: 0.8385 - precision: 0.8983 - recall: 0.0862 - val_loss: 0.9611 - val_categorical_accuracy: 0.5403 - val_auc: 0.8621 - val_precision: 0.9533 - val_recall: 0.2538
# Epoch 13/500
# 16390/16390 [==============================] - 9s 559us/sample - loss: 1.0206 - categorical_accuracy: 0.5621 - auc: 0.8438 - precision: 0.9158 - recall: 0.1361 - val_loss: 0.9415 - val_categorical_accuracy: 0.5290 - val_auc: 0.8617 - val_precision: 0.9678 - val_recall: 0.2714
# Epoch 14/500
# 16390/16390 [==============================] - 9s 555us/sample - loss: 1.0217 - categorical_accuracy: 0.5562 - auc: 0.8371 - precision: 0.8981 - recall: 0.1743 - val_loss: 0.9306 - val_categorical_accuracy: 0.5317 - val_auc: 0.8586 - val_precision: 0.9637 - val_recall: 0.2723
# Epoch 15/500
# 16390/16390 [==============================] - 9s 557us/sample - loss: 0.9956 - categorical_accuracy: 0.5569 - auc: 0.8418 - precision: 0.9220 - recall: 0.2004 - val_loss: 0.9205 - val_categorical_accuracy: 0.5146 - val_auc: 0.8554 - val_precision: 0.9719 - val_recall: 0.2784
# Epoch 16/500
# 16390/16390 [==============================] - 9s 568us/sample - loss: 0.9843 - categorical_accuracy: 0.5552 - auc: 0.8415 - precision: 0.9220 - recall: 0.2201 - val_loss: 0.8972 - val_categorical_accuracy: 0.5400 - val_auc: 0.8616 - val_precision: 0.9680 - val_recall: 0.2806
# Epoch 17/500
# 16390/16390 [==============================] - 9s 579us/sample - loss: 0.9643 - categorical_accuracy: 0.5614 - auc: 0.8471 - precision: 0.9199 - recall: 0.2298 - val_loss: 0.8760 - val_categorical_accuracy: 0.5796 - val_auc: 0.8701 - val_precision: 0.9728 - val_recall: 0.2796
# Epoch 18/500
# 16390/16390 [==============================] - 9s 562us/sample - loss: 0.9408 - categorical_accuracy: 0.5772 - auc: 0.8579 - precision: 0.9128 - recall: 0.2383 - val_loss: 0.8466 - val_categorical_accuracy: 0.5796 - val_auc: 0.8753 - val_precision: 0.9512 - val_recall: 0.2904
# Epoch 19/500
# 16390/16390 [==============================] - 9s 550us/sample - loss: 0.9163 - categorical_accuracy: 0.5900 - auc: 0.8664 - precision: 0.9167 - recall: 0.2517 - val_loss: 0.8420 - val_categorical_accuracy: 0.5781 - val_auc: 0.8733 - val_precision: 0.9643 - val_recall: 0.2833
# Epoch 20/500
# 16390/16390 [==============================] - 9s 558us/sample - loss: 0.9063 - categorical_accuracy: 0.5982 - auc: 0.8695 - precision: 0.9022 - recall: 0.2561 - val_loss: 0.8130 - val_categorical_accuracy: 0.5947 - val_auc: 0.8812 - val_precision: 0.9408 - val_recall: 0.3023
# Epoch 21/500
# 16390/16390 [==============================] - 9s 573us/sample - loss: 0.8845 - categorical_accuracy: 0.6035 - auc: 0.8750 - precision: 0.8904 - recall: 0.2821 - val_loss: 0.8409 - val_categorical_accuracy: 0.5681 - val_auc: 0.8686 - val_precision: 0.9664 - val_recall: 0.2811
# Epoch 22/500
# 16390/16390 [==============================] - 9s 558us/sample - loss: 0.8885 - categorical_accuracy: 0.5987 - auc: 0.8718 - precision: 0.8910 - recall: 0.2782 - val_loss: 0.7969 - val_categorical_accuracy: 0.5930 - val_auc: 0.8824 - val_precision: 0.9427 - val_recall: 0.3092
# Epoch 23/500
# 16390/16390 [==============================] - 9s 573us/sample - loss: 0.8589 - categorical_accuracy: 0.6159 - auc: 0.8804 - precision: 0.8743 - recall: 0.3042 - val_loss: 0.7967 - val_categorical_accuracy: 0.5857 - val_auc: 0.8804 - val_precision: 0.8844 - val_recall: 0.3155
# Epoch 24/500
# 16390/16390 [==============================] - 10s 581us/sample - loss: 0.8503 - categorical_accuracy: 0.6231 - auc: 0.8826 - precision: 0.8618 - recall: 0.3191 - val_loss: 0.7785 - val_categorical_accuracy: 0.5974 - val_auc: 0.8850 - val_precision: 0.8207 - val_recall: 0.3463
# Epoch 25/500
# 16390/16390 [==============================] - 9s 570us/sample - loss: 0.8309 - categorical_accuracy: 0.6245 - auc: 0.8863 - precision: 0.8549 - recall: 0.3314 - val_loss: 0.7780 - val_categorical_accuracy: 0.5817 - val_auc: 0.8810 - val_precision: 0.7218 - val_recall: 0.3939
# Epoch 26/500
# 16390/16390 [==============================] - 9s 568us/sample - loss: 0.8200 - categorical_accuracy: 0.6317 - auc: 0.8890 - precision: 0.8475 - recall: 0.3451 - val_loss: 0.7702 - val_categorical_accuracy: 0.5847 - val_auc: 0.8832 - val_precision: 0.7187 - val_recall: 0.4046
# Epoch 27/500
# 16390/16390 [==============================] - 9s 554us/sample - loss: 0.8099 - categorical_accuracy: 0.6337 - auc: 0.8911 - precision: 0.8378 - recall: 0.3688 - val_loss: 0.7694 - val_categorical_accuracy: 0.5742 - val_auc: 0.8820 - val_precision: 0.6665 - val_recall: 0.4341
# Epoch 28/500
# 16390/16390 [==============================] - 9s 565us/sample - loss: 0.7952 - categorical_accuracy: 0.6454 - auc: 0.8954 - precision: 0.8389 - recall: 0.3725 - val_loss: 0.7689 - val_categorical_accuracy: 0.5910 - val_auc: 0.8832 - val_precision: 0.7116 - val_recall: 0.4161
# Epoch 29/500
# 16390/16390 [==============================] - 9s 561us/sample - loss: 0.7989 - categorical_accuracy: 0.6331 - auc: 0.8917 - precision: 0.8277 - recall: 0.3841 - val_loss: 0.8151 - val_categorical_accuracy: 0.5591 - val_auc: 0.8663 - val_precision: 0.6472 - val_recall: 0.4163
# Epoch 30/500
# 16390/16390 [==============================] - 10s 598us/sample - loss: 0.8187 - categorical_accuracy: 0.6256 - auc: 0.8842 - precision: 0.8141 - recall: 0.3764 - val_loss: 0.7645 - val_categorical_accuracy: 0.5827 - val_auc: 0.8820 - val_precision: 0.6689 - val_recall: 0.4427
# Epoch 31/500
# 16390/16390 [==============================] - 9s 553us/sample - loss: 0.7754 - categorical_accuracy: 0.6401 - auc: 0.8964 - precision: 0.8080 - recall: 0.4051 - val_loss: 0.7615 - val_categorical_accuracy: 0.5761 - val_auc: 0.8826 - val_precision: 0.6438 - val_recall: 0.4639
# Epoch 32/500
# 16390/16390 [==============================] - 9s 561us/sample - loss: 0.7623 - categorical_accuracy: 0.6522 - auc: 0.9007 - precision: 0.8168 - recall: 0.4180 - val_loss: 0.7556 - val_categorical_accuracy: 0.5788 - val_auc: 0.8840 - val_precision: 0.6613 - val_recall: 0.4588
# Epoch 33/500
# 16390/16390 [==============================] - 9s 566us/sample - loss: 0.7574 - categorical_accuracy: 0.6492 - auc: 0.9005 - precision: 0.8064 - recall: 0.4275 - val_loss: 0.7463 - val_categorical_accuracy: 0.5954 - val_auc: 0.8883 - val_precision: 0.6837 - val_recall: 0.4578
# Epoch 34/500
# 16390/16390 [==============================] - 9s 563us/sample - loss: 0.7421 - categorical_accuracy: 0.6532 - auc: 0.9044 - precision: 0.8046 - recall: 0.4420 - val_loss: 0.7539 - val_categorical_accuracy: 0.5898 - val_auc: 0.8863 - val_precision: 0.6502 - val_recall: 0.4768
# Epoch 35/500
# 16390/16390 [==============================] - 9s 553us/sample - loss: 0.7411 - categorical_accuracy: 0.6603 - auc: 0.9045 - precision: 0.8014 - recall: 0.4498 - val_loss: 0.7420 - val_categorical_accuracy: 0.5891 - val_auc: 0.8891 - val_precision: 0.6515 - val_recall: 0.4837
# Epoch 36/500
# 16390/16390 [==============================] - 9s 568us/sample - loss: 0.7279 - categorical_accuracy: 0.6638 - auc: 0.9079 - precision: 0.8018 - recall: 0.4652 - val_loss: 0.7486 - val_categorical_accuracy: 0.5786 - val_auc: 0.8866 - val_precision: 0.6195 - val_recall: 0.4934
# Epoch 37/500
# 16390/16390 [==============================] - 10s 591us/sample - loss: 0.7270 - categorical_accuracy: 0.6637 - auc: 0.9073 - precision: 0.7921 - recall: 0.4711 - val_loss: 0.7339 - val_categorical_accuracy: 0.5959 - val_auc: 0.8929 - val_precision: 0.6427 - val_recall: 0.5007
# Epoch 38/500
# 16390/16390 [==============================] - 9s 567us/sample - loss: 0.7220 - categorical_accuracy: 0.6589 - auc: 0.9073 - precision: 0.7853 - recall: 0.4800 - val_loss: 0.7420 - val_categorical_accuracy: 0.5869 - val_auc: 0.8903 - val_precision: 0.6250 - val_recall: 0.5083
# Epoch 39/500
# 16390/16390 [==============================] - 9s 570us/sample - loss: 0.6987 - categorical_accuracy: 0.6789 - auc: 0.9147 - precision: 0.7930 - recall: 0.4963 - val_loss: 0.7337 - val_categorical_accuracy: 0.6037 - val_auc: 0.8939 - val_precision: 0.6576 - val_recall: 0.5112
# Epoch 40/500
# 16390/16390 [==============================] - 9s 552us/sample - loss: 0.7063 - categorical_accuracy: 0.6692 - auc: 0.9110 - precision: 0.7785 - recall: 0.5006 - val_loss: 0.7332 - val_categorical_accuracy: 0.5998 - val_auc: 0.8938 - val_precision: 0.6406 - val_recall: 0.5120
# Epoch 41/500
# 16390/16390 [==============================] - 9s 563us/sample - loss: 0.6962 - categorical_accuracy: 0.6771 - auc: 0.9141 - precision: 0.7879 - recall: 0.5115 - val_loss: 0.7224 - val_categorical_accuracy: 0.6110 - val_auc: 0.8955 - val_precision: 0.6735 - val_recall: 0.4998
# Epoch 42/500
# 16390/16390 [==============================] - 9s 555us/sample - loss: 0.6996 - categorical_accuracy: 0.6714 - auc: 0.9121 - precision: 0.7780 - recall: 0.5088 - val_loss: 0.7271 - val_categorical_accuracy: 0.5979 - val_auc: 0.8943 - val_precision: 0.6330 - val_recall: 0.5207
# Epoch 43/500
# 16390/16390 [==============================] - 10s 607us/sample - loss: 0.6903 - categorical_accuracy: 0.6771 - auc: 0.9142 - precision: 0.7787 - recall: 0.5232 - val_loss: 0.7283 - val_categorical_accuracy: 0.6010 - val_auc: 0.8942 - val_precision: 0.6392 - val_recall: 0.5178
# Epoch 44/500
# 16390/16390 [==============================] - 9s 562us/sample - loss: 0.6818 - categorical_accuracy: 0.6806 - auc: 0.9163 - precision: 0.7794 - recall: 0.5306 - val_loss: 0.7281 - val_categorical_accuracy: 0.5905 - val_auc: 0.8946 - val_precision: 0.6176 - val_recall: 0.5268
# Epoch 45/500
# 16390/16390 [==============================] - 9s 564us/sample - loss: 0.6873 - categorical_accuracy: 0.6835 - auc: 0.9150 - precision: 0.7737 - recall: 0.5328 - val_loss: 0.7271 - val_categorical_accuracy: 0.6040 - val_auc: 0.8961 - val_precision: 0.6350 - val_recall: 0.5290
# Epoch 46/500
# 16390/16390 [==============================] - 9s 562us/sample - loss: 0.6730 - categorical_accuracy: 0.6899 - auc: 0.9180 - precision: 0.7726 - recall: 0.5462 - val_loss: 0.7251 - val_categorical_accuracy: 0.6015 - val_auc: 0.8973 - val_precision: 0.6373 - val_recall: 0.5347
# Epoch 47/500
# 16390/16390 [==============================] - 9s 556us/sample - loss: 0.6604 - categorical_accuracy: 0.6973 - auc: 0.9218 - precision: 0.7780 - recall: 0.5597 - val_loss: 0.7151 - val_categorical_accuracy: 0.6081 - val_auc: 0.8998 - val_precision: 0.6406 - val_recall: 0.5459
# Epoch 48/500
# 16390/16390 [==============================] - 9s 555us/sample - loss: 0.6680 - categorical_accuracy: 0.6886 - auc: 0.9189 - precision: 0.7688 - recall: 0.5623 - val_loss: 0.7264 - val_categorical_accuracy: 0.6044 - val_auc: 0.8963 - val_precision: 0.6382 - val_recall: 0.5381
# Epoch 49/500
# 16390/16390 [==============================] - 9s 571us/sample - loss: 0.6477 - categorical_accuracy: 0.7013 - auc: 0.9240 - precision: 0.7780 - recall: 0.5714 - val_loss: 0.7181 - val_categorical_accuracy: 0.5979 - val_auc: 0.8988 - val_precision: 0.6238 - val_recall: 0.5454
# Epoch 50/500
# 16390/16390 [==============================] - 10s 585us/sample - loss: 0.6694 - categorical_accuracy: 0.6910 - auc: 0.9185 - precision: 0.7627 - recall: 0.5653 - val_loss: 0.7321 - val_categorical_accuracy: 0.6052 - val_auc: 0.8989 - val_precision: 0.6287 - val_recall: 0.5454
# Epoch 51/500
# 16390/16390 [==============================] - 9s 563us/sample - loss: 0.6315 - categorical_accuracy: 0.7126 - auc: 0.9287 - precision: 0.7865 - recall: 0.5930 - val_loss: 0.7579 - val_categorical_accuracy: 0.5830 - val_auc: 0.8889 - val_precision: 0.6016 - val_recall: 0.5373
# Epoch 52/500
# 16390/16390 [==============================] - 9s 563us/sample - loss: 0.6873 - categorical_accuracy: 0.6855 - auc: 0.9141 - precision: 0.7576 - recall: 0.5743 - val_loss: 0.7122 - val_categorical_accuracy: 0.6137 - val_auc: 0.9017 - val_precision: 0.6536 - val_recall: 0.5586
# Epoch 53/500
# 16390/16390 [==============================] - 9s 565us/sample - loss: 0.6322 - categorical_accuracy: 0.7136 - auc: 0.9286 - precision: 0.7854 - recall: 0.6030 - val_loss: 0.7124 - val_categorical_accuracy: 0.6240 - val_auc: 0.9011 - val_precision: 0.6577 - val_recall: 0.5627
# Epoch 54/500
# 16390/16390 [==============================] - 9s 562us/sample - loss: 0.6518 - categorical_accuracy: 0.7054 - auc: 0.9235 - precision: 0.7705 - recall: 0.6000 - val_loss: 0.7274 - val_categorical_accuracy: 0.6040 - val_auc: 0.8993 - val_precision: 0.6328 - val_recall: 0.5632
# Epoch 55/500
# 16390/16390 [==============================] - 9s 554us/sample - loss: 0.6390 - categorical_accuracy: 0.7124 - auc: 0.9266 - precision: 0.7766 - recall: 0.6067 - val_loss: 0.6906 - val_categorical_accuracy: 0.6545 - val_auc: 0.9098 - val_precision: 0.6937 - val_recall: 0.5996
# Epoch 56/500
# 16390/16390 [==============================] - 10s 589us/sample - loss: 0.6357 - categorical_accuracy: 0.7128 - auc: 0.9268 - precision: 0.7733 - recall: 0.6108 - val_loss: 0.7269 - val_categorical_accuracy: 0.5983 - val_auc: 0.8983 - val_precision: 0.6245 - val_recall: 0.5576
# Epoch 57/500
# 16390/16390 [==============================] - 9s 580us/sample - loss: 0.6332 - categorical_accuracy: 0.7156 - auc: 0.9283 - precision: 0.7775 - recall: 0.6207 - val_loss: 0.6984 - val_categorical_accuracy: 0.6393 - val_auc: 0.9079 - val_precision: 0.6675 - val_recall: 0.5878
# Epoch 58/500
# 16390/16390 [==============================] - 9s 572us/sample - loss: 0.5956 - categorical_accuracy: 0.7352 - auc: 0.9369 - precision: 0.7889 - recall: 0.6453 - val_loss: 0.7168 - val_categorical_accuracy: 0.6149 - val_auc: 0.9032 - val_precision: 0.6334 - val_recall: 0.5725
# Epoch 59/500
# 16390/16390 [==============================] - 9s 555us/sample - loss: 0.6135 - categorical_accuracy: 0.7261 - auc: 0.9326 - precision: 0.7806 - recall: 0.6438 - val_loss: 0.7392 - val_categorical_accuracy: 0.6071 - val_auc: 0.9022 - val_precision: 0.6264 - val_recall: 0.5688
# Epoch 60/500
# 16390/16390 [==============================] - 9s 565us/sample - loss: 0.5991 - categorical_accuracy: 0.7309 - auc: 0.9355 - precision: 0.7814 - recall: 0.6487 - val_loss: 0.7399 - val_categorical_accuracy: 0.6384 - val_auc: 0.9008 - val_precision: 0.6574 - val_recall: 0.6040
# Epoch 61/500
# 16390/16390 [==============================] - 9s 555us/sample - loss: 0.6772 - categorical_accuracy: 0.6943 - auc: 0.9167 - precision: 0.7393 - recall: 0.6223 - val_loss: 0.6791 - val_categorical_accuracy: 0.6667 - val_auc: 0.9147 - val_precision: 0.6993 - val_recall: 0.6249
# Epoch 62/500
# 16390/16390 [==============================] - 10s 582us/sample - loss: 0.6012 - categorical_accuracy: 0.7311 - auc: 0.9344 - precision: 0.7778 - recall: 0.6535 - val_loss: 0.7860 - val_categorical_accuracy: 0.5793 - val_auc: 0.8935 - val_precision: 0.5933 - val_recall: 0.5554
# Epoch 63/500
# 16390/16390 [==============================] - 9s 568us/sample - loss: 0.6314 - categorical_accuracy: 0.7201 - auc: 0.9284 - precision: 0.7675 - recall: 0.6445 - val_loss: 0.6803 - val_categorical_accuracy: 0.6554 - val_auc: 0.9132 - val_precision: 0.6812 - val_recall: 0.6042
# Epoch 64/500
# 16390/16390 [==============================] - 9s 575us/sample - loss: 0.5844 - categorical_accuracy: 0.7389 - auc: 0.9387 - precision: 0.7869 - recall: 0.6665 - val_loss: 0.7377 - val_categorical_accuracy: 0.6093 - val_auc: 0.9037 - val_precision: 0.6213 - val_recall: 0.5742
# Epoch 65/500
# 16390/16390 [==============================] - 9s 569us/sample - loss: 0.5760 - categorical_accuracy: 0.7520 - auc: 0.9412 - precision: 0.7997 - recall: 0.6811 - val_loss: 0.6802 - val_categorical_accuracy: 0.6484 - val_auc: 0.9135 - val_precision: 0.6715 - val_recall: 0.6101
# Epoch 66/500
# 16390/16390 [==============================] - 9s 559us/sample - loss: 0.5707 - categorical_accuracy: 0.7459 - auc: 0.9416 - precision: 0.7896 - recall: 0.6788 - val_loss: 0.7354 - val_categorical_accuracy: 0.6164 - val_auc: 0.9057 - val_precision: 0.6341 - val_recall: 0.5793
# Epoch 67/500
# 16390/16390 [==============================] - 9s 569us/sample - loss: 0.5608 - categorical_accuracy: 0.7570 - auc: 0.9444 - precision: 0.8020 - recall: 0.6893 - val_loss: 0.7228 - val_categorical_accuracy: 0.6388 - val_auc: 0.9052 - val_precision: 0.6539 - val_recall: 0.6103
# Epoch 68/500
# 16390/16390 [==============================] - 9s 571us/sample - loss: 0.6271 - categorical_accuracy: 0.7201 - auc: 0.9293 - precision: 0.7592 - recall: 0.6644 - val_loss: 0.6540 - val_categorical_accuracy: 0.7013 - val_auc: 0.9228 - val_precision: 0.7242 - val_recall: 0.6657
# Epoch 69/500
# 16390/16390 [==============================] - 10s 584us/sample - loss: 0.5786 - categorical_accuracy: 0.7427 - auc: 0.9391 - precision: 0.7800 - recall: 0.6821 - val_loss: 0.7936 - val_categorical_accuracy: 0.5876 - val_auc: 0.8963 - val_precision: 0.6010 - val_recall: 0.5642
# Epoch 70/500
# 16390/16390 [==============================] - 9s 566us/sample - loss: 0.5929 - categorical_accuracy: 0.7390 - auc: 0.9365 - precision: 0.7763 - recall: 0.6785 - val_loss: 0.7057 - val_categorical_accuracy: 0.6428 - val_auc: 0.9114 - val_precision: 0.6636 - val_recall: 0.6047
# Epoch 71/500
# 16390/16390 [==============================] - 9s 565us/sample - loss: 0.5393 - categorical_accuracy: 0.7746 - auc: 0.9495 - precision: 0.8143 - recall: 0.7164 - val_loss: 0.6800 - val_categorical_accuracy: 0.6628 - val_auc: 0.9149 - val_precision: 0.6811 - val_recall: 0.6323
# Epoch 72/500
# 16390/16390 [==============================] - 9s 566us/sample - loss: 0.5779 - categorical_accuracy: 0.7467 - auc: 0.9398 - precision: 0.7848 - recall: 0.6921 - val_loss: 0.7715 - val_categorical_accuracy: 0.6093 - val_auc: 0.9024 - val_precision: 0.6200 - val_recall: 0.5808
# Epoch 73/500
# 16390/16390 [==============================] - 9s 561us/sample - loss: 0.5491 - categorical_accuracy: 0.7645 - auc: 0.9464 - precision: 0.8028 - recall: 0.7085 - val_loss: 0.6621 - val_categorical_accuracy: 0.6767 - val_auc: 0.9188 - val_precision: 0.6922 - val_recall: 0.6442
# Epoch 74/500
# 16390/16390 [==============================] - 10s 585us/sample - loss: 0.5476 - categorical_accuracy: 0.7575 - auc: 0.9457 - precision: 0.7919 - recall: 0.7082 - val_loss: 0.7769 - val_categorical_accuracy: 0.6008 - val_auc: 0.9016 - val_precision: 0.6139 - val_recall: 0.5769
# Epoch 75/500
# 16390/16390 [==============================] - 10s 609us/sample - loss: 0.5496 - categorical_accuracy: 0.7637 - auc: 0.9460 - precision: 0.7961 - recall: 0.7148 - val_loss: 0.7164 - val_categorical_accuracy: 0.6489 - val_auc: 0.9114 - val_precision: 0.6673 - val_recall: 0.6152
# Epoch 76/500
# 16390/16390 [==============================] - 9s 559us/sample - loss: 0.5264 - categorical_accuracy: 0.7832 - auc: 0.9519 - precision: 0.8194 - recall: 0.7309 - val_loss: 0.7446 - val_categorical_accuracy: 0.6345 - val_auc: 0.9044 - val_precision: 0.6463 - val_recall: 0.6144
# Epoch 77/500
# 16390/16390 [==============================] - 9s 567us/sample - loss: 0.6112 - categorical_accuracy: 0.7445 - auc: 0.9344 - precision: 0.7770 - recall: 0.6924 - val_loss: 0.6595 - val_categorical_accuracy: 0.6925 - val_auc: 0.9225 - val_precision: 0.7129 - val_recall: 0.6611
# Epoch 78/500
# 16390/16390 [==============================] - 9s 568us/sample - loss: 0.5498 - categorical_accuracy: 0.7618 - auc: 0.9454 - precision: 0.7908 - recall: 0.7152 - val_loss: 0.7941 - val_categorical_accuracy: 0.6030 - val_auc: 0.9007 - val_precision: 0.6135 - val_recall: 0.5798
# Epoch 79/500
# 16390/16390 [==============================] - 9s 561us/sample - loss: 0.5379 - categorical_accuracy: 0.7703 - auc: 0.9485 - precision: 0.8022 - recall: 0.7228 - val_loss: 0.6867 - val_categorical_accuracy: 0.6667 - val_auc: 0.9169 - val_precision: 0.6864 - val_recall: 0.6340
# Epoch 80/500
# 16390/16390 [==============================] - 9s 559us/sample - loss: 0.4960 - categorical_accuracy: 0.8009 - auc: 0.9577 - precision: 0.8310 - recall: 0.7561 - val_loss: 0.7085 - val_categorical_accuracy: 0.6515 - val_auc: 0.9141 - val_precision: 0.6675 - val_recall: 0.6247
# Epoch 81/500
# 16390/16390 [==============================] - 9s 555us/sample - loss: 0.4948 - categorical_accuracy: 0.8018 - auc: 0.9581 - precision: 0.8324 - recall: 0.7572 - val_loss: 0.6290 - val_categorical_accuracy: 0.7157 - val_auc: 0.9298 - val_precision: 0.7346 - val_recall: 0.6908
# Epoch 82/500
# 16390/16390 [==============================] - 9s 578us/sample - loss: 0.5446 - categorical_accuracy: 0.7569 - auc: 0.9455 - precision: 0.7826 - recall: 0.7185 - val_loss: 0.7451 - val_categorical_accuracy: 0.6257 - val_auc: 0.9079 - val_precision: 0.6417 - val_recall: 0.5988
# Epoch 83/500
# 16390/16390 [==============================] - 9s 559us/sample - loss: 0.5103 - categorical_accuracy: 0.7876 - auc: 0.9541 - precision: 0.8178 - recall: 0.7431 - val_loss: 0.6623 - val_categorical_accuracy: 0.7045 - val_auc: 0.9241 - val_precision: 0.7211 - val_recall: 0.6720
# Epoch 84/500
# 16390/16390 [==============================] - 9s 560us/sample - loss: 0.5020 - categorical_accuracy: 0.7912 - auc: 0.9550 - precision: 0.8184 - recall: 0.7519 - val_loss: 0.7541 - val_categorical_accuracy: 0.6296 - val_auc: 0.9097 - val_precision: 0.6414 - val_recall: 0.6061
# Epoch 85/500
# 16390/16390 [==============================] - 9s 562us/sample - loss: 0.5046 - categorical_accuracy: 0.7883 - auc: 0.9549 - precision: 0.8156 - recall: 0.7538 - val_loss: 0.6329 - val_categorical_accuracy: 0.7206 - val_auc: 0.9297 - val_precision: 0.7358 - val_recall: 0.6964
# Epoch 86/500
# 16390/16390 [==============================] - 9s 565us/sample - loss: 0.5163 - categorical_accuracy: 0.7779 - auc: 0.9516 - precision: 0.8013 - recall: 0.7424 - val_loss: 0.8320 - val_categorical_accuracy: 0.6227 - val_auc: 0.9034 - val_precision: 0.6384 - val_recall: 0.5976
# Epoch 87/500
# 16390/16390 [==============================] - 9s 572us/sample - loss: 0.5073 - categorical_accuracy: 0.7888 - auc: 0.9542 - precision: 0.8179 - recall: 0.7501 - val_loss: 0.7272 - val_categorical_accuracy: 0.6564 - val_auc: 0.9118 - val_precision: 0.6679 - val_recall: 0.6388
# Epoch 88/500
# 16390/16390 [==============================] - 10s 584us/sample - loss: 0.5455 - categorical_accuracy: 0.7790 - auc: 0.9479 - precision: 0.8058 - recall: 0.7431 - val_loss: 0.7076 - val_categorical_accuracy: 0.6757 - val_auc: 0.9184 - val_precision: 0.6890 - val_recall: 0.6449
# Epoch 89/500
# 16390/16390 [==============================] - 9s 566us/sample - loss: 0.4586 - categorical_accuracy: 0.8210 - auc: 0.9639 - precision: 0.8479 - recall: 0.7893 - val_loss: 0.5992 - val_categorical_accuracy: 0.7399 - val_auc: 0.9374 - val_precision: 0.7563 - val_recall: 0.7225
# Epoch 90/500
# 16390/16390 [==============================] - 9s 565us/sample - loss: 0.5141 - categorical_accuracy: 0.7773 - auc: 0.9520 - precision: 0.7995 - recall: 0.7464 - val_loss: 0.7759 - val_categorical_accuracy: 0.6225 - val_auc: 0.9071 - val_precision: 0.6321 - val_recall: 0.5988
# Epoch 91/500
# 16390/16390 [==============================] - 9s 564us/sample - loss: 0.4958 - categorical_accuracy: 0.7985 - auc: 0.9568 - precision: 0.8220 - recall: 0.7656 - val_loss: 0.6086 - val_categorical_accuracy: 0.7494 - val_auc: 0.9370 - val_precision: 0.7645 - val_recall: 0.7328
# Epoch 92/500
# 16390/16390 [==============================] - 9s 552us/sample - loss: 0.4915 - categorical_accuracy: 0.7954 - auc: 0.9565 - precision: 0.8159 - recall: 0.7674 - val_loss: 0.7668 - val_categorical_accuracy: 0.6459 - val_auc: 0.9121 - val_precision: 0.6571 - val_recall: 0.6220
# Epoch 93/500
# 16390/16390 [==============================] - 9s 563us/sample - loss: 0.4647 - categorical_accuracy: 0.8121 - auc: 0.9620 - precision: 0.8362 - recall: 0.7810 - val_loss: 0.6516 - val_categorical_accuracy: 0.7042 - val_auc: 0.9276 - val_precision: 0.7145 - val_recall: 0.6889
# Epoch 94/500
# 16390/16390 [==============================] - 9s 563us/sample - loss: 0.5113 - categorical_accuracy: 0.7881 - auc: 0.9532 - precision: 0.8104 - recall: 0.7597 - val_loss: 0.7157 - val_categorical_accuracy: 0.6667 - val_auc: 0.9186 - val_precision: 0.6836 - val_recall: 0.6464
# Epoch 95/500
# 16390/16390 [==============================] - 9s 569us/sample - loss: 0.4443 - categorical_accuracy: 0.8303 - auc: 0.9658 - precision: 0.8508 - recall: 0.7991 - val_loss: 0.5955 - val_categorical_accuracy: 0.7518 - val_auc: 0.9390 - val_precision: 0.7597 - val_recall: 0.7367
# Epoch 96/500
# 16390/16390 [==============================] - 9s 554us/sample - loss: 0.5048 - categorical_accuracy: 0.7811 - auc: 0.9538 - precision: 0.8001 - recall: 0.7564 - val_loss: 0.8098 - val_categorical_accuracy: 0.6125 - val_auc: 0.9052 - val_precision: 0.6232 - val_recall: 0.5954
# Epoch 97/500
# 16390/16390 [==============================] - 10s 582us/sample - loss: 0.4809 - categorical_accuracy: 0.8057 - auc: 0.9590 - precision: 0.8289 - recall: 0.7784 - val_loss: 0.6475 - val_categorical_accuracy: 0.7167 - val_auc: 0.9307 - val_precision: 0.7347 - val_recall: 0.6979
# Epoch 98/500
# 16390/16390 [==============================] - 9s 568us/sample - loss: 0.4388 - categorical_accuracy: 0.8284 - auc: 0.9665 - precision: 0.8498 - recall: 0.8007 - val_loss: 0.7326 - val_categorical_accuracy: 0.6606 - val_auc: 0.9181 - val_precision: 0.6731 - val_recall: 0.6432
# Epoch 99/500
# 16390/16390 [==============================] - 9s 558us/sample - loss: 0.4419 - categorical_accuracy: 0.8281 - auc: 0.9659 - precision: 0.8503 - recall: 0.8027 - val_loss: 0.5946 - val_categorical_accuracy: 0.7740 - val_auc: 0.9412 - val_precision: 0.7821 - val_recall: 0.7645
# Epoch 100/500
# 16390/16390 [==============================] - 9s 558us/sample - loss: 0.5274 - categorical_accuracy: 0.7688 - auc: 0.9495 - precision: 0.7847 - recall: 0.7449 - val_loss: 0.6817 - val_categorical_accuracy: 0.6813 - val_auc: 0.9232 - val_precision: 0.6965 - val_recall: 0.6598
# Epoch 101/500
# 16390/16390 [==============================] - 10s 592us/sample - loss: 0.4313 - categorical_accuracy: 0.8367 - auc: 0.9678 - precision: 0.8552 - recall: 0.8092 - val_loss: 0.6636 - val_categorical_accuracy: 0.7284 - val_auc: 0.9315 - val_precision: 0.7415 - val_recall: 0.7118
# Epoch 102/500
# 16390/16390 [==============================] - 9s 570us/sample - loss: 0.4488 - categorical_accuracy: 0.8243 - auc: 0.9644 - precision: 0.8436 - recall: 0.7991 - val_loss: 0.8385 - val_categorical_accuracy: 0.6122 - val_auc: 0.9040 - val_precision: 0.6235 - val_recall: 0.6005
# Epoch 103/500
# 16390/16390 [==============================] - 9s 554us/sample - loss: 0.4808 - categorical_accuracy: 0.8112 - auc: 0.9592 - precision: 0.8317 - recall: 0.7866 - val_loss: 0.6631 - val_categorical_accuracy: 0.7206 - val_auc: 0.9306 - val_precision: 0.7338 - val_recall: 0.7035
# Epoch 104/500
# 16390/16390 [==============================] - 9s 569us/sample - loss: 0.4131 - categorical_accuracy: 0.8405 - auc: 0.9703 - precision: 0.8594 - recall: 0.8181 - val_loss: 0.7963 - val_categorical_accuracy: 0.6508 - val_auc: 0.9145 - val_precision: 0.6582 - val_recall: 0.6310
# Epoch 105/500
# 16390/16390 [==============================] - 9s 564us/sample - loss: 0.4439 - categorical_accuracy: 0.8218 - auc: 0.9648 - precision: 0.8390 - recall: 0.7984 - val_loss: 0.6073 - val_categorical_accuracy: 0.7694 - val_auc: 0.9407 - val_precision: 0.7763 - val_recall: 0.7621
# Epoch 106/500
# 16390/16390 [==============================] - 9s 562us/sample - loss: 0.5141 - categorical_accuracy: 0.7770 - auc: 0.9519 - precision: 0.7927 - recall: 0.7558 - val_loss: 0.6419 - val_categorical_accuracy: 0.7184 - val_auc: 0.9318 - val_precision: 0.7336 - val_recall: 0.6969
# Epoch 107/500
# 16390/16390 [==============================] - 10s 595us/sample - loss: 0.4064 - categorical_accuracy: 0.8476 - auc: 0.9715 - precision: 0.8663 - recall: 0.8238 - val_loss: 0.7606 - val_categorical_accuracy: 0.6606 - val_auc: 0.9176 - val_precision: 0.6721 - val_recall: 0.6462
# Epoch 108/500
# 16390/16390 [==============================] - 9s 574us/sample - loss: 0.4174 - categorical_accuracy: 0.8361 - auc: 0.9692 - precision: 0.8542 - recall: 0.8153 - val_loss: 0.6058 - val_categorical_accuracy: 0.7760 - val_auc: 0.9415 - val_precision: 0.7854 - val_recall: 0.7635
# Epoch 109/500
# 16390/16390 [==============================] - 9s 566us/sample - loss: 0.4950 - categorical_accuracy: 0.7909 - auc: 0.9559 - precision: 0.8069 - recall: 0.7705 - val_loss: 0.7382 - val_categorical_accuracy: 0.6615 - val_auc: 0.9182 - val_precision: 0.6730 - val_recall: 0.6432
# Epoch 110/500
# 16390/16390 [==============================] - 9s 565us/sample - loss: 0.4094 - categorical_accuracy: 0.8461 - auc: 0.9707 - precision: 0.8642 - recall: 0.8239 - val_loss: 0.6210 - val_categorical_accuracy: 0.7596 - val_auc: 0.9386 - val_precision: 0.7706 - val_recall: 0.7433
# Epoch 111/500
# 16390/16390 [==============================] - 9s 569us/sample - loss: 0.4305 - categorical_accuracy: 0.8268 - auc: 0.9666 - precision: 0.8419 - recall: 0.8072 - val_loss: 0.7958 - val_categorical_accuracy: 0.6518 - val_auc: 0.9146 - val_precision: 0.6634 - val_recall: 0.6335
# Epoch 112/500
# 16390/16390 [==============================] - 9s 575us/sample - loss: 0.4187 - categorical_accuracy: 0.8375 - auc: 0.9687 - precision: 0.8546 - recall: 0.8153 - val_loss: 0.5888 - val_categorical_accuracy: 0.7726 - val_auc: 0.9434 - val_precision: 0.7801 - val_recall: 0.7616
# Epoch 113/500
# 16390/16390 [==============================] - 9s 574us/sample - loss: 0.4840 - categorical_accuracy: 0.8028 - auc: 0.9580 - precision: 0.8164 - recall: 0.7829 - val_loss: 0.7276 - val_categorical_accuracy: 0.6911 - val_auc: 0.9226 - val_precision: 0.7010 - val_recall: 0.6728
# Epoch 114/500
# 16390/16390 [==============================] - 10s 580us/sample - loss: 0.3895 - categorical_accuracy: 0.8540 - auc: 0.9732 - precision: 0.8720 - recall: 0.8370 - val_loss: 0.5835 - val_categorical_accuracy: 0.7743 - val_auc: 0.9447 - val_precision: 0.7838 - val_recall: 0.7633
# Epoch 115/500
# 16390/16390 [==============================] - 9s 571us/sample - loss: 0.4544 - categorical_accuracy: 0.8131 - auc: 0.9628 - precision: 0.8289 - recall: 0.7954 - val_loss: 0.8180 - val_categorical_accuracy: 0.6337 - val_auc: 0.9119 - val_precision: 0.6457 - val_recall: 0.6191
# Epoch 116/500
# 16390/16390 [==============================] - 9s 561us/sample - loss: 0.4168 - categorical_accuracy: 0.8397 - auc: 0.9691 - precision: 0.8576 - recall: 0.8199 - val_loss: 0.6250 - val_categorical_accuracy: 0.7618 - val_auc: 0.9386 - val_precision: 0.7720 - val_recall: 0.7484
# Epoch 117/500
# 16390/16390 [==============================] - 9s 567us/sample - loss: 0.4074 - categorical_accuracy: 0.8417 - auc: 0.9703 - precision: 0.8586 - recall: 0.8238 - val_loss: 0.7014 - val_categorical_accuracy: 0.7045 - val_auc: 0.9274 - val_precision: 0.7152 - val_recall: 0.6874
# Epoch 118/500
# 16390/16390 [==============================] - 9s 561us/sample - loss: 0.3680 - categorical_accuracy: 0.8666 - auc: 0.9761 - precision: 0.8819 - recall: 0.8482 - val_loss: 0.5846 - val_categorical_accuracy: 0.7733 - val_auc: 0.9454 - val_precision: 0.7809 - val_recall: 0.7653
# Epoch 119/500
# 16390/16390 [==============================] - 9s 575us/sample - loss: 0.4794 - categorical_accuracy: 0.8021 - auc: 0.9589 - precision: 0.8183 - recall: 0.7834 - val_loss: 0.6850 - val_categorical_accuracy: 0.7147 - val_auc: 0.9287 - val_precision: 0.7269 - val_recall: 0.6996
# Epoch 120/500
# 16390/16390 [==============================] - 10s 638us/sample - loss: 0.3736 - categorical_accuracy: 0.8631 - auc: 0.9755 - precision: 0.8772 - recall: 0.8456 - val_loss: 0.5897 - val_categorical_accuracy: 0.7711 - val_auc: 0.9441 - val_precision: 0.7818 - val_recall: 0.7596
# Epoch 121/500
# 16390/16390 [==============================] - 10s 580us/sample - loss: 0.3946 - categorical_accuracy: 0.8450 - auc: 0.9721 - precision: 0.8606 - recall: 0.8281 - val_loss: 0.9399 - val_categorical_accuracy: 0.6144 - val_auc: 0.9062 - val_precision: 0.6223 - val_recall: 0.6030
# Epoch 122/500
# 16390/16390 [==============================] - 9s 571us/sample - loss: 0.4259 - categorical_accuracy: 0.8332 - auc: 0.9671 - precision: 0.8492 - recall: 0.8154 - val_loss: 0.5679 - val_categorical_accuracy: 0.7850 - val_auc: 0.9481 - val_precision: 0.7923 - val_recall: 0.7753
# Epoch 123/500
# 16390/16390 [==============================] - 9s 570us/sample - loss: 0.4152 - categorical_accuracy: 0.8330 - auc: 0.9687 - precision: 0.8476 - recall: 0.8170 - val_loss: 0.7281 - val_categorical_accuracy: 0.7106 - val_auc: 0.9258 - val_precision: 0.7245 - val_recall: 0.6942
# Epoch 124/500
# 16390/16390 [==============================] - 9s 565us/sample - loss: 0.3771 - categorical_accuracy: 0.8591 - auc: 0.9747 - precision: 0.8754 - recall: 0.8421 - val_loss: 0.7037 - val_categorical_accuracy: 0.6986 - val_auc: 0.9268 - val_precision: 0.7096 - val_recall: 0.6923
# Epoch 125/500
# 16390/16390 [==============================] - 10s 580us/sample - loss: 0.4288 - categorical_accuracy: 0.8369 - auc: 0.9673 - precision: 0.8532 - recall: 0.8215 - val_loss: 0.7296 - val_categorical_accuracy: 0.7028 - val_auc: 0.9274 - val_precision: 0.7129 - val_recall: 0.6877
# Epoch 126/500
# 16390/16390 [==============================] - 9s 556us/sample - loss: 0.3532 - categorical_accuracy: 0.8711 - auc: 0.9778 - precision: 0.8840 - recall: 0.8553 - val_loss: 0.5990 - val_categorical_accuracy: 0.7838 - val_auc: 0.9458 - val_precision: 0.7897 - val_recall: 0.7770
# Epoch 127/500
# 16390/16390 [==============================] - 10s 582us/sample - loss: 0.4671 - categorical_accuracy: 0.8045 - auc: 0.9612 - precision: 0.8180 - recall: 0.7874 - val_loss: 0.7457 - val_categorical_accuracy: 0.6847 - val_auc: 0.9232 - val_precision: 0.6948 - val_recall: 0.6698
# Epoch 128/500
# 16390/16390 [==============================] - 10s 595us/sample - loss: 0.3634 - categorical_accuracy: 0.8625 - auc: 0.9764 - precision: 0.8770 - recall: 0.8474 - val_loss: 0.6065 - val_categorical_accuracy: 0.7845 - val_auc: 0.9444 - val_precision: 0.7919 - val_recall: 0.7775
# Epoch 129/500
# 16390/16390 [==============================] - 10s 599us/sample - loss: 0.4070 - categorical_accuracy: 0.8420 - auc: 0.9701 - precision: 0.8537 - recall: 0.8261 - val_loss: 0.6995 - val_categorical_accuracy: 0.7238 - val_auc: 0.9311 - val_precision: 0.7345 - val_recall: 0.7121
# Epoch 130/500
# 16390/16390 [==============================] - 9s 558us/sample - loss: 0.3426 - categorical_accuracy: 0.8750 - auc: 0.9790 - precision: 0.8869 - recall: 0.8598 - val_loss: 0.5915 - val_categorical_accuracy: 0.7845 - val_auc: 0.9459 - val_precision: 0.7936 - val_recall: 0.7777
# Epoch 131/500
# 16390/16390 [==============================] - 9s 552us/sample - loss: 0.3981 - categorical_accuracy: 0.8439 - auc: 0.9713 - precision: 0.8581 - recall: 0.8299 - val_loss: 0.7673 - val_categorical_accuracy: 0.6840 - val_auc: 0.9232 - val_precision: 0.6936 - val_recall: 0.6694
# Epoch 132/500
# 16390/16390 [==============================] - 9s 545us/sample - loss: 0.3478 - categorical_accuracy: 0.8700 - auc: 0.9781 - precision: 0.8822 - recall: 0.8533 - val_loss: 0.6139 - val_categorical_accuracy: 0.7862 - val_auc: 0.9449 - val_precision: 0.7916 - val_recall: 0.7787
# Epoch 133/500
# 16390/16390 [==============================] - 10s 593us/sample - loss: 0.4246 - categorical_accuracy: 0.8284 - auc: 0.9676 - precision: 0.8399 - recall: 0.8149 - val_loss: 0.6360 - val_categorical_accuracy: 0.7477 - val_auc: 0.9393 - val_precision: 0.7568 - val_recall: 0.7350
# Epoch 134/500
# 16390/16390 [==============================] - 9s 572us/sample - loss: 0.3388 - categorical_accuracy: 0.8780 - auc: 0.9792 - precision: 0.8899 - recall: 0.8642 - val_loss: 0.6498 - val_categorical_accuracy: 0.7635 - val_auc: 0.9386 - val_precision: 0.7734 - val_recall: 0.7535
# Epoch 135/500
# 16390/16390 [==============================] - 9s 555us/sample - loss: 0.3693 - categorical_accuracy: 0.8618 - auc: 0.9754 - precision: 0.8751 - recall: 0.8486 - val_loss: 0.7683 - val_categorical_accuracy: 0.6798 - val_auc: 0.9216 - val_precision: 0.6891 - val_recall: 0.6701
# Epoch 136/500
# 16390/16390 [==============================] - 9s 564us/sample - loss: 0.4276 - categorical_accuracy: 0.8392 - auc: 0.9676 - precision: 0.8528 - recall: 0.8248 - val_loss: 0.6316 - val_categorical_accuracy: 0.7562 - val_auc: 0.9408 - val_precision: 0.7695 - val_recall: 0.7438
# Epoch 137/500
# 16390/16390 [==============================] - 9s 558us/sample - loss: 0.3454 - categorical_accuracy: 0.8719 - auc: 0.9783 - precision: 0.8835 - recall: 0.8585 - val_loss: 0.8277 - val_categorical_accuracy: 0.6798 - val_auc: 0.9201 - val_precision: 0.6911 - val_recall: 0.6676
# Epoch 138/500
# 16390/16390 [==============================] - 9s 557us/sample - loss: 0.3674 - categorical_accuracy: 0.8605 - auc: 0.9752 - precision: 0.8732 - recall: 0.8474 - val_loss: 0.6563 - val_categorical_accuracy: 0.7831 - val_auc: 0.9428 - val_precision: 0.7875 - val_recall: 0.7770
# Epoch 139/500
# 16390/16390 [==============================] - 9s 574us/sample - loss: 0.4368 - categorical_accuracy: 0.8260 - auc: 0.9661 - precision: 0.8379 - recall: 0.8136 - val_loss: 0.6378 - val_categorical_accuracy: 0.7560 - val_auc: 0.9397 - val_precision: 0.7637 - val_recall: 0.7462
# Epoch 140/500
# 16390/16390 [==============================] - 9s 571us/sample - loss: 0.3198 - categorical_accuracy: 0.8857 - auc: 0.9817 - precision: 0.8969 - recall: 0.8724 - val_loss: 0.5886 - val_categorical_accuracy: 0.7772 - val_auc: 0.9473 - val_precision: 0.7868 - val_recall: 0.7709
# Epoch 141/500
# 16390/16390 [==============================] - 9s 577us/sample - loss: 0.3474 - categorical_accuracy: 0.8708 - auc: 0.9778 - precision: 0.8817 - recall: 0.8592 - val_loss: 0.7031 - val_categorical_accuracy: 0.7316 - val_auc: 0.9334 - val_precision: 0.7409 - val_recall: 0.7172
# Epoch 142/500
# 16390/16390 [==============================] - 10s 608us/sample - loss: 0.3226 - categorical_accuracy: 0.8860 - auc: 0.9808 - precision: 0.8989 - recall: 0.8736 - val_loss: 0.6298 - val_categorical_accuracy: 0.7862 - val_auc: 0.9456 - val_precision: 0.7888 - val_recall: 0.7811
# Epoch 143/500
# 16390/16390 [==============================] - 10s 593us/sample - loss: 0.4373 - categorical_accuracy: 0.8236 - auc: 0.9661 - precision: 0.8354 - recall: 0.8087 - val_loss: 0.7348 - val_categorical_accuracy: 0.7008 - val_auc: 0.9269 - val_precision: 0.7092 - val_recall: 0.6891
# Epoch 144/500
# 16390/16390 [==============================] - 9s 558us/sample - loss: 0.3636 - categorical_accuracy: 0.8647 - auc: 0.9761 - precision: 0.8787 - recall: 0.8509 - val_loss: 0.6105 - val_categorical_accuracy: 0.7911 - val_auc: 0.9457 - val_precision: 0.7968 - val_recall: 0.7845
# Epoch 145/500
# 16390/16390 [==============================] - 9s 562us/sample - loss: 0.3534 - categorical_accuracy: 0.8675 - auc: 0.9771 - precision: 0.8786 - recall: 0.8540 - val_loss: 0.6940 - val_categorical_accuracy: 0.7335 - val_auc: 0.9337 - val_precision: 0.7447 - val_recall: 0.7223
# Epoch 146/500
# 16390/16390 [==============================] - 9s 579us/sample - loss: 0.3143 - categorical_accuracy: 0.8883 - auc: 0.9820 - precision: 0.8983 - recall: 0.8758 - val_loss: 0.6057 - val_categorical_accuracy: 0.7892 - val_auc: 0.9477 - val_precision: 0.7956 - val_recall: 0.7826
# Epoch 147/500
# 16390/16390 [==============================] - 9s 550us/sample - loss: 0.3941 - categorical_accuracy: 0.8434 - auc: 0.9718 - precision: 0.8571 - recall: 0.8310 - val_loss: 0.6957 - val_categorical_accuracy: 0.7194 - val_auc: 0.9329 - val_precision: 0.7320 - val_recall: 0.7079
# Epoch 148/500
# 16390/16390 [==============================] - 9s 562us/sample - loss: 0.3023 - categorical_accuracy: 0.8927 - auc: 0.9834 - precision: 0.9032 - recall: 0.8809 - val_loss: 0.6141 - val_categorical_accuracy: 0.7897 - val_auc: 0.9465 - val_precision: 0.7975 - val_recall: 0.7833
# Epoch 149/500
# 16390/16390 [==============================] - 9s 568us/sample - loss: 0.3562 - categorical_accuracy: 0.8645 - auc: 0.9769 - precision: 0.8771 - recall: 0.8521 - val_loss: 0.7996 - val_categorical_accuracy: 0.6930 - val_auc: 0.9241 - val_precision: 0.7041 - val_recall: 0.6847
# Epoch 150/500
# 16390/16390 [==============================] - 9s 578us/sample - loss: 0.3556 - categorical_accuracy: 0.8682 - auc: 0.9769 - precision: 0.8786 - recall: 0.8560 - val_loss: 0.6189 - val_categorical_accuracy: 0.7953 - val_auc: 0.9460 - val_precision: 0.8004 - val_recall: 0.7887
# Epoch 151/500
# 16390/16390 [==============================] - 9s 568us/sample - loss: 0.3629 - categorical_accuracy: 0.8585 - auc: 0.9760 - precision: 0.8699 - recall: 0.8465 - val_loss: 0.7266 - val_categorical_accuracy: 0.7308 - val_auc: 0.9313 - val_precision: 0.7390 - val_recall: 0.7160
# Epoch 152/500
# 16390/16390 [==============================] - 10s 580us/sample - loss: 0.3241 - categorical_accuracy: 0.8831 - auc: 0.9807 - precision: 0.8951 - recall: 0.8696 - val_loss: 0.6039 - val_categorical_accuracy: 0.7787 - val_auc: 0.9481 - val_precision: 0.7838 - val_recall: 0.7721
# Epoch 153/500
# 16390/16390 [==============================] - 9s 556us/sample - loss: 0.3710 - categorical_accuracy: 0.8572 - auc: 0.9749 - precision: 0.8686 - recall: 0.8451 - val_loss: 0.6625 - val_categorical_accuracy: 0.7489 - val_auc: 0.9391 - val_precision: 0.7559 - val_recall: 0.7382
# Epoch 154/500
# 16390/16390 [==============================] - 9s 553us/sample - loss: 0.2926 - categorical_accuracy: 0.8924 - auc: 0.9844 - precision: 0.9033 - recall: 0.8815 - val_loss: 0.6948 - val_categorical_accuracy: 0.7809 - val_auc: 0.9394 - val_precision: 0.7879 - val_recall: 0.7767
# Epoch 155/500
# 16390/16390 [==============================] - 9s 550us/sample - loss: 0.4219 - categorical_accuracy: 0.8324 - auc: 0.9686 - precision: 0.8438 - recall: 0.8213 - val_loss: 0.7169 - val_categorical_accuracy: 0.7157 - val_auc: 0.9315 - val_precision: 0.7264 - val_recall: 0.7050
# Epoch 156/500
# 16390/16390 [==============================] - 9s 562us/sample - loss: 0.3158 - categorical_accuracy: 0.8854 - auc: 0.9818 - precision: 0.8963 - recall: 0.8733 - val_loss: 0.5974 - val_categorical_accuracy: 0.7928 - val_auc: 0.9480 - val_precision: 0.7984 - val_recall: 0.7836
# Epoch 157/500
# 16390/16390 [==============================] - 9s 562us/sample - loss: 0.3102 - categorical_accuracy: 0.8877 - auc: 0.9821 - precision: 0.8984 - recall: 0.8760 - val_loss: 0.6847 - val_categorical_accuracy: 0.7448 - val_auc: 0.9375 - val_precision: 0.7566 - val_recall: 0.7367
# Epoch 158/500
# 16390/16390 [==============================] - 9s 564us/sample - loss: 0.2929 - categorical_accuracy: 0.8938 - auc: 0.9842 - precision: 0.9049 - recall: 0.8836 - val_loss: 0.6241 - val_categorical_accuracy: 0.7867 - val_auc: 0.9483 - val_precision: 0.7942 - val_recall: 0.7845
# Epoch 159/500
# 16390/16390 [==============================] - 10s 580us/sample - loss: 0.3877 - categorical_accuracy: 0.8494 - auc: 0.9729 - precision: 0.8597 - recall: 0.8389 - val_loss: 0.6455 - val_categorical_accuracy: 0.7657 - val_auc: 0.9422 - val_precision: 0.7765 - val_recall: 0.7570
# Epoch 160/500
# 16390/16390 [==============================] - 9s 553us/sample - loss: 0.2833 - categorical_accuracy: 0.9003 - auc: 0.9851 - precision: 0.9105 - recall: 0.8891 - val_loss: 0.6025 - val_categorical_accuracy: 0.7772 - val_auc: 0.9481 - val_precision: 0.7846 - val_recall: 0.7699
# Epoch 161/500
# 16390/16390 [==============================] - 9s 558us/sample - loss: 0.2813 - categorical_accuracy: 0.9004 - auc: 0.9853 - precision: 0.9097 - recall: 0.8897 - val_loss: 0.6989 - val_categorical_accuracy: 0.7465 - val_auc: 0.9376 - val_precision: 0.7563 - val_recall: 0.7382
# Epoch 162/500
# 16390/16390 [==============================] - 9s 564us/sample - loss: 0.2816 - categorical_accuracy: 0.9001 - auc: 0.9852 - precision: 0.9090 - recall: 0.8900 - val_loss: 0.6752 - val_categorical_accuracy: 0.7862 - val_auc: 0.9440 - val_precision: 0.7917 - val_recall: 0.7818
# Epoch 163/500
# 16390/16390 [==============================] - 9s 566us/sample - loss: 0.4262 - categorical_accuracy: 0.8296 - auc: 0.9685 - precision: 0.8402 - recall: 0.8194 - val_loss: 0.7973 - val_categorical_accuracy: 0.6984 - val_auc: 0.9257 - val_precision: 0.7084 - val_recall: 0.6877
# Epoch 164/500
# 16390/16390 [==============================] - 9s 556us/sample - loss: 0.3591 - categorical_accuracy: 0.8656 - auc: 0.9766 - precision: 0.8764 - recall: 0.8560 - val_loss: 0.6363 - val_categorical_accuracy: 0.7865 - val_auc: 0.9448 - val_precision: 0.7932 - val_recall: 0.7799
# Epoch 165/500
# ...
# 16390/16390 [==============================] - 9s 563us/sample - loss: 0.0675 - categorical_accuracy: 0.9779 - auc: 0.9986 - precision: 0.9795 - recall: 0.9766 - val_loss: 0.8031 - val_categorical_accuracy: 0.8045 - val_auc: 0.9399 - val_precision: 0.8067 - val_recall: 0.8023
# Epoch 447/500
# 16390/16390 [==============================] - 9s 560us/sample - loss: 0.0654 - categorical_accuracy: 0.9793 - auc: 0.9987 - precision: 0.9804 - recall: 0.9774 - val_loss: 0.8015 - val_categorical_accuracy: 0.8075 - val_auc: 0.9403 - val_precision: 0.8118 - val_recall: 0.8053
# Epoch 448/500
# 16390/16390 [==============================] - 9s 564us/sample - loss: 0.0627 - categorical_accuracy: 0.9796 - auc: 0.9991 - precision: 0.9810 - recall: 0.9782 - val_loss: 0.8222 - val_categorical_accuracy: 0.8082 - val_auc: 0.9381 - val_precision: 0.8111 - val_recall: 0.8060
# Epoch 449/500
# 16390/16390 [==============================] - 9s 557us/sample - loss: 0.0651 - categorical_accuracy: 0.9798 - auc: 0.9987 - precision: 0.9815 - recall: 0.9785 - val_loss: 0.7869 - val_categorical_accuracy: 0.8080 - val_auc: 0.9420 - val_precision: 0.8107 - val_recall: 0.8067
# Epoch 450/500
# 16390/16390 [==============================] - 9s 574us/sample - loss: 0.0672 - categorical_accuracy: 0.9781 - auc: 0.9987 - precision: 0.9800 - recall: 0.9766 - val_loss: 0.7683 - val_categorical_accuracy: 0.8172 - val_auc: 0.9426 - val_precision: 0.8194 - val_recall: 0.8148
# Epoch 451/500
# 16390/16390 [==============================] - 9s 570us/sample - loss: 0.1051 - categorical_accuracy: 0.9637 - auc: 0.9970 - precision: 0.9655 - recall: 0.9622 - val_loss: 1.1623 - val_categorical_accuracy: 0.7352 - val_auc: 0.9013 - val_precision: 0.7375 - val_recall: 0.7323
# Epoch 452/500
# 16390/16390 [==============================] - 9s 565us/sample - loss: 0.1402 - categorical_accuracy: 0.9530 - auc: 0.9952 - precision: 0.9555 - recall: 0.9507 - val_loss: 0.8899 - val_categorical_accuracy: 0.8119 - val_auc: 0.9297 - val_precision: 0.8145 - val_recall: 0.8111
# Epoch 453/500
# 16390/16390 [==============================] - 9s 570us/sample - loss: 0.1855 - categorical_accuracy: 0.9384 - auc: 0.9920 - precision: 0.9411 - recall: 0.9361 - val_loss: 0.8487 - val_categorical_accuracy: 0.7909 - val_auc: 0.9347 - val_precision: 0.7952 - val_recall: 0.7892
# Epoch 454/500
# 16390/16390 [==============================] - 9s 563us/sample - loss: 0.0917 - categorical_accuracy: 0.9701 - auc: 0.9977 - precision: 0.9728 - recall: 0.9684 - val_loss: 0.7966 - val_categorical_accuracy: 0.8080 - val_auc: 0.9392 - val_precision: 0.8111 - val_recall: 0.8067
# Epoch 455/500
# 16390/16390 [==============================] - 9s 564us/sample - loss: 0.0616 - categorical_accuracy: 0.9796 - auc: 0.9990 - precision: 0.9816 - recall: 0.9782 - val_loss: 0.8138 - val_categorical_accuracy: 0.8050 - val_auc: 0.9387 - val_precision: 0.8082 - val_recall: 0.8028
# Epoch 456/500
# 16390/16390 [==============================] - 9s 572us/sample - loss: 0.0622 - categorical_accuracy: 0.9797 - auc: 0.9991 - precision: 0.9816 - recall: 0.9785 - val_loss: 0.8008 - val_categorical_accuracy: 0.8080 - val_auc: 0.9409 - val_precision: 0.8109 - val_recall: 0.8067
# Epoch 457/500
# 16390/16390 [==============================] - 9s 547us/sample - loss: 0.0584 - categorical_accuracy: 0.9805 - auc: 0.9992 - precision: 0.9822 - recall: 0.9791 - val_loss: 0.7857 - val_categorical_accuracy: 0.8148 - val_auc: 0.9397 - val_precision: 0.8170 - val_recall: 0.8138
# Epoch 458/500
# 16390/16390 [==============================] - 9s 561us/sample - loss: 0.0660 - categorical_accuracy: 0.9784 - auc: 0.9989 - precision: 0.9799 - recall: 0.9766 - val_loss: 0.8490 - val_categorical_accuracy: 0.8009 - val_auc: 0.9357 - val_precision: 0.8053 - val_recall: 0.7994
# Epoch 459/500
# 16390/16390 [==============================] - 9s 561us/sample - loss: 0.0881 - categorical_accuracy: 0.9694 - auc: 0.9979 - precision: 0.9717 - recall: 0.9677 - val_loss: 0.8075 - val_categorical_accuracy: 0.8114 - val_auc: 0.9369 - val_precision: 0.8147 - val_recall: 0.8089
# Epoch 460/500
# 16390/16390 [==============================] - 9s 560us/sample - loss: 0.1342 - categorical_accuracy: 0.9538 - auc: 0.9954 - precision: 0.9558 - recall: 0.9516 - val_loss: 0.9422 - val_categorical_accuracy: 0.7689 - val_auc: 0.9266 - val_precision: 0.7732 - val_recall: 0.7670
# Epoch 461/500
# 16390/16390 [==============================] - 9s 567us/sample - loss: 0.0917 - categorical_accuracy: 0.9674 - auc: 0.9981 - precision: 0.9699 - recall: 0.9658 - val_loss: 0.8088 - val_categorical_accuracy: 0.8114 - val_auc: 0.9367 - val_precision: 0.8139 - val_recall: 0.8102
# Epoch 462/500
# 16390/16390 [==============================] - 9s 553us/sample - loss: 0.0705 - categorical_accuracy: 0.9770 - auc: 0.9985 - precision: 0.9787 - recall: 0.9753 - val_loss: 0.7905 - val_categorical_accuracy: 0.8158 - val_auc: 0.9408 - val_precision: 0.8191 - val_recall: 0.8143
# Epoch 463/500
# 16390/16390 [==============================] - 9s 573us/sample - loss: 0.0771 - categorical_accuracy: 0.9739 - auc: 0.9984 - precision: 0.9757 - recall: 0.9727 - val_loss: 0.8287 - val_categorical_accuracy: 0.8011 - val_auc: 0.9382 - val_precision: 0.8044 - val_recall: 0.7989
# Epoch 464/500
# 16390/16390 [==============================] - 9s 565us/sample - loss: 0.0729 - categorical_accuracy: 0.9766 - auc: 0.9985 - precision: 0.9781 - recall: 0.9749 - val_loss: 0.7738 - val_categorical_accuracy: 0.8131 - val_auc: 0.9431 - val_precision: 0.8158 - val_recall: 0.8114
# Epoch 465/500
# 16390/16390 [==============================] - 9s 579us/sample - loss: 0.0751 - categorical_accuracy: 0.9754 - auc: 0.9986 - precision: 0.9772 - recall: 0.9732 - val_loss: 0.8248 - val_categorical_accuracy: 0.8097 - val_auc: 0.9373 - val_precision: 0.8122 - val_recall: 0.8075
# Epoch 466/500
# 16390/16390 [==============================] - 9s 559us/sample - loss: 0.0585 - categorical_accuracy: 0.9818 - auc: 0.9989 - precision: 0.9834 - recall: 0.9802 - val_loss: 0.8363 - val_categorical_accuracy: 0.8055 - val_auc: 0.9348 - val_precision: 0.8087 - val_recall: 0.8023
# Epoch 467/500
# 16390/16390 [==============================] - 9s 561us/sample - loss: 0.0750 - categorical_accuracy: 0.9755 - auc: 0.9985 - precision: 0.9779 - recall: 0.9737 - val_loss: 0.7922 - val_categorical_accuracy: 0.8128 - val_auc: 0.9400 - val_precision: 0.8152 - val_recall: 0.8119
# Epoch 468/500
# 16390/16390 [==============================] - 9s 556us/sample - loss: 0.1757 - categorical_accuracy: 0.9442 - auc: 0.9919 - precision: 0.9466 - recall: 0.9422 - val_loss: 1.1449 - val_categorical_accuracy: 0.7396 - val_auc: 0.9038 - val_precision: 0.7426 - val_recall: 0.7365
# Epoch 469/500
# 16390/16390 [==============================] - 10s 584us/sample - loss: 0.1822 - categorical_accuracy: 0.9406 - auc: 0.9923 - precision: 0.9431 - recall: 0.9384 - val_loss: 0.8134 - val_categorical_accuracy: 0.8148 - val_auc: 0.9375 - val_precision: 0.8198 - val_recall: 0.8136
# Epoch 470/500
# 16390/16390 [==============================] - 9s 570us/sample - loss: 0.0809 - categorical_accuracy: 0.9714 - auc: 0.9982 - precision: 0.9741 - recall: 0.9690 - val_loss: 0.8328 - val_categorical_accuracy: 0.8080 - val_auc: 0.9376 - val_precision: 0.8100 - val_recall: 0.8053
# Epoch 471/500
# 16390/16390 [==============================] - 9s 566us/sample - loss: 0.0570 - categorical_accuracy: 0.9821 - auc: 0.9992 - precision: 0.9836 - recall: 0.9810 - val_loss: 0.8269 - val_categorical_accuracy: 0.8111 - val_auc: 0.9368 - val_precision: 0.8131 - val_recall: 0.8092
# Epoch 472/500
# 16390/16390 [==============================] - 9s 554us/sample - loss: 0.0598 - categorical_accuracy: 0.9807 - auc: 0.9991 - precision: 0.9823 - recall: 0.9791 - val_loss: 0.8014 - val_categorical_accuracy: 0.8138 - val_auc: 0.9413 - val_precision: 0.8142 - val_recall: 0.8104
# Epoch 473/500
# 16390/16390 [==============================] - 9s 555us/sample - loss: 0.0559 - categorical_accuracy: 0.9824 - auc: 0.9992 - precision: 0.9840 - recall: 0.9805 - val_loss: 0.7976 - val_categorical_accuracy: 0.8148 - val_auc: 0.9396 - val_precision: 0.8172 - val_recall: 0.8128
# Epoch 474/500
# 16390/16390 [==============================] - 9s 557us/sample - loss: 0.0600 - categorical_accuracy: 0.9808 - auc: 0.9990 - precision: 0.9821 - recall: 0.9793 - val_loss: 0.8310 - val_categorical_accuracy: 0.8075 - val_auc: 0.9362 - val_precision: 0.8110 - val_recall: 0.8060
# Epoch 475/500
# 16390/16390 [==============================] - 9s 562us/sample - loss: 0.0667 - categorical_accuracy: 0.9787 - auc: 0.9988 - precision: 0.9802 - recall: 0.9772 - val_loss: 0.8515 - val_categorical_accuracy: 0.8009 - val_auc: 0.9345 - val_precision: 0.8033 - val_recall: 0.7994
# Epoch 476/500
# 16390/16390 [==============================] - 10s 583us/sample - loss: 0.0640 - categorical_accuracy: 0.9791 - auc: 0.9986 - precision: 0.9807 - recall: 0.9776 - val_loss: 0.7980 - val_categorical_accuracy: 0.8119 - val_auc: 0.9392 - val_precision: 0.8138 - val_recall: 0.8094
# Epoch 477/500
# 16390/16390 [==============================] - 9s 558us/sample - loss: 0.0822 - categorical_accuracy: 0.9717 - auc: 0.9981 - precision: 0.9733 - recall: 0.9702 - val_loss: 1.1744 - val_categorical_accuracy: 0.7416 - val_auc: 0.8978 - val_precision: 0.7440 - val_recall: 0.7396
# Epoch 478/500
# 16390/16390 [==============================] - 9s 571us/sample - loss: 0.2094 - categorical_accuracy: 0.9334 - auc: 0.9900 - precision: 0.9360 - recall: 0.9317 - val_loss: 0.9729 - val_categorical_accuracy: 0.7960 - val_auc: 0.9218 - val_precision: 0.7979 - val_recall: 0.7948
# Epoch 479/500
# 16390/16390 [==============================] - 9s 554us/sample - loss: 0.1826 - categorical_accuracy: 0.9375 - auc: 0.9922 - precision: 0.9403 - recall: 0.9359 - val_loss: 0.7790 - val_categorical_accuracy: 0.8143 - val_auc: 0.9416 - val_precision: 0.8174 - val_recall: 0.8116
# Epoch 480/500
# 16390/16390 [==============================] - 9s 555us/sample - loss: 0.0682 - categorical_accuracy: 0.9783 - auc: 0.9988 - precision: 0.9805 - recall: 0.9768 - val_loss: 0.8022 - val_categorical_accuracy: 0.8080 - val_auc: 0.9393 - val_precision: 0.8110 - val_recall: 0.8065
# Epoch 481/500
# 16390/16390 [==============================] - 9s 557us/sample - loss: 0.0534 - categorical_accuracy: 0.9832 - auc: 0.9993 - precision: 0.9854 - recall: 0.9817 - val_loss: 0.8056 - val_categorical_accuracy: 0.8087 - val_auc: 0.9402 - val_precision: 0.8111 - val_recall: 0.8067
# Epoch 482/500
# 16390/16390 [==============================] - 10s 584us/sample - loss: 0.0575 - categorical_accuracy: 0.9810 - auc: 0.9991 - precision: 0.9826 - recall: 0.9800 - val_loss: 0.8272 - val_categorical_accuracy: 0.8058 - val_auc: 0.9372 - val_precision: 0.8097 - val_recall: 0.8045
# Epoch 483/500
# 16390/16390 [==============================] - 9s 567us/sample - loss: 0.0598 - categorical_accuracy: 0.9815 - auc: 0.9989 - precision: 0.9833 - recall: 0.9802 - val_loss: 0.8102 - val_categorical_accuracy: 0.8094 - val_auc: 0.9408 - val_precision: 0.8118 - val_recall: 0.8075
# Epoch 484/500
# 16390/16390 [==============================] - 9s 565us/sample - loss: 0.0568 - categorical_accuracy: 0.9810 - auc: 0.9992 - precision: 0.9823 - recall: 0.9797 - val_loss: 0.8321 - val_categorical_accuracy: 0.8111 - val_auc: 0.9363 - val_precision: 0.8132 - val_recall: 0.8082
# Epoch 485/500
# 16390/16390 [==============================] - 9s 572us/sample - loss: 0.0600 - categorical_accuracy: 0.9816 - auc: 0.9988 - precision: 0.9829 - recall: 0.9804 - val_loss: 0.8134 - val_categorical_accuracy: 0.8136 - val_auc: 0.9385 - val_precision: 0.8151 - val_recall: 0.8111
# Epoch 486/500
# 16390/16390 [==============================] - 9s 555us/sample - loss: 0.0694 - categorical_accuracy: 0.9760 - auc: 0.9986 - precision: 0.9772 - recall: 0.9748 - val_loss: 0.8255 - val_categorical_accuracy: 0.8058 - val_auc: 0.9377 - val_precision: 0.8097 - val_recall: 0.8055
# Epoch 487/500
# 16390/16390 [==============================] - 9s 566us/sample - loss: 0.0720 - categorical_accuracy: 0.9772 - auc: 0.9987 - precision: 0.9783 - recall: 0.9760 - val_loss: 0.9966 - val_categorical_accuracy: 0.7709 - val_auc: 0.9207 - val_precision: 0.7742 - val_recall: 0.7689
# Epoch 488/500
# 16390/16390 [==============================] - 9s 575us/sample - loss: 0.1364 - categorical_accuracy: 0.9539 - auc: 0.9954 - precision: 0.9556 - recall: 0.9518 - val_loss: 1.0567 - val_categorical_accuracy: 0.7872 - val_auc: 0.9139 - val_precision: 0.7890 - val_recall: 0.7855
# Epoch 489/500
# 16390/16390 [==============================] - 9s 577us/sample - loss: 0.2267 - categorical_accuracy: 0.9274 - auc: 0.9882 - precision: 0.9298 - recall: 0.9243 - val_loss: 0.8715 - val_categorical_accuracy: 0.7911 - val_auc: 0.9341 - val_precision: 0.7945 - val_recall: 0.7887
# Epoch 490/500
# 16390/16390 [==============================] - 9s 572us/sample - loss: 0.0720 - categorical_accuracy: 0.9760 - auc: 0.9986 - precision: 0.9780 - recall: 0.9744 - val_loss: 0.8167 - val_categorical_accuracy: 0.8023 - val_auc: 0.9393 - val_precision: 0.8056 - val_recall: 0.8011
# Epoch 491/500
# 16390/16390 [==============================] - 9s 563us/sample - loss: 0.0645 - categorical_accuracy: 0.9794 - auc: 0.9988 - precision: 0.9809 - recall: 0.9783 - val_loss: 0.8101 - val_categorical_accuracy: 0.8109 - val_auc: 0.9387 - val_precision: 0.8131 - val_recall: 0.8092
# Epoch 492/500
# 16390/16390 [==============================] - 9s 547us/sample - loss: 0.0551 - categorical_accuracy: 0.9818 - auc: 0.9993 - precision: 0.9832 - recall: 0.9807 - val_loss: 0.8739 - val_categorical_accuracy: 0.8036 - val_auc: 0.9332 - val_precision: 0.8065 - val_recall: 0.8014
# Epoch 493/500
# 16390/16390 [==============================] - 9s 548us/sample - loss: 0.0579 - categorical_accuracy: 0.9813 - auc: 0.9992 - precision: 0.9827 - recall: 0.9794 - val_loss: 0.8077 - val_categorical_accuracy: 0.8128 - val_auc: 0.9397 - val_precision: 0.8148 - val_recall: 0.8114
# Epoch 494/500
# 16390/16390 [==============================] - 9s 562us/sample - loss: 0.0768 - categorical_accuracy: 0.9748 - auc: 0.9980 - precision: 0.9762 - recall: 0.9735 - val_loss: 0.8507 - val_categorical_accuracy: 0.8011 - val_auc: 0.9352 - val_precision: 0.8035 - val_recall: 0.7992
# Epoch 495/500
# 16390/16390 [==============================] - 10s 597us/sample - loss: 0.0638 - categorical_accuracy: 0.9791 - auc: 0.9989 - precision: 0.9807 - recall: 0.9772 - val_loss: 0.8359 - val_categorical_accuracy: 0.8087 - val_auc: 0.9370 - val_precision: 0.8114 - val_recall: 0.8065
# Epoch 496/500
# 16390/16390 [==============================] - 9s 566us/sample - loss: 0.0563 - categorical_accuracy: 0.9829 - auc: 0.9991 - precision: 0.9845 - recall: 0.9818 - val_loss: 0.8340 - val_categorical_accuracy: 0.8121 - val_auc: 0.9374 - val_precision: 0.8133 - val_recall: 0.8099
# Epoch 497/500
# 16390/16390 [==============================] - 9s 561us/sample - loss: 0.0567 - categorical_accuracy: 0.9816 - auc: 0.9990 - precision: 0.9827 - recall: 0.9800 - val_loss: 0.8422 - val_categorical_accuracy: 0.8136 - val_auc: 0.9346 - val_precision: 0.8168 - val_recall: 0.8114
# Epoch 498/500
# 16390/16390 [==============================] - 9s 567us/sample - loss: 0.0596 - categorical_accuracy: 0.9802 - auc: 0.9989 - precision: 0.9817 - recall: 0.9792 - val_loss: 0.8420 - val_categorical_accuracy: 0.8141 - val_auc: 0.9365 - val_precision: 0.8160 - val_recall: 0.8116
# Epoch 499/500
# 16390/16390 [==============================] - 9s 553us/sample - loss: 0.0620 - categorical_accuracy: 0.9793 - auc: 0.9989 - precision: 0.9811 - recall: 0.9779 - val_loss: 0.9706 - val_categorical_accuracy: 0.7823 - val_auc: 0.9230 - val_precision: 0.7843 - val_recall: 0.7789
# Epoch 500/500
# 16390/16390 [==============================] - 9s 553us/sample - loss: 0.1382 - categorical_accuracy: 0.9533 - auc: 0.9949 - precision: 0.9553 - recall: 0.9516 - val_loss: 1.1507 - val_categorical_accuracy: 0.7789 - val_auc: 0.9051 - val_precision: 0.7798 - val_recall: 0.7779

# %% [markdown]
# ### $\textbf{Metrics vs. Training Epoch}$

# %%
# %matplotlib notebook

# Text legend labels for training set curves
train_set_lbl = ('Training Set (' + 
    str(int(100 * (1 - pct_validation))) + '%)');
    
# Text legend labels for validation set curves
val_set_lbl = ('Training Set (' + 
    str(int(100 * (1 - pct_validation))) + '%)');

# New figure
loss_fig = plt.figure(figsize=(9.9,12));

#############
# Loss plot #
#############
ax1 = plt.subplot(5,1,1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Linear grid of training epochs
epochs = arange(0,N_epoch);

# Cross-entropy error (dB) - training set
plt.plot(epochs,10 * log10(
    model.history.history['loss']),
    '.-',c='g',alpha=0.5,
    label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,10 * log10(
    model.history.history['val_loss']),
    '.-',c='k',alpha=0.5,
    label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Cross-Entropy Error vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Error${}_{\varepsilon}$ (dB)',fontsize=14);

# Legend
plt.legend();

#################
# Accuracy plot #
#################
plt.subplot(5,1,2,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['categorical_accuracy'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_categorical_accuracy'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Categorical Accuracy vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Accuracy${}_{\varepsilon}$ ($\times100\%$)',fontsize=14);

# Legend
plt.legend();

##################
# Precision plot #
##################
plt.subplot(5,1,3,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['precision'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_precision'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]); 

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Precision${}_{\varepsilon}$',fontsize=14);

# Legend
plt.legend();

###############
# Recall plot #
###############
plt.subplot(5,1,4,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['recall'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_recall'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Recall vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Recall${}_{\varepsilon}$',fontsize=14);

# Legend
plt.legend();

############
# AUC plot #
############
plt.subplot(5,1,5,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['auc'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_auc'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Area Under ROC Curve vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'AUC${}_{\varepsilon}$',fontsize=14);

# Legend
plt.legend();

# Optimize layout
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="989.7166666666667">

# %% [markdown]
# ### $\textbf{Pass Entire Dataset (i.e., Train }\cup\textbf{ Validation) to Model}$

# %%
# C x 1 class prediction for entire dataset
Y_hat = model.predict(
    X,                        # Input data
    batch_size=N_batch,       # Batch size
);

# Cast 1-hot class labels as ordinal labels
y_hat = argmax(Y_hat,axis=1); # Predictions
y_true = argmax(Y,axis=1);    # Ground truth

# %% [markdown]
# ### $\textbf{Confusion Matrix Using Predictions Output Above}$

# %%
#########################
#    Compute Matrix:    #
#########################

# Use the sklearn confusion matrix function
confusion_mat = confusion_matrix(y_true,y_hat,
    labels=[c for c in range(C)],sample_weight=None);

#########################
#   Confusion Plotter:  # - adapated from online example
#########################

def plot_confusion_matrix(C,classes,normalize=False,
            title='Confusion matrix',cmap=plt.cm.Greens):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    
    # Let epsilon > 0 be small...
    epsilon = 1e-7;
    
    # Normalization of confusion matrix C
    if normalize:
        C = C.astype('float') / (epsilon + C.sum(axis=1)[:, newaxis]);

    # Print the matrix C
    print(C);
    
    # Image representation
    ax = plt.gca();   # <-- grab current axes
    C = flipud(C);    # <-- flip horizontally for visualization
    im = ax.imshow(C,cmap=cmap);
    
    # Colorbar
    colorbar(im);
    
    # Title
    plt.title(title,fontsize=20,weight="bold");
    
    # Tick labels
    tick_marks = arange(len(classes));
    plt.xticks(tick_marks, classes, rotation=45,fontweight="bold");
    
    # Overwrite default y-axis limits
    plt.ylim([-0.5,len(classes)-0.5]);

    # Text labels in tiles (i.e., elements)
    fmt = '.2f' if normalize else 'd'
    thresh = C.max() / 2.
    for i, j in iter_prod(range(C.shape[0]), range(C.shape[1])):
        plt.text(j, i, format(C[i, j], fmt),
                 horizontalalignment="center",weight="bold",
                 color="white" if C[i, j] > thresh else "black")

    # x-axis labels
    plt.ylabel('True label',fontsize=16,weight="bold");
    
    # y-axis labels
    plt.xlabel('Predicted label',fontsize=16,weight="bold");
    
    # Set axis layout
    plt.tight_layout();
    
#########################
#    Scale Colorbar:    # - found this online
#########################

def colorbar(mappable):
    last_axes = plt.gca()
    ax = mappable.axes
    fig = ax.figure
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    cbar = fig.colorbar(mappable, cax=cax)
    plt.sca(last_axes)
    return cbar

#########################
#    Visualization:     #
#########################

conf_fig = plt.figure(figsize=(9.9,9.9));
plot_confusion_matrix(
    confusion_mat, 
    classes=[clss for clss in class_table],
    normalize=True,
    title='Confusion Matrix',
    cmap=plt.cm.Greens);
# Out:
# <img src="data:image/png;base64,..." width="989.7166666666667">
# [[0.99161509 0.00139748 0.00219605 0.00479138]
#  [0.00577617 0.94416366 0.00144404 0.04861613]
#  [0.00650888 0.02149901 0.56548323 0.40650888]
#  [0.00607611 0.01503038 0.00527662 0.97361689]]

# %%
# %matplotlib notebook

from numpy import reshape,dstack,max,min,uint8

plt.figure(figsize=(9.9,20))
W = [w for w in model.weights];

plt.subplot(6,1,1);
IMG = dstack(20*(abs(reshape(W[0].numpy(),(3,M,4*M)))));
IMG = (255*(IMG - min(IMG))/(max(IMG) - min(IMG))).astype(uint8);
plt.imshow(IMG,aspect='equal');

plt.subplot(6,1,2);
plt.imshow(transpose(W[2].numpy()),aspect='equal',cmap='Greys');

plt.subplot(6,1,3);
IMG = (20*(abs(reshape(W[4].numpy(),(16,16,3)))));
IMG = (255*(IMG - min(IMG))/(max(IMG) - min(IMG))).astype(uint8);
plt.imshow(IMG,aspect='equal');
plt.tight_layout();

plt.subplot(6,1,4);
plt.imshow(W[6].numpy(),aspect='equal',cmap='Greys');

plt.subplot(6,1,5);
plt.imshow(W[7].numpy(),aspect='equal',cmap='Greys');

plt.subplot(6,1,6);
plt.imshow(transpose(W[9].numpy()),aspect='equal',cmap='Greys');

plt.tight_layout();
# Out:
# <div id='e7c9ccd9-74e3-4fe3-a0c8-340916e9e906'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-585ce213fe38> in <module>
#       7
#       8 plt.subplot(6,1,1);
# ----> 9 IMG = dstack(20*(abs(reshape(W[0].numpy(),(3,M,4*M)))));
#      10 IMG = (255*(IMG - min(IMG))/(max(IMG) - min(IMG))).astype(uint8);
#      11 plt.imshow(IMG,aspect='equal');
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     299            [5, 6]])
#     300     """
# --> 301     return _wrapfunc(a, 'reshape', newshape, order=order)
#     302
#     303
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      59
#      60     try:
# ---> 61         return bound(*args, **kwds)
#      62     except TypeError:
#      63         # A TypeError occurs if the object does have such a method in its
#
# ValueError: cannot reshape array of size 449307 into shape (3,129,516)

# %%
shape(W[4])
