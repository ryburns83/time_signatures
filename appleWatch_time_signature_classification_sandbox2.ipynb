# %% [markdown]
# ## $\textbf{Inferring Musical Time Signature via Apple Watch Logs of Conductor Wrist Motion}$
#
# $\textbf{Author:}\text{ Ryan Burns}$
#
# ## $\textbf{Inferring Musical Time Signature via Apple Watch Logs of Conductor Wrist Motion}$
#
# $\textbf{Author:}\text{ Ryan Burns}$
#
# $\text{This notebook is dedicated to analysis of componentwise cross-correlation (across IMU sensors) as input feature to deep learning classifiers.}$
#
# $\textbf{Motion Class Labels:}$
#
# $\text{All class labels are defined for a right-handed user. An orchestral conductor varies their baton pattern according to 1 of 4 possible states, }$
# $\text{comprised of 3 time signature classes and a resting class (i.e., cessation of baton motion).}$
#
# $\text{0 }\leftrightarrow [1\enspace0\enspace0\enspace0]\leftrightarrow \text{REST}\Longrightarrow\text{conductor has ceased baton motion (no conducting)}$
#
# $\text{1 }\leftrightarrow [0\enspace1\enspace0\enspace0]\leftrightarrow {2/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{2}{4}}\text{ time signature}$
#
# $\text{2 }\leftrightarrow [0\enspace0\enspace1\enspace0]\leftrightarrow {3/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{3}{4}}\text{ time signature}$
#
# $\text{3 }\leftrightarrow [0\enspace0\enspace0\enspace1]\leftrightarrow {4/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{4}{4}}\text{ time signature}$
#
# $\text{For more information on musical time signatures, visit: }\textit{https://en.wikipedia.org/wiki/Time_signature}.$
#
# ![title](baton_motion.png)
#
# $\text{The baton patterns for each time signature of interest are depicted diagramatically above. We assume a tech enthusiast conductor who desires}$
# $\text{an Apple Watch app/experience for automatic discrimination between the 3 time signatures above, in addition to a catch-all }\textit{at-rest}\text{ state. We }$
# $\text{also assume that this conductor would like automatic time-signature inference to be as tempo-agnostic as possible. Be it }\textit{largo}\text{ or }\textit{prestissimo}\text{,}$
# $\text{we assume that the tempo of the musical composition of question would not fool the ideal baton pattern classifier. As such, while the amount}$
# $\text{of data collected for this analysis is still limited in its size and diversity (i.e., we can assume overfit models), efforts have been made during}$
# $\text{data collection to vary the tempo across each time signature's constituent wrist motion observations. The duration (in seconds or measures)}$
# $\text{of each time signature's wrist motion subsequence is also varied during collection. We create an aggregated dataset of independent concatenated}$
# $\text{collects for supervised learning in the code below.}$
#
# $\textbf{Note On Labeling:}$
#
# $\text{SensorLog labels are recorded in real time using the app's class label buttons for a streaming iPhone. This iPhone logs data concurrently with}$
# $\text{an Apple Watch, which also reports its own class labels. Since toggling of the Apple Watch's class labels using the SensorLog UI on the watch }$
# $\text{face would interfere with data collection of wrist motion, we use the }\textit{iPhone}\text{ to log wrist motion labels. By time-aligning the iPhone and Apple}$
# $\text{Watch streams below (i.e., using POSIX timestamps), we can readily provide wrist motion labels for the Apple Watch motion signals without}$
# $\text{interfering with their trajectory as just described. In short, real-time motion labeling is available through dual stream of Apple Watch }$
# $\text{iPhone data, where the former provides the motion observations of interest and the latter provides a mechanism for real-time motion labeling.}$
#
# $\text{We add Gaussian noise to the input signals to randomly vary input to the network, in addition to applying random dropout to a subset of}$
# $\text{the connections within the network at a fixed probability. The model is trained on a subset of data and validated on the remaining data.}$
#
# $\textbf{Motion Class Labels:}$
#
# $\text{All class labels are defined for a right-handed user. An orchestral conductor varies their baton pattern according to 1 of 4 possible states, }$
# $\text{comprised of 3 time signature classes and a resting class (i.e., cessation of baton motion).}$
#
# $\text{0 }\leftrightarrow [1\enspace0\enspace0\enspace0]\leftrightarrow \text{REST}\Longrightarrow\text{conductor has ceased baton motion (no conducting)}$
#
# $\text{1 }\leftrightarrow [0\enspace1\enspace0\enspace0]\leftrightarrow {2/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{2}{4}}\text{ time signature}$
#
# $\text{2 }\leftrightarrow [0\enspace0\enspace1\enspace0]\leftrightarrow {3/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{3}{4}}\text{ time signature}$
#
# $\text{3 }\leftrightarrow [0\enspace0\enspace0\enspace1]\leftrightarrow {4/4}\Longrightarrow\text{conductor proceeds with baton motion consistent with a }\mathbf{\genfrac{}{}{0pt}{}{4}{4}}\text{ time signature}$
#
# $\text{For more information on musical time signatures, visit: }\textit{https://en.wikipedia.org/wiki/Time_signature}.$
#
# ![title](baton_motion.png)
#
# $\text{The baton patterns for each time signature of interest are depicted diagramatically above. We assume a tech enthusiast conductor who desires}$
# $\text{an Apple Watch app/experience for automatic discrimination between the 3 time signatures above, in addition to a catch-all }\textit{at-rest}\text{ state. We }$
# $\text{also assume that this conductor would like automatic time-signature inference to be as tempo-agnostic as possible. Be it }\textit{largo}\text{ or }\textit{prestissimo}\text{,}$
# $\text{we assume that the tempo of the musical composition of question would not fool the ideal baton pattern classifier. As such, while the amount}$
# $\text{of data collected for this analysis is still limited in its size and diversity (i.e., we can assume overfit models), efforts have been made during}$
# $\text{data collection to vary the tempo across each time signature's constituent wrist motion observations. The duration (in seconds or measures)}$
# $\text{of each time signature's wrist motion subsequence is also varied during collection. We create an aggregated dataset of independent concatenated}$
# $\text{collects for supervised learning in the code below.}$
#
# $\textbf{Note On Labeling:}$
#
# $\text{SensorLog labels are recorded in real time using the app's class label buttons for a streaming iPhone. This iPhone logs data concurrently with}$
# $\text{an Apple Watch, which also reports its own class labels. Since toggling of the Apple Watch's class labels using the SensorLog UI on the watch }$
# $\text{face would interfere with data collection of wrist motion, we use the }\textit{iPhone}\text{ to log wrist motion labels. By time-aligning the iPhone and Apple}$
# $\text{Watch streams below (i.e., using POSIX timestamps), we can readily provide wrist motion labels for the Apple Watch motion signals without}$
# $\text{interfering with their trajectory as just described. In short, real-time motion labeling is available through dual stream of Apple Watch }$
# $\text{iPhone data, where the former provides the motion observations of interest and the latter provides a mechanism for real-time motion labeling.}$

# %% [markdown]
# ### $\textbf{Import Packages}$

# %%
import pandas as pd
from os import getcwd, environ;
from itertools import product as iter_prod;
from matplotlib import pyplot as plt;
from mpl_toolkits.axes_grid1 import make_axes_locatable
from numpy import array, hstack, argmax, ones, zeros, log10;
from numpy import logical_or, logical_not, expand_dims, flip;
from numpy import  abs, arange, shape, newaxis, sum, flipud;
from numpy import nan_to_num, transpose;
from scipy.signal import spectrogram;

from tensorflow.keras.models import Sequential, Model;
from tensorflow.keras.optimizers import RMSprop;
from tensorflow.keras.metrics import CategoricalAccuracy;
from tensorflow.keras.metrics import Precision, Recall, AUC;
from tensorflow.keras.layers import Dropout, LSTM, Dense, Conv2D;
from tensorflow.keras.layers import Activation, Reshape, Conv1D;
from tensorflow.keras.layers import Input, GaussianNoise, ConvLSTM2D;
from sklearn.metrics import confusion_matrix;

from SensorLogUtils import convert_iPhone_units;

environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# ### $\textbf{Class Label Definitions}$

# %%
# Ordinal motion class labels
class_table = pd.DataFrame({
    'REST': {
        'id': 'REST', 
        'description': 'no conducting / baton pattern',
        '1-hot label': [1,0,0,0],
        'ordinal label': 0
    },
    '2/4': {
        'id': '2/4', 
        'description': 'conducting pattern for a 2/4 time signature',
        '1-hot label': [0,1,0,0],
        'ordinal label': 1
    },
    '3/4': {
        'id': '3/4', 
        'description':'conducting pattern for a 3/4 time signature',
        '1-hot label': [0,0,1,0],
        'ordinal label': 2
    },
    '4/4': {
        'id': '4/4', 
        'description':'conducting pattern for a 4/4 time signature',
        '1-hot label': [0,0,0,1],
        'ordinal label': 3
    }
});

# Number of classes
C = 4;

# Print class table
class_table
# Out:
#                                         REST  \
# id                                      REST
# description    no conducting / baton pattern
# 1-hot label                     [1, 0, 0, 0]
# ordinal label                              0
#
#                                                        2/4  \
# id                                                     2/4
# description    conducting pattern for a 2/4 time signature
# 1-hot label                                   [0, 1, 0, 0]
# ordinal label                                            1
#
#                                                        3/4  \
# id                                                     3/4
# description    conducting pattern for a 3/4 time signature
# 1-hot label                                   [0, 0, 1, 0]
# ordinal label                                            2
#
#                                                        4/4
# id                                                     4/4
# description    conducting pattern for a 4/4 time signature
# 1-hot label                                   [0, 0, 0, 1]
# ordinal label                                            3

# %% [markdown]
# ### $\textbf{Specify & Load Dataset}$

# %%
################
# Specify data #
################

# Specify local data storage path
data_path = getcwd() + '/data';

# Collect file string ID
collect_IDs = [
    'time_signatures_collect1',
    'time_signatures_collect2'
];

# Build string filename corresponding to collect_ID
collect_files = [
    (data_path + '/labeled_' + collect_ID + '_appleWatch.csv')
for collect_ID in collect_IDs];

#############
# Load data #
#############

# Load and concatenate dataframes for all
# labeled collects in list collect_IDs
df = pd.concat([pd.read_csv(f, 
    error_bad_lines=False,
    warn_bad_lines=False)
    for f in collect_files
],axis=0,ignore_index=True);

# Data fields (column headers)
fields = [fd for fd in df];

# Length of dataframe
N = len(df); # (samples)

# %% [markdown]
# ### $\textbf{Select IMU Data & 1-Hot Class Labels}$

# %%
# Select input signals
x = nan_to_num(array(df[[
    'accelerometerAccelerationX(m/s^2)',
    'accelerometerAccelerationY(m/s^2)',
    'accelerometerAccelerationZ(m/s^2)',
    'motionRotationRateX(rad/s)',
    'motionRotationRateY(rad/s)',
    'motionRotationRateZ(rad/s)'
]]));

# Define 1-hot labels
y = nan_to_num(array(df[[
    
    # List all class headers in table above
    class_name for class_name in class_table
]]));

# %% [markdown]
# ### $\textbf{Specify Sliding Observation Window Parameters}$

# %%
# Number of raw sensor samples (N)
# and their dimensionality (D)
N, D = shape(x);

# Sliding obs. window length
M = 64; # (samples)

# Step size of obs. window
m = 5;  # (samples)

# Linear grid for sliding observation
# window reflecting window length & step
# size specified above, mapped to raw
# sensor samples n = M, M + m, M + 2m, ...
obs_idx = [n for n in range(M,N,m)];

# %% [markdown]
# ### $\textbf{Define Observations & Class Labels}$

# %%
# Windowed spectrogram observation sequence input to model
# X = array([
#     hstack(tuple(spectrogram(x[(n - M):n,d],
#     window='parzen',fs=100,nperseg=32,nfft=64)[2] 
#     for d in range(D))) for n in obs_idx
# ]);
from numpy import correlate
X = array([transpose([correlate(x[(n - M):n,d1],
    x[(n - M):n,d2],'full') for d1 in range(D) for d2 in range(D)]) for n in obs_idx
]);


# Overwrite N,M,D with new dimensionality
N,M,D = shape(X);

# Ground truth 1-hot window-resolution class labels
Y = array([
    [1 if c == argmax(sum(y[(n - M):n,:],0)) 
    else 0 for c in range(C)] for n in obs_idx]);

# %% [markdown]
# ### $\textbf{Training Parameters}$

# %%
# Fraction of dataset to hold 
# out for model validation
pct_validation = 0.25;

# Total number of obs.
N_obs = len(X);

# Number of training epochs
N_epoch = 500;

# Number of batches
N_batch = int(N_obs / 3);

# %% [markdown]
# ### $\textbf{Define Machine Learning Model}$

# %%
#####################################################
# Define model architecture w/ Keras functional API #
#####################################################

# Input layer - M x D observation window
input_layer = Input((M,D));

# Add Gaussian noise to M x D input
h0 = GaussianNoise(1e-4)(input_layer);
h1 = Conv1D(filters=D,kernel_size=D,
            activation='relu')(h0);
h2 = Reshape((92*36,))(Dense(D,
    activation='tanh')(h1));
h3 = Dropout(0.5)(h2);

# Output layer - C x 1 softmax class activation 
output_layer = Dense(C,activation='softmax')(h3);

# Set up Keras Model() instance
model = Model(
    inputs=input_layer,  # Model inputs
    outputs=output_layer # Model outputs
);

###########################
# Define loss & optimizer #
###########################

# Set RMSprop optimization for 
# speed-of-convergence purposes
opt = RMSprop(
    learning_rate=0.001,
    rho=0.9,
    momentum=0.001,
    epsilon=1e-07,
    name="RMSprop"
);

# Model compilation, using categorical
# cross-entropy error w/ RMSprop
model.compile(
    
    # Error/loss function
    loss='categorical_crossentropy', 
    
    # Use RMSprop
    optimizer=opt,
    
    # List metrics here
    metrics=[
        CategoricalAccuracy(),
        AUC(),
        Precision(),
        Recall()
    ]
);

# Print a summary table
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 127, 36)]         0
# _________________________________________________________________
# gaussian_noise (GaussianNois (None, 127, 36)           0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 92, 36)            46692
# _________________________________________________________________
# dense (Dense)                (None, 92, 36)            1332
# _________________________________________________________________
# reshape (Reshape)            (None, 3312)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 3312)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 13252
# =================================================================
# Total params: 61,276
# Trainable params: 61,276
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### $\textbf{Train Machine Learning Model}$

# %%
# Model training
model.fit(
    
    # Input dataset
    x=X, # windowed observations
    y=Y, # 1-hot motion class labels
    
    # Batch size
    batch_size=N_batch,
    
    # Number of training epochs
    epochs=N_epoch,
    
    # Print progress
    verbose=1,
    
    # Set aside fraction for validation
    validation_split=pct_validation,
    
    # False for time series
    shuffle=False,
    
    # Other misc params
    sample_weight=None,
    validation_freq=1,
    max_queue_size=10,
    
    # Parallelize job across 2 workers
    workers=2,
    use_multiprocessing=True
);
# Out:
# Train on 12321 samples, validate on 4108 samples
# Epoch 1/500
# 12321/12321 [==============================] - 8s 650us/sample - loss: 2.6705 - categorical_accuracy: 0.3649 - auc: 0.6221 - precision: 0.3735 - recall: 0.3404 - val_loss: 1.4761 - val_categorical_accuracy: 0.4572 - val_auc: 0.7611 - val_precision: 0.4737 - val_recall: 0.4406
# Epoch 2/500
# 12321/12321 [==============================] - 6s 475us/sample - loss: 1.9921 - categorical_accuracy: 0.4473 - auc: 0.7184 - precision: 0.4608 - recall: 0.4252 - val_loss: 1.0911 - val_categorical_accuracy: 0.5879 - val_auc: 0.8618 - val_precision: 0.6034 - val_recall: 0.5691
# Epoch 3/500
# 12321/12321 [==============================] - 6s 477us/sample - loss: 1.3088 - categorical_accuracy: 0.5901 - auc: 0.8261 - precision: 0.6085 - recall: 0.5666 - val_loss: 0.8352 - val_categorical_accuracy: 0.6955 - val_auc: 0.8902 - val_precision: 0.7192 - val_recall: 0.6514
# Epoch 4/500
# 12321/12321 [==============================] - 6s 477us/sample - loss: 1.1480 - categorical_accuracy: 0.6086 - auc: 0.8475 - precision: 0.6284 - recall: 0.5793 - val_loss: 0.7472 - val_categorical_accuracy: 0.7249 - val_auc: 0.9145 - val_precision: 0.7452 - val_recall: 0.7084
# Epoch 5/500
# 12321/12321 [==============================] - 6s 491us/sample - loss: 0.9204 - categorical_accuracy: 0.6809 - auc: 0.8902 - precision: 0.7016 - recall: 0.6551 - val_loss: 0.6678 - val_categorical_accuracy: 0.7478 - val_auc: 0.9304 - val_precision: 0.7669 - val_recall: 0.7310
# Epoch 6/500
# 12321/12321 [==============================] - 6s 501us/sample - loss: 0.9712 - categorical_accuracy: 0.6763 - auc: 0.8855 - precision: 0.6971 - recall: 0.6559 - val_loss: 0.7898 - val_categorical_accuracy: 0.7169 - val_auc: 0.9238 - val_precision: 0.7247 - val_recall: 0.7108
# Epoch 7/500
# 12321/12321 [==============================] - 6s 489us/sample - loss: 0.8930 - categorical_accuracy: 0.7091 - auc: 0.9033 - precision: 0.7242 - recall: 0.6932 - val_loss: 0.5829 - val_categorical_accuracy: 0.7814 - val_auc: 0.9465 - val_precision: 0.7964 - val_recall: 0.7685
# Epoch 8/500
# 12321/12321 [==============================] - 6s 494us/sample - loss: 0.8331 - categorical_accuracy: 0.7191 - auc: 0.9103 - precision: 0.7338 - recall: 0.7036 - val_loss: 1.0777 - val_categorical_accuracy: 0.7181 - val_auc: 0.8969 - val_precision: 0.7293 - val_recall: 0.7057
# Epoch 9/500
# 12321/12321 [==============================] - 6s 498us/sample - loss: 0.8854 - categorical_accuracy: 0.7342 - auc: 0.9112 - precision: 0.7469 - recall: 0.7193 - val_loss: 0.5139 - val_categorical_accuracy: 0.8004 - val_auc: 0.9561 - val_precision: 0.8238 - val_recall: 0.7911
# Epoch 10/500
# 12321/12321 [==============================] - 6s 500us/sample - loss: 0.7274 - categorical_accuracy: 0.7408 - auc: 0.9275 - precision: 0.7550 - recall: 0.7275 - val_loss: 0.7544 - val_categorical_accuracy: 0.7566 - val_auc: 0.9345 - val_precision: 0.7642 - val_recall: 0.7495
# Epoch 11/500
# 12321/12321 [==============================] - 6s 504us/sample - loss: 0.7799 - categorical_accuracy: 0.7455 - auc: 0.9251 - precision: 0.7560 - recall: 0.7348 - val_loss: 0.6645 - val_categorical_accuracy: 0.7595 - val_auc: 0.9417 - val_precision: 0.7656 - val_recall: 0.7522
# Epoch 12/500
# 12321/12321 [==============================] - 6s 503us/sample - loss: 0.8833 - categorical_accuracy: 0.7226 - auc: 0.9130 - precision: 0.7333 - recall: 0.7103 - val_loss: 0.7937 - val_categorical_accuracy: 0.7697 - val_auc: 0.9322 - val_precision: 0.7807 - val_recall: 0.7619
# Epoch 13/500
# 12321/12321 [==============================] - 6s 502us/sample - loss: 0.6781 - categorical_accuracy: 0.7862 - auc: 0.9394 - precision: 0.7972 - recall: 0.7758 - val_loss: 0.4513 - val_categorical_accuracy: 0.8442 - val_auc: 0.9650 - val_precision: 0.8546 - val_recall: 0.8315
# Epoch 14/500
# 12321/12321 [==============================] - 6s 501us/sample - loss: 0.5748 - categorical_accuracy: 0.7996 - auc: 0.9514 - precision: 0.8094 - recall: 0.7895 - val_loss: 0.6417 - val_categorical_accuracy: 0.7994 - val_auc: 0.9447 - val_precision: 0.8087 - val_recall: 0.7914
# Epoch 15/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.6600 - categorical_accuracy: 0.7852 - auc: 0.9416 - precision: 0.7934 - recall: 0.7746 - val_loss: 0.6407 - val_categorical_accuracy: 0.7807 - val_auc: 0.9502 - val_precision: 0.7852 - val_recall: 0.7748
# Epoch 16/500
# 12321/12321 [==============================] - 6s 514us/sample - loss: 0.7542 - categorical_accuracy: 0.7622 - auc: 0.9314 - precision: 0.7719 - recall: 0.7529 - val_loss: 0.8129 - val_categorical_accuracy: 0.7675 - val_auc: 0.9359 - val_precision: 0.7716 - val_recall: 0.7641
# Epoch 17/500
# 12321/12321 [==============================] - 6s 513us/sample - loss: 0.6876 - categorical_accuracy: 0.7908 - auc: 0.9410 - precision: 0.7981 - recall: 0.7821 - val_loss: 0.5085 - val_categorical_accuracy: 0.8262 - val_auc: 0.9589 - val_precision: 0.8342 - val_recall: 0.8204
# Epoch 18/500
# 12321/12321 [==============================] - 6s 516us/sample - loss: 0.5775 - categorical_accuracy: 0.8036 - auc: 0.9513 - precision: 0.8119 - recall: 0.7941 - val_loss: 0.5230 - val_categorical_accuracy: 0.8318 - val_auc: 0.9610 - val_precision: 0.8372 - val_recall: 0.8277
# Epoch 19/500
# 12321/12321 [==============================] - 7s 531us/sample - loss: 0.5772 - categorical_accuracy: 0.8102 - auc: 0.9525 - precision: 0.8162 - recall: 0.8005 - val_loss: 0.5389 - val_categorical_accuracy: 0.8096 - val_auc: 0.9584 - val_precision: 0.8152 - val_recall: 0.8040
# Epoch 20/500
# 12321/12321 [==============================] - 7s 538us/sample - loss: 0.5305 - categorical_accuracy: 0.8143 - auc: 0.9576 - precision: 0.8227 - recall: 0.8068 - val_loss: 0.6848 - val_categorical_accuracy: 0.8021 - val_auc: 0.9472 - val_precision: 0.8132 - val_recall: 0.7982
# Epoch 21/500
# 12321/12321 [==============================] - 6s 513us/sample - loss: 0.7339 - categorical_accuracy: 0.7890 - auc: 0.9381 - precision: 0.7936 - recall: 0.7826 - val_loss: 0.5863 - val_categorical_accuracy: 0.8189 - val_auc: 0.9577 - val_precision: 0.8261 - val_recall: 0.8130
# Epoch 22/500
# 12321/12321 [==============================] - 6s 514us/sample - loss: 0.5290 - categorical_accuracy: 0.8249 - auc: 0.9583 - precision: 0.8330 - recall: 0.8173 - val_loss: 0.4887 - val_categorical_accuracy: 0.8362 - val_auc: 0.9633 - val_precision: 0.8460 - val_recall: 0.8306
# Epoch 23/500
# 12321/12321 [==============================] - 6s 526us/sample - loss: 0.5179 - categorical_accuracy: 0.8177 - auc: 0.9595 - precision: 0.8265 - recall: 0.8098 - val_loss: 0.4672 - val_categorical_accuracy: 0.8471 - val_auc: 0.9657 - val_precision: 0.8527 - val_recall: 0.8286
# Epoch 24/500
# 12321/12321 [==============================] - 6s 515us/sample - loss: 0.4927 - categorical_accuracy: 0.8323 - auc: 0.9631 - precision: 0.8396 - recall: 0.8261 - val_loss: 0.6659 - val_categorical_accuracy: 0.8111 - val_auc: 0.9487 - val_precision: 0.8171 - val_recall: 0.8060
# Epoch 25/500
# 12321/12321 [==============================] - 7s 535us/sample - loss: 0.6441 - categorical_accuracy: 0.7990 - auc: 0.9468 - precision: 0.8045 - recall: 0.7938 - val_loss: 0.5828 - val_categorical_accuracy: 0.8087 - val_auc: 0.9560 - val_precision: 0.8151 - val_recall: 0.8038
# Epoch 26/500
# 12321/12321 [==============================] - 6s 515us/sample - loss: 0.5106 - categorical_accuracy: 0.8322 - auc: 0.9612 - precision: 0.8392 - recall: 0.8258 - val_loss: 0.6979 - val_categorical_accuracy: 0.7950 - val_auc: 0.9478 - val_precision: 0.7995 - val_recall: 0.7911
# Epoch 27/500
# 12321/12321 [==============================] - 6s 511us/sample - loss: 0.5320 - categorical_accuracy: 0.8352 - auc: 0.9594 - precision: 0.8399 - recall: 0.8303 - val_loss: 0.4641 - val_categorical_accuracy: 0.8396 - val_auc: 0.9672 - val_precision: 0.8452 - val_recall: 0.8347
# Epoch 28/500
# 12321/12321 [==============================] - 6s 519us/sample - loss: 0.5202 - categorical_accuracy: 0.8214 - auc: 0.9593 - precision: 0.8280 - recall: 0.8131 - val_loss: 0.5029 - val_categorical_accuracy: 0.8345 - val_auc: 0.9625 - val_precision: 0.8419 - val_recall: 0.8281
# Epoch 29/500
# 12321/12321 [==============================] - 6s 518us/sample - loss: 0.5224 - categorical_accuracy: 0.8270 - auc: 0.9608 - precision: 0.8329 - recall: 0.8212 - val_loss: 0.5118 - val_categorical_accuracy: 0.8333 - val_auc: 0.9595 - val_precision: 0.8385 - val_recall: 0.8267
# Epoch 30/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.5597 - categorical_accuracy: 0.8186 - auc: 0.9551 - precision: 0.8246 - recall: 0.8119 - val_loss: 0.7740 - val_categorical_accuracy: 0.7775 - val_auc: 0.9416 - val_precision: 0.7786 - val_recall: 0.7741
# Epoch 31/500
# 12321/12321 [==============================] - 6s 518us/sample - loss: 0.7477 - categorical_accuracy: 0.7680 - auc: 0.9352 - precision: 0.7758 - recall: 0.7609 - val_loss: 0.8770 - val_categorical_accuracy: 0.7775 - val_auc: 0.9350 - val_precision: 0.7829 - val_recall: 0.7741
# Epoch 32/500
# 12321/12321 [==============================] - 6s 518us/sample - loss: 0.7111 - categorical_accuracy: 0.8007 - auc: 0.9430 - precision: 0.8065 - recall: 0.7963 - val_loss: 0.4346 - val_categorical_accuracy: 0.8505 - val_auc: 0.9719 - val_precision: 0.8545 - val_recall: 0.8466
# Epoch 33/500
# 12321/12321 [==============================] - 6s 519us/sample - loss: 0.4264 - categorical_accuracy: 0.8526 - auc: 0.9704 - precision: 0.8576 - recall: 0.8480 - val_loss: 0.4855 - val_categorical_accuracy: 0.8320 - val_auc: 0.9644 - val_precision: 0.8427 - val_recall: 0.8242
# Epoch 34/500
# 12321/12321 [==============================] - 7s 541us/sample - loss: 0.5379 - categorical_accuracy: 0.8214 - auc: 0.9577 - precision: 0.8292 - recall: 0.8140 - val_loss: 0.5795 - val_categorical_accuracy: 0.8165 - val_auc: 0.9578 - val_precision: 0.8311 - val_recall: 0.8133
# Epoch 35/500
# 12321/12321 [==============================] - 6s 521us/sample - loss: 0.5683 - categorical_accuracy: 0.8201 - auc: 0.9574 - precision: 0.8246 - recall: 0.8142 - val_loss: 0.6977 - val_categorical_accuracy: 0.8004 - val_auc: 0.9498 - val_precision: 0.8059 - val_recall: 0.7965
# Epoch 36/500
# 12321/12321 [==============================] - 6s 523us/sample - loss: 0.5676 - categorical_accuracy: 0.8286 - auc: 0.9580 - precision: 0.8340 - recall: 0.8244 - val_loss: 0.6502 - val_categorical_accuracy: 0.8079 - val_auc: 0.9530 - val_precision: 0.8127 - val_recall: 0.8057
# Epoch 37/500
# 12321/12321 [==============================] - 6s 522us/sample - loss: 0.5206 - categorical_accuracy: 0.8296 - auc: 0.9612 - precision: 0.8350 - recall: 0.8244 - val_loss: 0.6051 - val_categorical_accuracy: 0.8223 - val_auc: 0.9555 - val_precision: 0.8271 - val_recall: 0.8199
# Epoch 38/500
# 12321/12321 [==============================] - 6s 523us/sample - loss: 0.5047 - categorical_accuracy: 0.8412 - auc: 0.9632 - precision: 0.8452 - recall: 0.8375 - val_loss: 0.4805 - val_categorical_accuracy: 0.8313 - val_auc: 0.9676 - val_precision: 0.8386 - val_recall: 0.8286
# Epoch 39/500
# 12321/12321 [==============================] - 6s 524us/sample - loss: 0.5241 - categorical_accuracy: 0.8337 - auc: 0.9614 - precision: 0.8374 - recall: 0.8283 - val_loss: 0.5190 - val_categorical_accuracy: 0.8500 - val_auc: 0.9616 - val_precision: 0.8526 - val_recall: 0.8488
# Epoch 40/500
# 12321/12321 [==============================] - 6s 522us/sample - loss: 0.4700 - categorical_accuracy: 0.8442 - auc: 0.9662 - precision: 0.8498 - recall: 0.8388 - val_loss: 0.6398 - val_categorical_accuracy: 0.8118 - val_auc: 0.9527 - val_precision: 0.8154 - val_recall: 0.8062
# Epoch 41/500
# 12321/12321 [==============================] - 6s 519us/sample - loss: 0.5653 - categorical_accuracy: 0.8216 - auc: 0.9566 - precision: 0.8268 - recall: 0.8175 - val_loss: 0.6637 - val_categorical_accuracy: 0.8072 - val_auc: 0.9522 - val_precision: 0.8112 - val_recall: 0.8053
# Epoch 42/500
# 12321/12321 [==============================] - 6s 521us/sample - loss: 0.5624 - categorical_accuracy: 0.8400 - auc: 0.9583 - precision: 0.8439 - recall: 0.8360 - val_loss: 0.5873 - val_categorical_accuracy: 0.8218 - val_auc: 0.9601 - val_precision: 0.8252 - val_recall: 0.8196
# Epoch 43/500
# 12321/12321 [==============================] - 7s 538us/sample - loss: 0.5150 - categorical_accuracy: 0.8352 - auc: 0.9625 - precision: 0.8399 - recall: 0.8313 - val_loss: 0.4528 - val_categorical_accuracy: 0.8608 - val_auc: 0.9697 - val_precision: 0.8635 - val_recall: 0.8595
# Epoch 44/500
# 12321/12321 [==============================] - 6s 524us/sample - loss: 0.4519 - categorical_accuracy: 0.8593 - auc: 0.9683 - precision: 0.8616 - recall: 0.8563 - val_loss: 0.6578 - val_categorical_accuracy: 0.8101 - val_auc: 0.9553 - val_precision: 0.8125 - val_recall: 0.8072
# Epoch 45/500
# 12321/12321 [==============================] - 6s 514us/sample - loss: 0.5131 - categorical_accuracy: 0.8410 - auc: 0.9629 - precision: 0.8450 - recall: 0.8373 - val_loss: 0.6512 - val_categorical_accuracy: 0.8228 - val_auc: 0.9560 - val_precision: 0.8289 - val_recall: 0.8162
# Epoch 46/500
# 12321/12321 [==============================] - 6s 519us/sample - loss: 0.5717 - categorical_accuracy: 0.8321 - auc: 0.9570 - precision: 0.8365 - recall: 0.8275 - val_loss: 0.5737 - val_categorical_accuracy: 0.8247 - val_auc: 0.9645 - val_precision: 0.8276 - val_recall: 0.8225
# Epoch 47/500
# 12321/12321 [==============================] - 6s 518us/sample - loss: 0.4114 - categorical_accuracy: 0.8615 - auc: 0.9730 - precision: 0.8655 - recall: 0.8589 - val_loss: 0.4619 - val_categorical_accuracy: 0.8622 - val_auc: 0.9683 - val_precision: 0.8643 - val_recall: 0.8603
# Epoch 48/500
# 12321/12321 [==============================] - 6s 518us/sample - loss: 0.3936 - categorical_accuracy: 0.8670 - auc: 0.9738 - precision: 0.8702 - recall: 0.8626 - val_loss: 0.6375 - val_categorical_accuracy: 0.8206 - val_auc: 0.9560 - val_precision: 0.8251 - val_recall: 0.8177
# Epoch 49/500
# 12321/12321 [==============================] - 6s 526us/sample - loss: 0.4630 - categorical_accuracy: 0.8505 - auc: 0.9672 - precision: 0.8546 - recall: 0.8478 - val_loss: 0.7777 - val_categorical_accuracy: 0.8045 - val_auc: 0.9406 - val_precision: 0.8073 - val_recall: 0.8014
# Epoch 50/500
# 12321/12321 [==============================] - 6s 521us/sample - loss: 0.6206 - categorical_accuracy: 0.8230 - auc: 0.9530 - precision: 0.8272 - recall: 0.8180 - val_loss: 0.7084 - val_categorical_accuracy: 0.8004 - val_auc: 0.9548 - val_precision: 0.8019 - val_recall: 0.7992
# Epoch 51/500
# 12321/12321 [==============================] - 6s 523us/sample - loss: 0.5177 - categorical_accuracy: 0.8313 - auc: 0.9631 - precision: 0.8360 - recall: 0.8262 - val_loss: 0.6200 - val_categorical_accuracy: 0.8279 - val_auc: 0.9601 - val_precision: 0.8317 - val_recall: 0.8238
# Epoch 52/500
# 12321/12321 [==============================] - 6s 525us/sample - loss: 0.5288 - categorical_accuracy: 0.8456 - auc: 0.9625 - precision: 0.8480 - recall: 0.8425 - val_loss: 0.6004 - val_categorical_accuracy: 0.8238 - val_auc: 0.9612 - val_precision: 0.8260 - val_recall: 0.8225
# Epoch 53/500
# 12321/12321 [==============================] - 7s 552us/sample - loss: 0.4223 - categorical_accuracy: 0.8622 - auc: 0.9718 - precision: 0.8663 - recall: 0.8586 - val_loss: 0.4611 - val_categorical_accuracy: 0.8508 - val_auc: 0.9694 - val_precision: 0.8582 - val_recall: 0.8483
# Epoch 54/500
# 12321/12321 [==============================] - 6s 523us/sample - loss: 0.4442 - categorical_accuracy: 0.8550 - auc: 0.9700 - precision: 0.8589 - recall: 0.8511 - val_loss: 0.6840 - val_categorical_accuracy: 0.8028 - val_auc: 0.9446 - val_precision: 0.8067 - val_recall: 0.7994
# Epoch 55/500
# 12321/12321 [==============================] - 7s 529us/sample - loss: 0.5270 - categorical_accuracy: 0.8279 - auc: 0.9598 - precision: 0.8341 - recall: 0.8195 - val_loss: 0.6156 - val_categorical_accuracy: 0.8242 - val_auc: 0.9583 - val_precision: 0.8297 - val_recall: 0.8206
# Epoch 56/500
# 12321/12321 [==============================] - 6s 524us/sample - loss: 0.5814 - categorical_accuracy: 0.8233 - auc: 0.9569 - precision: 0.8285 - recall: 0.8184 - val_loss: 0.6345 - val_categorical_accuracy: 0.8116 - val_auc: 0.9560 - val_precision: 0.8128 - val_recall: 0.8094
# Epoch 57/500
# 12321/12321 [==============================] - 6s 524us/sample - loss: 0.4507 - categorical_accuracy: 0.8512 - auc: 0.9682 - precision: 0.8567 - recall: 0.8472 - val_loss: 0.4753 - val_categorical_accuracy: 0.8608 - val_auc: 0.9636 - val_precision: 0.8651 - val_recall: 0.8586
# Epoch 58/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.4435 - categorical_accuracy: 0.8517 - auc: 0.9690 - precision: 0.8562 - recall: 0.8454 - val_loss: 0.5564 - val_categorical_accuracy: 0.8264 - val_auc: 0.9616 - val_precision: 0.8289 - val_recall: 0.8242
# Epoch 59/500
# 12321/12321 [==============================] - 6s 523us/sample - loss: 0.4350 - categorical_accuracy: 0.8568 - auc: 0.9704 - precision: 0.8611 - recall: 0.8537 - val_loss: 0.4669 - val_categorical_accuracy: 0.8720 - val_auc: 0.9670 - val_precision: 0.8751 - val_recall: 0.8615
# Epoch 60/500
# 12321/12321 [==============================] - 6s 525us/sample - loss: 0.4621 - categorical_accuracy: 0.8529 - auc: 0.9678 - precision: 0.8574 - recall: 0.8487 - val_loss: 0.6287 - val_categorical_accuracy: 0.8247 - val_auc: 0.9557 - val_precision: 0.8282 - val_recall: 0.8225
# Epoch 61/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.4990 - categorical_accuracy: 0.8445 - auc: 0.9645 - precision: 0.8488 - recall: 0.8405 - val_loss: 0.5015 - val_categorical_accuracy: 0.8576 - val_auc: 0.9635 - val_precision: 0.8615 - val_recall: 0.8552
# Epoch 62/500
# 12321/12321 [==============================] - 7s 544us/sample - loss: 0.4973 - categorical_accuracy: 0.8377 - auc: 0.9629 - precision: 0.8439 - recall: 0.8318 - val_loss: 0.5537 - val_categorical_accuracy: 0.8440 - val_auc: 0.9637 - val_precision: 0.8479 - val_recall: 0.8415
# Epoch 63/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.4635 - categorical_accuracy: 0.8476 - auc: 0.9666 - precision: 0.8528 - recall: 0.8424 - val_loss: 0.4180 - val_categorical_accuracy: 0.8700 - val_auc: 0.9728 - val_precision: 0.8741 - val_recall: 0.8671
# Epoch 64/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.4370 - categorical_accuracy: 0.8526 - auc: 0.9696 - precision: 0.8575 - recall: 0.8469 - val_loss: 0.6306 - val_categorical_accuracy: 0.8126 - val_auc: 0.9567 - val_precision: 0.8156 - val_recall: 0.8106
# Epoch 65/500
# 12321/12321 [==============================] - 6s 526us/sample - loss: 0.4701 - categorical_accuracy: 0.8507 - auc: 0.9666 - precision: 0.8557 - recall: 0.8464 - val_loss: 0.5258 - val_categorical_accuracy: 0.8418 - val_auc: 0.9643 - val_precision: 0.8533 - val_recall: 0.8408
# Epoch 66/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.4659 - categorical_accuracy: 0.8576 - auc: 0.9670 - precision: 0.8607 - recall: 0.8538 - val_loss: 0.5485 - val_categorical_accuracy: 0.8286 - val_auc: 0.9613 - val_precision: 0.8324 - val_recall: 0.8245
# Epoch 67/500
# 12321/12321 [==============================] - 6s 526us/sample - loss: 0.4353 - categorical_accuracy: 0.8560 - auc: 0.9694 - precision: 0.8627 - recall: 0.8509 - val_loss: 0.4424 - val_categorical_accuracy: 0.8639 - val_auc: 0.9708 - val_precision: 0.8668 - val_recall: 0.8615
# Epoch 68/500
# 12321/12321 [==============================] - 6s 523us/sample - loss: 0.4701 - categorical_accuracy: 0.8473 - auc: 0.9661 - precision: 0.8560 - recall: 0.8387 - val_loss: 0.6471 - val_categorical_accuracy: 0.8211 - val_auc: 0.9516 - val_precision: 0.8232 - val_recall: 0.8184
# Epoch 69/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.4547 - categorical_accuracy: 0.8550 - auc: 0.9685 - precision: 0.8592 - recall: 0.8514 - val_loss: 0.5261 - val_categorical_accuracy: 0.8564 - val_auc: 0.9656 - val_precision: 0.8589 - val_recall: 0.8535
# Epoch 70/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.4065 - categorical_accuracy: 0.8669 - auc: 0.9735 - precision: 0.8708 - recall: 0.8647 - val_loss: 0.6266 - val_categorical_accuracy: 0.8281 - val_auc: 0.9501 - val_precision: 0.8314 - val_recall: 0.8238
# Epoch 71/500
# 12321/12321 [==============================] - 7s 545us/sample - loss: 0.4564 - categorical_accuracy: 0.8585 - auc: 0.9673 - precision: 0.8627 - recall: 0.8538 - val_loss: 0.5765 - val_categorical_accuracy: 0.8333 - val_auc: 0.9577 - val_precision: 0.8445 - val_recall: 0.8301
# Epoch 72/500
# 12321/12321 [==============================] - 6s 524us/sample - loss: 0.4415 - categorical_accuracy: 0.8587 - auc: 0.9703 - precision: 0.8630 - recall: 0.8540 - val_loss: 0.6155 - val_categorical_accuracy: 0.8242 - val_auc: 0.9497 - val_precision: 0.8288 - val_recall: 0.8216
# Epoch 73/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.4142 - categorical_accuracy: 0.8586 - auc: 0.9716 - precision: 0.8650 - recall: 0.8531 - val_loss: 0.5477 - val_categorical_accuracy: 0.8464 - val_auc: 0.9606 - val_precision: 0.8527 - val_recall: 0.8425
# Epoch 74/500
# 12321/12321 [==============================] - 6s 526us/sample - loss: 0.4773 - categorical_accuracy: 0.8413 - auc: 0.9669 - precision: 0.8456 - recall: 0.8369 - val_loss: 0.6186 - val_categorical_accuracy: 0.8211 - val_auc: 0.9538 - val_precision: 0.8290 - val_recall: 0.8179
# Epoch 75/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.4227 - categorical_accuracy: 0.8649 - auc: 0.9720 - precision: 0.8689 - recall: 0.8597 - val_loss: 0.5165 - val_categorical_accuracy: 0.8571 - val_auc: 0.9673 - val_precision: 0.8602 - val_recall: 0.8549
# Epoch 76/500
# 12321/12321 [==============================] - 6s 524us/sample - loss: 0.4181 - categorical_accuracy: 0.8667 - auc: 0.9737 - precision: 0.8709 - recall: 0.8623 - val_loss: 0.6751 - val_categorical_accuracy: 0.8225 - val_auc: 0.9539 - val_precision: 0.8251 - val_recall: 0.8208
# Epoch 77/500
# 12321/12321 [==============================] - 7s 529us/sample - loss: 0.4246 - categorical_accuracy: 0.8641 - auc: 0.9723 - precision: 0.8680 - recall: 0.8617 - val_loss: 0.5423 - val_categorical_accuracy: 0.8440 - val_auc: 0.9662 - val_precision: 0.8476 - val_recall: 0.8410
# Epoch 78/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.4238 - categorical_accuracy: 0.8673 - auc: 0.9725 - precision: 0.8709 - recall: 0.8642 - val_loss: 0.6211 - val_categorical_accuracy: 0.8289 - val_auc: 0.9580 - val_precision: 0.8326 - val_recall: 0.8269
# Epoch 79/500
# 12321/12321 [==============================] - 6s 526us/sample - loss: 0.3624 - categorical_accuracy: 0.8763 - auc: 0.9769 - precision: 0.8800 - recall: 0.8726 - val_loss: 0.5570 - val_categorical_accuracy: 0.8432 - val_auc: 0.9638 - val_precision: 0.8465 - val_recall: 0.8406
# Epoch 80/500
# 12321/12321 [==============================] - 7s 542us/sample - loss: 0.3674 - categorical_accuracy: 0.8774 - auc: 0.9770 - precision: 0.8797 - recall: 0.8746 - val_loss: 0.5756 - val_categorical_accuracy: 0.8430 - val_auc: 0.9624 - val_precision: 0.8468 - val_recall: 0.8396
# Epoch 81/500
# 12321/12321 [==============================] - 7s 531us/sample - loss: 0.3659 - categorical_accuracy: 0.8772 - auc: 0.9772 - precision: 0.8796 - recall: 0.8740 - val_loss: 0.6928 - val_categorical_accuracy: 0.8184 - val_auc: 0.9506 - val_precision: 0.8232 - val_recall: 0.8172
# Epoch 82/500
# 12321/12321 [==============================] - 6s 522us/sample - loss: 0.5000 - categorical_accuracy: 0.8436 - auc: 0.9643 - precision: 0.8478 - recall: 0.8397 - val_loss: 0.5782 - val_categorical_accuracy: 0.8442 - val_auc: 0.9597 - val_precision: 0.8454 - val_recall: 0.8415
# Epoch 83/500
# 12321/12321 [==============================] - 6s 525us/sample - loss: 0.3707 - categorical_accuracy: 0.8847 - auc: 0.9771 - precision: 0.8878 - recall: 0.8821 - val_loss: 0.5296 - val_categorical_accuracy: 0.8503 - val_auc: 0.9640 - val_precision: 0.8541 - val_recall: 0.8481
# Epoch 84/500
# 12321/12321 [==============================] - 6s 520us/sample - loss: 0.3744 - categorical_accuracy: 0.8805 - auc: 0.9767 - precision: 0.8830 - recall: 0.8782 - val_loss: 0.5906 - val_categorical_accuracy: 0.8242 - val_auc: 0.9610 - val_precision: 0.8277 - val_recall: 0.8211
# Epoch 85/500
# 12321/12321 [==============================] - 6s 525us/sample - loss: 0.3756 - categorical_accuracy: 0.8731 - auc: 0.9765 - precision: 0.8773 - recall: 0.8701 - val_loss: 0.5654 - val_categorical_accuracy: 0.8554 - val_auc: 0.9551 - val_precision: 0.8607 - val_recall: 0.8527
# Epoch 86/500
# 12321/12321 [==============================] - 6s 524us/sample - loss: 0.4494 - categorical_accuracy: 0.8600 - auc: 0.9691 - precision: 0.8640 - recall: 0.8551 - val_loss: 0.7398 - val_categorical_accuracy: 0.8001 - val_auc: 0.9495 - val_precision: 0.8067 - val_recall: 0.7977
# Epoch 87/500
# 12321/12321 [==============================] - 6s 525us/sample - loss: 0.4167 - categorical_accuracy: 0.8686 - auc: 0.9733 - precision: 0.8727 - recall: 0.8654 - val_loss: 0.4820 - val_categorical_accuracy: 0.8739 - val_auc: 0.9702 - val_precision: 0.8762 - val_recall: 0.8720
# Epoch 88/500
# 12321/12321 [==============================] - 7s 533us/sample - loss: 0.3749 - categorical_accuracy: 0.8779 - auc: 0.9765 - precision: 0.8809 - recall: 0.8748 - val_loss: 0.7161 - val_categorical_accuracy: 0.8062 - val_auc: 0.9537 - val_precision: 0.8086 - val_recall: 0.8033
# Epoch 89/500
# 12321/12321 [==============================] - 6s 523us/sample - loss: 0.3791 - categorical_accuracy: 0.8732 - auc: 0.9760 - precision: 0.8770 - recall: 0.8711 - val_loss: 0.4823 - val_categorical_accuracy: 0.8756 - val_auc: 0.9692 - val_precision: 0.8786 - val_recall: 0.8722
# Epoch 90/500
# 12321/12321 [==============================] - 7s 539us/sample - loss: 0.3771 - categorical_accuracy: 0.8706 - auc: 0.9766 - precision: 0.8740 - recall: 0.8674 - val_loss: 0.7307 - val_categorical_accuracy: 0.8084 - val_auc: 0.9485 - val_precision: 0.8106 - val_recall: 0.8065
# Epoch 91/500
# 12321/12321 [==============================] - 6s 522us/sample - loss: 0.3885 - categorical_accuracy: 0.8751 - auc: 0.9748 - precision: 0.8783 - recall: 0.8719 - val_loss: 0.5384 - val_categorical_accuracy: 0.8496 - val_auc: 0.9659 - val_precision: 0.8507 - val_recall: 0.8464
# Epoch 92/500
# 12321/12321 [==============================] - 6s 522us/sample - loss: 0.4766 - categorical_accuracy: 0.8521 - auc: 0.9676 - precision: 0.8564 - recall: 0.8494 - val_loss: 0.5864 - val_categorical_accuracy: 0.8274 - val_auc: 0.9605 - val_precision: 0.8293 - val_recall: 0.8252
# Epoch 93/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.4117 - categorical_accuracy: 0.8686 - auc: 0.9732 - precision: 0.8720 - recall: 0.8653 - val_loss: 0.4938 - val_categorical_accuracy: 0.8639 - val_auc: 0.9671 - val_precision: 0.8671 - val_recall: 0.8627
# Epoch 94/500
# 12321/12321 [==============================] - 6s 522us/sample - loss: 0.3956 - categorical_accuracy: 0.8766 - auc: 0.9750 - precision: 0.8796 - recall: 0.8739 - val_loss: 0.5862 - val_categorical_accuracy: 0.8340 - val_auc: 0.9589 - val_precision: 0.8369 - val_recall: 0.8308
# Epoch 95/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.3304 - categorical_accuracy: 0.8861 - auc: 0.9804 - precision: 0.8900 - recall: 0.8824 - val_loss: 0.4520 - val_categorical_accuracy: 0.8676 - val_auc: 0.9698 - val_precision: 0.8698 - val_recall: 0.8649
# Epoch 96/500
# 12321/12321 [==============================] - 6s 522us/sample - loss: 0.3579 - categorical_accuracy: 0.8753 - auc: 0.9778 - precision: 0.8806 - recall: 0.8718 - val_loss: 0.6412 - val_categorical_accuracy: 0.8272 - val_auc: 0.9578 - val_precision: 0.8310 - val_recall: 0.8257
# Epoch 97/500
# 12321/12321 [==============================] - 6s 526us/sample - loss: 0.3982 - categorical_accuracy: 0.8697 - auc: 0.9749 - precision: 0.8744 - recall: 0.8658 - val_loss: 0.4778 - val_categorical_accuracy: 0.8705 - val_auc: 0.9701 - val_precision: 0.8811 - val_recall: 0.8673
# Epoch 98/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.4243 - categorical_accuracy: 0.8651 - auc: 0.9728 - precision: 0.8680 - recall: 0.8620 - val_loss: 0.6611 - val_categorical_accuracy: 0.8079 - val_auc: 0.9576 - val_precision: 0.8145 - val_recall: 0.8072
# Epoch 99/500
# 12321/12321 [==============================] - 7s 545us/sample - loss: 0.3934 - categorical_accuracy: 0.8728 - auc: 0.9754 - precision: 0.8763 - recall: 0.8701 - val_loss: 0.5695 - val_categorical_accuracy: 0.8391 - val_auc: 0.9616 - val_precision: 0.8417 - val_recall: 0.8376
# Epoch 100/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.4579 - categorical_accuracy: 0.8627 - auc: 0.9693 - precision: 0.8666 - recall: 0.8596 - val_loss: 0.5512 - val_categorical_accuracy: 0.8403 - val_auc: 0.9631 - val_precision: 0.8422 - val_recall: 0.8379
# Epoch 101/500
# 12321/12321 [==============================] - 6s 524us/sample - loss: 0.3699 - categorical_accuracy: 0.8748 - auc: 0.9767 - precision: 0.8806 - recall: 0.8698 - val_loss: 0.4278 - val_categorical_accuracy: 0.8734 - val_auc: 0.9735 - val_precision: 0.8803 - val_recall: 0.8698
# Epoch 102/500
# 12321/12321 [==============================] - 6s 525us/sample - loss: 0.3248 - categorical_accuracy: 0.8869 - auc: 0.9807 - precision: 0.8913 - recall: 0.8844 - val_loss: 0.5989 - val_categorical_accuracy: 0.8308 - val_auc: 0.9606 - val_precision: 0.8330 - val_recall: 0.8259
# Epoch 103/500
# 12321/12321 [==============================] - 6s 524us/sample - loss: 0.3916 - categorical_accuracy: 0.8748 - auc: 0.9746 - precision: 0.8775 - recall: 0.8718 - val_loss: 0.4505 - val_categorical_accuracy: 0.8783 - val_auc: 0.9717 - val_precision: 0.8800 - val_recall: 0.8751
# Epoch 104/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.3716 - categorical_accuracy: 0.8786 - auc: 0.9768 - precision: 0.8818 - recall: 0.8752 - val_loss: 0.6259 - val_categorical_accuracy: 0.8274 - val_auc: 0.9545 - val_precision: 0.8301 - val_recall: 0.8245
# Epoch 105/500
# 12321/12321 [==============================] - 7s 529us/sample - loss: 0.3467 - categorical_accuracy: 0.8814 - auc: 0.9789 - precision: 0.8849 - recall: 0.8783 - val_loss: 0.4440 - val_categorical_accuracy: 0.8617 - val_auc: 0.9707 - val_precision: 0.8648 - val_recall: 0.8566
# Epoch 106/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.2872 - categorical_accuracy: 0.9003 - auc: 0.9841 - precision: 0.9035 - recall: 0.8971 - val_loss: 0.5265 - val_categorical_accuracy: 0.8391 - val_auc: 0.9652 - val_precision: 0.8421 - val_recall: 0.8386
# Epoch 107/500
# 12321/12321 [==============================] - 6s 527us/sample - loss: 0.3389 - categorical_accuracy: 0.8832 - auc: 0.9799 - precision: 0.8859 - recall: 0.8805 - val_loss: 0.6813 - val_categorical_accuracy: 0.8077 - val_auc: 0.9484 - val_precision: 0.8098 - val_recall: 0.8072
# Epoch 108/500
# 12321/12321 [==============================] - 7s 552us/sample - loss: 0.4473 - categorical_accuracy: 0.8563 - auc: 0.9695 - precision: 0.8617 - recall: 0.8520 - val_loss: 0.5482 - val_categorical_accuracy: 0.8474 - val_auc: 0.9642 - val_precision: 0.8599 - val_recall: 0.8444
# Epoch 109/500
# 12321/12321 [==============================] - 7s 539us/sample - loss: 0.4116 - categorical_accuracy: 0.8685 - auc: 0.9743 - precision: 0.8715 - recall: 0.8657 - val_loss: 0.5690 - val_categorical_accuracy: 0.8437 - val_auc: 0.9635 - val_precision: 0.8452 - val_recall: 0.8410
# Epoch 110/500
# 12321/12321 [==============================] - 7s 528us/sample - loss: 0.3329 - categorical_accuracy: 0.8882 - auc: 0.9805 - precision: 0.8902 - recall: 0.8869 - val_loss: 0.4901 - val_categorical_accuracy: 0.8617 - val_auc: 0.9685 - val_precision: 0.8674 - val_recall: 0.8600
# Epoch 111/500
# 12321/12321 [==============================] - 7s 549us/sample - loss: 0.3577 - categorical_accuracy: 0.8860 - auc: 0.9788 - precision: 0.8884 - recall: 0.8836 - val_loss: 0.5074 - val_categorical_accuracy: 0.8569 - val_auc: 0.9662 - val_precision: 0.8591 - val_recall: 0.8547
# Epoch 112/500
# 12321/12321 [==============================] - 6s 519us/sample - loss: 0.3111 - categorical_accuracy: 0.8934 - auc: 0.9825 - precision: 0.8953 - recall: 0.8908 - val_loss: 0.4085 - val_categorical_accuracy: 0.8817 - val_auc: 0.9738 - val_precision: 0.8858 - val_recall: 0.8800
# Epoch 113/500
# 12321/12321 [==============================] - 6s 519us/sample - loss: 0.3070 - categorical_accuracy: 0.8905 - auc: 0.9830 - precision: 0.8933 - recall: 0.8877 - val_loss: 0.6006 - val_categorical_accuracy: 0.8262 - val_auc: 0.9609 - val_precision: 0.8290 - val_recall: 0.8238
# Epoch 114/500
# 12321/12321 [==============================] - 6s 515us/sample - loss: 0.3584 - categorical_accuracy: 0.8774 - auc: 0.9779 - precision: 0.8801 - recall: 0.8731 - val_loss: 0.4618 - val_categorical_accuracy: 0.8678 - val_auc: 0.9715 - val_precision: 0.8763 - val_recall: 0.8591
# Epoch 115/500
# 12321/12321 [==============================] - 6s 514us/sample - loss: 0.3413 - categorical_accuracy: 0.8888 - auc: 0.9789 - precision: 0.8913 - recall: 0.8856 - val_loss: 0.6170 - val_categorical_accuracy: 0.8274 - val_auc: 0.9605 - val_precision: 0.8294 - val_recall: 0.8262
# Epoch 116/500
# 12321/12321 [==============================] - 6s 513us/sample - loss: 0.3291 - categorical_accuracy: 0.8865 - auc: 0.9807 - precision: 0.8893 - recall: 0.8845 - val_loss: 0.4101 - val_categorical_accuracy: 0.8807 - val_auc: 0.9749 - val_precision: 0.8848 - val_recall: 0.8768
# Epoch 117/500
# 12321/12321 [==============================] - 7s 532us/sample - loss: 0.3139 - categorical_accuracy: 0.8964 - auc: 0.9821 - precision: 0.9002 - recall: 0.8935 - val_loss: 0.5712 - val_categorical_accuracy: 0.8267 - val_auc: 0.9606 - val_precision: 0.8290 - val_recall: 0.8250
# Epoch 118/500
# 12321/12321 [==============================] - 6s 511us/sample - loss: 0.3444 - categorical_accuracy: 0.8800 - auc: 0.9801 - precision: 0.8835 - recall: 0.8774 - val_loss: 0.6132 - val_categorical_accuracy: 0.8449 - val_auc: 0.9611 - val_precision: 0.8466 - val_recall: 0.8437
# Epoch 119/500
# 12321/12321 [==============================] - 6s 509us/sample - loss: 0.4550 - categorical_accuracy: 0.8567 - auc: 0.9721 - precision: 0.8585 - recall: 0.8550 - val_loss: 0.5806 - val_categorical_accuracy: 0.8318 - val_auc: 0.9646 - val_precision: 0.8346 - val_recall: 0.8306
# Epoch 120/500
# 12321/12321 [==============================] - 6s 507us/sample - loss: 0.3072 - categorical_accuracy: 0.8985 - auc: 0.9826 - precision: 0.9000 - recall: 0.8968 - val_loss: 0.4136 - val_categorical_accuracy: 0.8880 - val_auc: 0.9733 - val_precision: 0.8914 - val_recall: 0.8870
# Epoch 121/500
# 12321/12321 [==============================] - 6s 500us/sample - loss: 0.3140 - categorical_accuracy: 0.8889 - auc: 0.9823 - precision: 0.8918 - recall: 0.8874 - val_loss: 0.6227 - val_categorical_accuracy: 0.8301 - val_auc: 0.9607 - val_precision: 0.8327 - val_recall: 0.8213
# Epoch 122/500
# 12321/12321 [==============================] - 6s 502us/sample - loss: 0.3287 - categorical_accuracy: 0.8873 - auc: 0.9810 - precision: 0.8898 - recall: 0.8856 - val_loss: 0.4572 - val_categorical_accuracy: 0.8793 - val_auc: 0.9705 - val_precision: 0.8826 - val_recall: 0.8780
# Epoch 123/500
# 12321/12321 [==============================] - 6s 505us/sample - loss: 0.3437 - categorical_accuracy: 0.8813 - auc: 0.9803 - precision: 0.8840 - recall: 0.8787 - val_loss: 0.6896 - val_categorical_accuracy: 0.8291 - val_auc: 0.9572 - val_precision: 0.8346 - val_recall: 0.8240
# Epoch 124/500
# 12321/12321 [==============================] - 6s 500us/sample - loss: 0.3780 - categorical_accuracy: 0.8817 - auc: 0.9773 - precision: 0.8844 - recall: 0.8799 - val_loss: 0.5109 - val_categorical_accuracy: 0.8651 - val_auc: 0.9691 - val_precision: 0.8700 - val_recall: 0.8586
# Epoch 125/500
# 12321/12321 [==============================] - 6s 499us/sample - loss: 0.3450 - categorical_accuracy: 0.8878 - auc: 0.9800 - precision: 0.8895 - recall: 0.8856 - val_loss: 0.5882 - val_categorical_accuracy: 0.8401 - val_auc: 0.9627 - val_precision: 0.8423 - val_recall: 0.8386
# Epoch 126/500
# 12321/12321 [==============================] - 6s 501us/sample - loss: 0.3028 - categorical_accuracy: 0.9000 - auc: 0.9835 - precision: 0.9016 - recall: 0.8986 - val_loss: 0.4472 - val_categorical_accuracy: 0.8734 - val_auc: 0.9717 - val_precision: 0.8768 - val_recall: 0.8695
# Epoch 127/500
# 12321/12321 [==============================] - 6s 520us/sample - loss: 0.2781 - categorical_accuracy: 0.8994 - auc: 0.9856 - precision: 0.9011 - recall: 0.8963 - val_loss: 0.5948 - val_categorical_accuracy: 0.8269 - val_auc: 0.9583 - val_precision: 0.8272 - val_recall: 0.8250
# Epoch 128/500
# 12321/12321 [==============================] - 6s 500us/sample - loss: 0.4071 - categorical_accuracy: 0.8580 - auc: 0.9743 - precision: 0.8634 - recall: 0.8545 - val_loss: 0.4949 - val_categorical_accuracy: 0.8627 - val_auc: 0.9671 - val_precision: 0.8663 - val_recall: 0.8612
# Epoch 129/500
# 12321/12321 [==============================] - 6s 500us/sample - loss: 0.3384 - categorical_accuracy: 0.8900 - auc: 0.9800 - precision: 0.8924 - recall: 0.8883 - val_loss: 0.4908 - val_categorical_accuracy: 0.8508 - val_auc: 0.9702 - val_precision: 0.8526 - val_recall: 0.8488
# Epoch 130/500
# 12321/12321 [==============================] - 6s 501us/sample - loss: 0.2914 - categorical_accuracy: 0.8995 - auc: 0.9838 - precision: 0.9010 - recall: 0.8978 - val_loss: 0.4759 - val_categorical_accuracy: 0.8700 - val_auc: 0.9663 - val_precision: 0.8720 - val_recall: 0.8690
# Epoch 131/500
# 12321/12321 [==============================] - 6s 498us/sample - loss: 0.3331 - categorical_accuracy: 0.8840 - auc: 0.9810 - precision: 0.8868 - recall: 0.8814 - val_loss: 0.5440 - val_categorical_accuracy: 0.8493 - val_auc: 0.9679 - val_precision: 0.8513 - val_recall: 0.8474
# Epoch 132/500
# 12321/12321 [==============================] - 6s 500us/sample - loss: 0.3365 - categorical_accuracy: 0.8947 - auc: 0.9809 - precision: 0.8959 - recall: 0.8927 - val_loss: 0.5398 - val_categorical_accuracy: 0.8688 - val_auc: 0.9639 - val_precision: 0.8715 - val_recall: 0.8668
# Epoch 133/500
# 12321/12321 [==============================] - 6s 500us/sample - loss: 0.3513 - categorical_accuracy: 0.8941 - auc: 0.9794 - precision: 0.8954 - recall: 0.8929 - val_loss: 0.6255 - val_categorical_accuracy: 0.8374 - val_auc: 0.9612 - val_precision: 0.8399 - val_recall: 0.8367
# Epoch 134/500
# 12321/12321 [==============================] - 6s 495us/sample - loss: 0.3224 - categorical_accuracy: 0.8953 - auc: 0.9809 - precision: 0.8971 - recall: 0.8930 - val_loss: 0.4363 - val_categorical_accuracy: 0.8888 - val_auc: 0.9704 - val_precision: 0.8921 - val_recall: 0.8858
# Epoch 135/500
# 12321/12321 [==============================] - 6s 497us/sample - loss: 0.2860 - categorical_accuracy: 0.9023 - auc: 0.9845 - precision: 0.9045 - recall: 0.9003 - val_loss: 0.6271 - val_categorical_accuracy: 0.8444 - val_auc: 0.9607 - val_precision: 0.8465 - val_recall: 0.8418
# Epoch 136/500
# 12321/12321 [==============================] - 6s 508us/sample - loss: 0.3283 - categorical_accuracy: 0.8890 - auc: 0.9813 - precision: 0.8911 - recall: 0.8870 - val_loss: 0.4144 - val_categorical_accuracy: 0.8851 - val_auc: 0.9758 - val_precision: 0.8890 - val_recall: 0.8829
# Epoch 137/500
# 12321/12321 [==============================] - 6s 515us/sample - loss: 0.3490 - categorical_accuracy: 0.8830 - auc: 0.9798 - precision: 0.8867 - recall: 0.8807 - val_loss: 0.5398 - val_categorical_accuracy: 0.8423 - val_auc: 0.9648 - val_precision: 0.8481 - val_recall: 0.8398
# Epoch 138/500
# 12321/12321 [==============================] - 6s 507us/sample - loss: 0.3316 - categorical_accuracy: 0.8901 - auc: 0.9808 - precision: 0.8935 - recall: 0.8876 - val_loss: 0.5536 - val_categorical_accuracy: 0.8508 - val_auc: 0.9651 - val_precision: 0.8533 - val_recall: 0.8493
# Epoch 139/500
# 12321/12321 [==============================] - 6s 495us/sample - loss: 0.3720 - categorical_accuracy: 0.8779 - auc: 0.9777 - precision: 0.8801 - recall: 0.8761 - val_loss: 0.5132 - val_categorical_accuracy: 0.8756 - val_auc: 0.9680 - val_precision: 0.8777 - val_recall: 0.8737
# Epoch 140/500
# 12321/12321 [==============================] - 6s 497us/sample - loss: 0.3610 - categorical_accuracy: 0.8815 - auc: 0.9790 - precision: 0.8835 - recall: 0.8793 - val_loss: 0.5343 - val_categorical_accuracy: 0.8549 - val_auc: 0.9663 - val_precision: 0.8568 - val_recall: 0.8532
# Epoch 141/500
# 12321/12321 [==============================] - 6s 501us/sample - loss: 0.2973 - categorical_accuracy: 0.9047 - auc: 0.9837 - precision: 0.9060 - recall: 0.9037 - val_loss: 0.4466 - val_categorical_accuracy: 0.8839 - val_auc: 0.9720 - val_precision: 0.8870 - val_recall: 0.8827
# Epoch 142/500
# 12321/12321 [==============================] - 6s 500us/sample - loss: 0.3156 - categorical_accuracy: 0.8944 - auc: 0.9823 - precision: 0.8968 - recall: 0.8926 - val_loss: 0.5429 - val_categorical_accuracy: 0.8530 - val_auc: 0.9662 - val_precision: 0.8545 - val_recall: 0.8508
# Epoch 143/500
# 12321/12321 [==============================] - 6s 498us/sample - loss: 0.2926 - categorical_accuracy: 0.9050 - auc: 0.9842 - precision: 0.9070 - recall: 0.9029 - val_loss: 0.4150 - val_categorical_accuracy: 0.8878 - val_auc: 0.9749 - val_precision: 0.8895 - val_recall: 0.8861
# Epoch 144/500
# 12321/12321 [==============================] - 6s 495us/sample - loss: 0.3144 - categorical_accuracy: 0.8937 - auc: 0.9819 - precision: 0.8958 - recall: 0.8920 - val_loss: 0.6141 - val_categorical_accuracy: 0.8308 - val_auc: 0.9595 - val_precision: 0.8344 - val_recall: 0.8291
# Epoch 145/500
# 12321/12321 [==============================] - 6s 497us/sample - loss: 0.3152 - categorical_accuracy: 0.8990 - auc: 0.9813 - precision: 0.9017 - recall: 0.8964 - val_loss: 0.4498 - val_categorical_accuracy: 0.8841 - val_auc: 0.9722 - val_precision: 0.8853 - val_recall: 0.8829
# Epoch 146/500
# 12321/12321 [==============================] - 6s 519us/sample - loss: 0.3026 - categorical_accuracy: 0.8975 - auc: 0.9832 - precision: 0.8992 - recall: 0.8959 - val_loss: 0.5205 - val_categorical_accuracy: 0.8503 - val_auc: 0.9656 - val_precision: 0.8532 - val_recall: 0.8491
# Epoch 147/500
# 12321/12321 [==============================] - 6s 499us/sample - loss: 0.2844 - categorical_accuracy: 0.9022 - auc: 0.9841 - precision: 0.9052 - recall: 0.9005 - val_loss: 0.4810 - val_categorical_accuracy: 0.8751 - val_auc: 0.9676 - val_precision: 0.8768 - val_recall: 0.8729
# Epoch 148/500
# 12321/12321 [==============================] - 6s 496us/sample - loss: 0.3000 - categorical_accuracy: 0.8982 - auc: 0.9838 - precision: 0.9005 - recall: 0.8967 - val_loss: 0.5569 - val_categorical_accuracy: 0.8544 - val_auc: 0.9625 - val_precision: 0.8566 - val_recall: 0.8535
# Epoch 149/500
# 12321/12321 [==============================] - 6s 496us/sample - loss: 0.3104 - categorical_accuracy: 0.8929 - auc: 0.9823 - precision: 0.8953 - recall: 0.8911 - val_loss: 0.4964 - val_categorical_accuracy: 0.8673 - val_auc: 0.9692 - val_precision: 0.8690 - val_recall: 0.8642
# Epoch 150/500
# 12321/12321 [==============================] - 6s 497us/sample - loss: 0.3720 - categorical_accuracy: 0.8767 - auc: 0.9780 - precision: 0.8796 - recall: 0.8747 - val_loss: 0.5580 - val_categorical_accuracy: 0.8352 - val_auc: 0.9621 - val_precision: 0.8415 - val_recall: 0.8320
# Epoch 151/500
# 12321/12321 [==============================] - 6s 494us/sample - loss: 0.3065 - categorical_accuracy: 0.8951 - auc: 0.9828 - precision: 0.8992 - recall: 0.8930 - val_loss: 0.4432 - val_categorical_accuracy: 0.8841 - val_auc: 0.9717 - val_precision: 0.8879 - val_recall: 0.8827
# Epoch 152/500
# 12321/12321 [==============================] - 6s 497us/sample - loss: 0.3156 - categorical_accuracy: 0.8968 - auc: 0.9825 - precision: 0.9001 - recall: 0.8948 - val_loss: 0.7016 - val_categorical_accuracy: 0.8138 - val_auc: 0.9532 - val_precision: 0.8253 - val_recall: 0.8121
# Epoch 153/500
# 12321/12321 [==============================] - 6s 497us/sample - loss: 0.3398 - categorical_accuracy: 0.8918 - auc: 0.9799 - precision: 0.8934 - recall: 0.8907 - val_loss: 0.4775 - val_categorical_accuracy: 0.8651 - val_auc: 0.9677 - val_precision: 0.8735 - val_recall: 0.8608
# Epoch 154/500
# 12321/12321 [==============================] - 6s 498us/sample - loss: 0.3314 - categorical_accuracy: 0.8903 - auc: 0.9800 - precision: 0.8921 - recall: 0.8878 - val_loss: 0.6664 - val_categorical_accuracy: 0.8186 - val_auc: 0.9559 - val_precision: 0.8286 - val_recall: 0.8169
# Epoch 155/500
# 12321/12321 [==============================] - 6s 501us/sample - loss: 0.3532 - categorical_accuracy: 0.8787 - auc: 0.9790 - precision: 0.8817 - recall: 0.8758 - val_loss: 0.4770 - val_categorical_accuracy: 0.8715 - val_auc: 0.9695 - val_precision: 0.8748 - val_recall: 0.8705
# Epoch 156/500
# 12321/12321 [==============================] - 6s 512us/sample - loss: 0.2819 - categorical_accuracy: 0.9001 - auc: 0.9848 - precision: 0.9019 - recall: 0.8989 - val_loss: 0.5088 - val_categorical_accuracy: 0.8595 - val_auc: 0.9664 - val_precision: 0.8613 - val_recall: 0.8569
# Epoch 157/500
# 12321/12321 [==============================] - 6s 500us/sample - loss: 0.3025 - categorical_accuracy: 0.8893 - auc: 0.9836 - precision: 0.8930 - recall: 0.8865 - val_loss: 0.5017 - val_categorical_accuracy: 0.8612 - val_auc: 0.9699 - val_precision: 0.8643 - val_recall: 0.8588
# Epoch 158/500
# 12321/12321 [==============================] - 6s 496us/sample - loss: 0.2958 - categorical_accuracy: 0.9020 - auc: 0.9836 - precision: 0.9048 - recall: 0.8990 - val_loss: 0.4420 - val_categorical_accuracy: 0.8632 - val_auc: 0.9724 - val_precision: 0.8673 - val_recall: 0.8620
# Epoch 159/500
# 12321/12321 [==============================] - 6s 497us/sample - loss: 0.2759 - categorical_accuracy: 0.9056 - auc: 0.9850 - precision: 0.9081 - recall: 0.9039 - val_loss: 0.6906 - val_categorical_accuracy: 0.8128 - val_auc: 0.9512 - val_precision: 0.8162 - val_recall: 0.8106
# Epoch 160/500
# 12321/12321 [==============================] - 6s 499us/sample - loss: 0.3680 - categorical_accuracy: 0.8767 - auc: 0.9777 - precision: 0.8777 - recall: 0.8747 - val_loss: 0.5945 - val_categorical_accuracy: 0.8264 - val_auc: 0.9625 - val_precision: 0.8300 - val_recall: 0.8235
# Epoch 161/500
# 12321/12321 [==============================] - 6s 500us/sample - loss: 0.3294 - categorical_accuracy: 0.8904 - auc: 0.9807 - precision: 0.8922 - recall: 0.8885 - val_loss: 0.5115 - val_categorical_accuracy: 0.8547 - val_auc: 0.9666 - val_precision: 0.8571 - val_recall: 0.8527
# Epoch 162/500
# 12321/12321 [==============================] - 6s 500us/sample - loss: 0.3733 - categorical_accuracy: 0.8783 - auc: 0.9772 - precision: 0.8802 - recall: 0.8762 - val_loss: 0.5619 - val_categorical_accuracy: 0.8420 - val_auc: 0.9647 - val_precision: 0.8441 - val_recall: 0.8396
# Epoch 163/500
# 12321/12321 [==============================] - 6s 506us/sample - loss: 0.3146 - categorical_accuracy: 0.8981 - auc: 0.9823 - precision: 0.9005 - recall: 0.8962 - val_loss: 0.4664 - val_categorical_accuracy: 0.8634 - val_auc: 0.9690 - val_precision: 0.8652 - val_recall: 0.8610
# Epoch 164/500
# 12321/12321 [==============================] - 6s 498us/sample - loss: 0.2973 - categorical_accuracy: 0.8968 - auc: 0.9836 - precision: 0.8998 - recall: 0.8958 - val_loss: 0.5960 - val_categorical_accuracy: 0.8318 - val_auc: 0.9602 - val_precision: 0.8373 - val_recall: 0.8296
# Epoch 165/500
# 12321/12321 [==============================] - 6s 495us/sample - loss: 0.3287 - categorical_accuracy: 0.8861 - auc: 0.9806 - precision: 0.8885 - recall: 0.8839 - val_loss: 0.4473 - val_categorical_accuracy: 0.8790 - val_auc: 0.9727 - val_precision: 0.8819 - val_recall: 0.8766
# Epoch 166/500
# ...
# 12321/12321 [==============================] - 6s 495us/sample - loss: 0.2045 - categorical_accuracy: 0.9324 - auc: 0.9909 - precision: 0.9338 - recall: 0.9305 - val_loss: 0.4741 - val_categorical_accuracy: 0.8780 - val_auc: 0.9714 - val_precision: 0.8799 - val_recall: 0.8773
# Epoch 447/500
# 12321/12321 [==============================] - 6s 491us/sample - loss: 0.2517 - categorical_accuracy: 0.9134 - auc: 0.9878 - precision: 0.9157 - recall: 0.9121 - val_loss: 0.4253 - val_categorical_accuracy: 0.8861 - val_auc: 0.9747 - val_precision: 0.8884 - val_recall: 0.8853
# Epoch 448/500
# 12321/12321 [==============================] - 6s 490us/sample - loss: 0.2034 - categorical_accuracy: 0.9312 - auc: 0.9906 - precision: 0.9329 - recall: 0.9305 - val_loss: 0.3862 - val_categorical_accuracy: 0.9065 - val_auc: 0.9777 - val_precision: 0.9086 - val_recall: 0.9053
# Epoch 449/500
# 12321/12321 [==============================] - 6s 491us/sample - loss: 0.2485 - categorical_accuracy: 0.9184 - auc: 0.9874 - precision: 0.9196 - recall: 0.9173 - val_loss: 0.4565 - val_categorical_accuracy: 0.8746 - val_auc: 0.9734 - val_precision: 0.8766 - val_recall: 0.8737
# Epoch 450/500
# 12321/12321 [==============================] - 6s 493us/sample - loss: 0.2066 - categorical_accuracy: 0.9291 - auc: 0.9908 - precision: 0.9305 - recall: 0.9277 - val_loss: 0.4119 - val_categorical_accuracy: 0.9038 - val_auc: 0.9754 - val_precision: 0.9050 - val_recall: 0.9019
# Epoch 451/500
# 12321/12321 [==============================] - 6s 500us/sample - loss: 0.1996 - categorical_accuracy: 0.9343 - auc: 0.9912 - precision: 0.9357 - recall: 0.9335 - val_loss: 0.3985 - val_categorical_accuracy: 0.8912 - val_auc: 0.9780 - val_precision: 0.8921 - val_recall: 0.8880
# Epoch 452/500
# 12321/12321 [==============================] - 6s 486us/sample - loss: 0.1861 - categorical_accuracy: 0.9338 - auc: 0.9924 - precision: 0.9356 - recall: 0.9321 - val_loss: 0.4313 - val_categorical_accuracy: 0.8912 - val_auc: 0.9746 - val_precision: 0.8932 - val_recall: 0.8900
# Epoch 453/500
# 12321/12321 [==============================] - 6s 488us/sample - loss: 0.1960 - categorical_accuracy: 0.9292 - auc: 0.9913 - precision: 0.9304 - recall: 0.9279 - val_loss: 0.3874 - val_categorical_accuracy: 0.8939 - val_auc: 0.9789 - val_precision: 0.8964 - val_recall: 0.8929
# Epoch 454/500
# 12321/12321 [==============================] - 6s 487us/sample - loss: 0.2219 - categorical_accuracy: 0.9222 - auc: 0.9898 - precision: 0.9243 - recall: 0.9206 - val_loss: 0.5863 - val_categorical_accuracy: 0.8620 - val_auc: 0.9644 - val_precision: 0.8632 - val_recall: 0.8600
# Epoch 455/500
# 12321/12321 [==============================] - 6s 491us/sample - loss: 0.2766 - categorical_accuracy: 0.9099 - auc: 0.9862 - precision: 0.9108 - recall: 0.9088 - val_loss: 0.4312 - val_categorical_accuracy: 0.8951 - val_auc: 0.9752 - val_precision: 0.8972 - val_recall: 0.8941
# Epoch 456/500
# 12321/12321 [==============================] - 6s 490us/sample - loss: 0.2063 - categorical_accuracy: 0.9338 - auc: 0.9902 - precision: 0.9358 - recall: 0.9325 - val_loss: 0.4194 - val_categorical_accuracy: 0.8997 - val_auc: 0.9765 - val_precision: 0.9005 - val_recall: 0.8970
# Epoch 457/500
# 12321/12321 [==============================] - 6s 488us/sample - loss: 0.2478 - categorical_accuracy: 0.9148 - auc: 0.9878 - precision: 0.9163 - recall: 0.9140 - val_loss: 0.4468 - val_categorical_accuracy: 0.8875 - val_auc: 0.9752 - val_precision: 0.8914 - val_recall: 0.8856
# Epoch 458/500
# 12321/12321 [==============================] - 6s 492us/sample - loss: 0.2328 - categorical_accuracy: 0.9213 - auc: 0.9889 - precision: 0.9226 - recall: 0.9198 - val_loss: 0.4093 - val_categorical_accuracy: 0.9046 - val_auc: 0.9756 - val_precision: 0.9073 - val_recall: 0.9029
# Epoch 459/500
# 12321/12321 [==============================] - 6s 499us/sample - loss: 0.2200 - categorical_accuracy: 0.9287 - auc: 0.9894 - precision: 0.9302 - recall: 0.9271 - val_loss: 0.4924 - val_categorical_accuracy: 0.8681 - val_auc: 0.9710 - val_precision: 0.8708 - val_recall: 0.8647
# Epoch 460/500
# 12321/12321 [==============================] - 6s 502us/sample - loss: 0.2277 - categorical_accuracy: 0.9240 - auc: 0.9888 - precision: 0.9255 - recall: 0.9226 - val_loss: 0.4405 - val_categorical_accuracy: 0.8863 - val_auc: 0.9755 - val_precision: 0.8912 - val_recall: 0.8851
# Epoch 461/500
# 12321/12321 [==============================] - 6s 498us/sample - loss: 0.2663 - categorical_accuracy: 0.9089 - auc: 0.9867 - precision: 0.9106 - recall: 0.9076 - val_loss: 0.4796 - val_categorical_accuracy: 0.8707 - val_auc: 0.9716 - val_precision: 0.8741 - val_recall: 0.8668
# Epoch 462/500
# 12321/12321 [==============================] - 6s 490us/sample - loss: 0.2054 - categorical_accuracy: 0.9291 - auc: 0.9908 - precision: 0.9306 - recall: 0.9282 - val_loss: 0.4268 - val_categorical_accuracy: 0.8922 - val_auc: 0.9744 - val_precision: 0.8957 - val_recall: 0.8909
# Epoch 463/500
# 12321/12321 [==============================] - 6s 494us/sample - loss: 0.2303 - categorical_accuracy: 0.9160 - auc: 0.9901 - precision: 0.9187 - recall: 0.9142 - val_loss: 0.5879 - val_categorical_accuracy: 0.8591 - val_auc: 0.9629 - val_precision: 0.8622 - val_recall: 0.8574
# Epoch 464/500
# 12321/12321 [==============================] - 6s 490us/sample - loss: 0.2702 - categorical_accuracy: 0.9097 - auc: 0.9858 - precision: 0.9118 - recall: 0.9078 - val_loss: 0.4553 - val_categorical_accuracy: 0.8827 - val_auc: 0.9738 - val_precision: 0.8854 - val_recall: 0.8805
# Epoch 465/500
# 12321/12321 [==============================] - 6s 491us/sample - loss: 0.1874 - categorical_accuracy: 0.9354 - auc: 0.9921 - precision: 0.9372 - recall: 0.9343 - val_loss: 0.3922 - val_categorical_accuracy: 0.9107 - val_auc: 0.9778 - val_precision: 0.9132 - val_recall: 0.9090
# Epoch 466/500
# 12321/12321 [==============================] - 6s 497us/sample - loss: 0.1986 - categorical_accuracy: 0.9313 - auc: 0.9911 - precision: 0.9331 - recall: 0.9302 - val_loss: 0.4247 - val_categorical_accuracy: 0.8975 - val_auc: 0.9747 - val_precision: 0.9008 - val_recall: 0.8948
# Epoch 467/500
# 12321/12321 [==============================] - 6s 491us/sample - loss: 0.1820 - categorical_accuracy: 0.9374 - auc: 0.9923 - precision: 0.9386 - recall: 0.9358 - val_loss: 0.4425 - val_categorical_accuracy: 0.8856 - val_auc: 0.9728 - val_precision: 0.8880 - val_recall: 0.8836
# Epoch 468/500
# 12321/12321 [==============================] - 6s 493us/sample - loss: 0.2164 - categorical_accuracy: 0.9274 - auc: 0.9903 - precision: 0.9289 - recall: 0.9252 - val_loss: 0.4773 - val_categorical_accuracy: 0.8690 - val_auc: 0.9711 - val_precision: 0.8710 - val_recall: 0.8681
# Epoch 469/500
# 12321/12321 [==============================] - 6s 503us/sample - loss: 0.2321 - categorical_accuracy: 0.9228 - auc: 0.9885 - precision: 0.9239 - recall: 0.9215 - val_loss: 0.4597 - val_categorical_accuracy: 0.8866 - val_auc: 0.9708 - val_precision: 0.8900 - val_recall: 0.8841
# Epoch 470/500
# 12321/12321 [==============================] - 6s 511us/sample - loss: 0.2462 - categorical_accuracy: 0.9192 - auc: 0.9876 - precision: 0.9206 - recall: 0.9179 - val_loss: 0.4159 - val_categorical_accuracy: 0.8805 - val_auc: 0.9754 - val_precision: 0.8829 - val_recall: 0.8790
# Epoch 471/500
# 12321/12321 [==============================] - 6s 494us/sample - loss: 0.2399 - categorical_accuracy: 0.9154 - auc: 0.9886 - precision: 0.9188 - recall: 0.9133 - val_loss: 0.5136 - val_categorical_accuracy: 0.8698 - val_auc: 0.9685 - val_precision: 0.8721 - val_recall: 0.8683
# Epoch 472/500
# 12321/12321 [==============================] - 6s 491us/sample - loss: 0.2621 - categorical_accuracy: 0.9133 - auc: 0.9866 - precision: 0.9148 - recall: 0.9119 - val_loss: 0.4162 - val_categorical_accuracy: 0.8934 - val_auc: 0.9744 - val_precision: 0.8958 - val_recall: 0.8917
# Epoch 473/500
# 12321/12321 [==============================] - 6s 490us/sample - loss: 0.1833 - categorical_accuracy: 0.9397 - auc: 0.9921 - precision: 0.9410 - recall: 0.9384 - val_loss: 0.4185 - val_categorical_accuracy: 0.8978 - val_auc: 0.9763 - val_precision: 0.8999 - val_recall: 0.8953
# Epoch 474/500
# 12321/12321 [==============================] - 6s 490us/sample - loss: 0.1994 - categorical_accuracy: 0.9302 - auc: 0.9914 - precision: 0.9317 - recall: 0.9287 - val_loss: 0.4512 - val_categorical_accuracy: 0.8768 - val_auc: 0.9737 - val_precision: 0.8784 - val_recall: 0.8754
# Epoch 475/500
# 12321/12321 [==============================] - 6s 487us/sample - loss: 0.2032 - categorical_accuracy: 0.9277 - auc: 0.9911 - precision: 0.9297 - recall: 0.9270 - val_loss: 0.4446 - val_categorical_accuracy: 0.8905 - val_auc: 0.9726 - val_precision: 0.8922 - val_recall: 0.8888
# Epoch 476/500
# 12321/12321 [==============================] - 6s 493us/sample - loss: 0.2010 - categorical_accuracy: 0.9314 - auc: 0.9913 - precision: 0.9325 - recall: 0.9301 - val_loss: 0.5111 - val_categorical_accuracy: 0.8654 - val_auc: 0.9659 - val_precision: 0.8679 - val_recall: 0.8620
# Epoch 477/500
# 12321/12321 [==============================] - 6s 493us/sample - loss: 0.2203 - categorical_accuracy: 0.9225 - auc: 0.9899 - precision: 0.9239 - recall: 0.9209 - val_loss: 0.4387 - val_categorical_accuracy: 0.8895 - val_auc: 0.9722 - val_precision: 0.8907 - val_recall: 0.8883
# Epoch 478/500
# 12321/12321 [==============================] - 6s 493us/sample - loss: 0.2211 - categorical_accuracy: 0.9283 - auc: 0.9894 - precision: 0.9302 - recall: 0.9269 - val_loss: 0.4188 - val_categorical_accuracy: 0.8990 - val_auc: 0.9747 - val_precision: 0.9010 - val_recall: 0.8975
# Epoch 479/500
# 12321/12321 [==============================] - 6s 491us/sample - loss: 0.1743 - categorical_accuracy: 0.9378 - auc: 0.9932 - precision: 0.9392 - recall: 0.9364 - val_loss: 0.4242 - val_categorical_accuracy: 0.8948 - val_auc: 0.9731 - val_precision: 0.8990 - val_recall: 0.8924
# Epoch 480/500
# 12321/12321 [==============================] - 6s 510us/sample - loss: 0.2094 - categorical_accuracy: 0.9287 - auc: 0.9902 - precision: 0.9315 - recall: 0.9265 - val_loss: 0.4196 - val_categorical_accuracy: 0.9024 - val_auc: 0.9746 - val_precision: 0.9053 - val_recall: 0.9024
# Epoch 481/500
# 12321/12321 [==============================] - 6s 493us/sample - loss: 0.1952 - categorical_accuracy: 0.9326 - auc: 0.9911 - precision: 0.9339 - recall: 0.9316 - val_loss: 0.4607 - val_categorical_accuracy: 0.8861 - val_auc: 0.9713 - val_precision: 0.8897 - val_recall: 0.8815
# Epoch 482/500
# 12321/12321 [==============================] - 6s 491us/sample - loss: 0.2103 - categorical_accuracy: 0.9284 - auc: 0.9901 - precision: 0.9306 - recall: 0.9272 - val_loss: 0.4330 - val_categorical_accuracy: 0.8951 - val_auc: 0.9741 - val_precision: 0.8969 - val_recall: 0.8939
# Epoch 483/500
# 12321/12321 [==============================] - 6s 492us/sample - loss: 0.1899 - categorical_accuracy: 0.9339 - auc: 0.9917 - precision: 0.9353 - recall: 0.9330 - val_loss: 0.5712 - val_categorical_accuracy: 0.8542 - val_auc: 0.9672 - val_precision: 0.8560 - val_recall: 0.8520
# Epoch 484/500
# 12321/12321 [==============================] - 6s 490us/sample - loss: 0.2185 - categorical_accuracy: 0.9291 - auc: 0.9889 - precision: 0.9305 - recall: 0.9283 - val_loss: 0.4704 - val_categorical_accuracy: 0.8797 - val_auc: 0.9733 - val_precision: 0.8844 - val_recall: 0.8790
# Epoch 485/500
# 12321/12321 [==============================] - 6s 494us/sample - loss: 0.2610 - categorical_accuracy: 0.9147 - auc: 0.9863 - precision: 0.9154 - recall: 0.9133 - val_loss: 0.4335 - val_categorical_accuracy: 0.8873 - val_auc: 0.9747 - val_precision: 0.8891 - val_recall: 0.8856
# Epoch 486/500
# 12321/12321 [==============================] - 6s 494us/sample - loss: 0.1922 - categorical_accuracy: 0.9313 - auc: 0.9918 - precision: 0.9326 - recall: 0.9303 - val_loss: 0.4456 - val_categorical_accuracy: 0.8951 - val_auc: 0.9737 - val_precision: 0.8985 - val_recall: 0.8944
# Epoch 487/500
# 12321/12321 [==============================] - 6s 491us/sample - loss: 0.2006 - categorical_accuracy: 0.9287 - auc: 0.9914 - precision: 0.9302 - recall: 0.9280 - val_loss: 0.4695 - val_categorical_accuracy: 0.8888 - val_auc: 0.9732 - val_precision: 0.8900 - val_recall: 0.8863
# Epoch 488/500
# 12321/12321 [==============================] - 6s 492us/sample - loss: 0.1942 - categorical_accuracy: 0.9360 - auc: 0.9909 - precision: 0.9375 - recall: 0.9357 - val_loss: 0.3949 - val_categorical_accuracy: 0.9099 - val_auc: 0.9757 - val_precision: 0.9114 - val_recall: 0.9092
# Epoch 489/500
# 12321/12321 [==============================] - 6s 491us/sample - loss: 0.1926 - categorical_accuracy: 0.9317 - auc: 0.9918 - precision: 0.9329 - recall: 0.9305 - val_loss: 0.4226 - val_categorical_accuracy: 0.8961 - val_auc: 0.9752 - val_precision: 0.8970 - val_recall: 0.8948
# Epoch 490/500
# 12321/12321 [==============================] - 6s 516us/sample - loss: 0.1805 - categorical_accuracy: 0.9367 - auc: 0.9921 - precision: 0.9378 - recall: 0.9356 - val_loss: 0.4003 - val_categorical_accuracy: 0.9000 - val_auc: 0.9750 - val_precision: 0.9048 - val_recall: 0.8980
# Epoch 491/500
# 12321/12321 [==============================] - 6s 496us/sample - loss: 0.1991 - categorical_accuracy: 0.9308 - auc: 0.9913 - precision: 0.9326 - recall: 0.9297 - val_loss: 0.4770 - val_categorical_accuracy: 0.8844 - val_auc: 0.9724 - val_precision: 0.8860 - val_recall: 0.8817
# Epoch 492/500
# 12321/12321 [==============================] - 6s 491us/sample - loss: 0.1883 - categorical_accuracy: 0.9367 - auc: 0.9916 - precision: 0.9385 - recall: 0.9359 - val_loss: 0.4140 - val_categorical_accuracy: 0.9036 - val_auc: 0.9740 - val_precision: 0.9049 - val_recall: 0.9034
# Epoch 493/500
# 12321/12321 [==============================] - 6s 492us/sample - loss: 0.1992 - categorical_accuracy: 0.9330 - auc: 0.9908 - precision: 0.9346 - recall: 0.9315 - val_loss: 0.5574 - val_categorical_accuracy: 0.8561 - val_auc: 0.9648 - val_precision: 0.8583 - val_recall: 0.8549
# Epoch 494/500
# 12321/12321 [==============================] - 6s 490us/sample - loss: 0.1977 - categorical_accuracy: 0.9326 - auc: 0.9913 - precision: 0.9342 - recall: 0.9323 - val_loss: 0.4332 - val_categorical_accuracy: 0.8961 - val_auc: 0.9737 - val_precision: 0.8978 - val_recall: 0.8944
# Epoch 495/500
# 12321/12321 [==============================] - 6s 494us/sample - loss: 0.2312 - categorical_accuracy: 0.9257 - auc: 0.9887 - precision: 0.9270 - recall: 0.9243 - val_loss: 0.4266 - val_categorical_accuracy: 0.9017 - val_auc: 0.9756 - val_precision: 0.9032 - val_recall: 0.9014
# Epoch 496/500
# 12321/12321 [==============================] - 6s 491us/sample - loss: 0.1746 - categorical_accuracy: 0.9399 - auc: 0.9925 - precision: 0.9414 - recall: 0.9390 - val_loss: 0.4521 - val_categorical_accuracy: 0.8849 - val_auc: 0.9734 - val_precision: 0.8865 - val_recall: 0.8841
# Epoch 497/500
# 12321/12321 [==============================] - 6s 487us/sample - loss: 0.1849 - categorical_accuracy: 0.9387 - auc: 0.9920 - precision: 0.9405 - recall: 0.9370 - val_loss: 0.4254 - val_categorical_accuracy: 0.9026 - val_auc: 0.9761 - val_precision: 0.9050 - val_recall: 0.9019
# Epoch 498/500
# 12321/12321 [==============================] - 6s 491us/sample - loss: 0.1859 - categorical_accuracy: 0.9350 - auc: 0.9927 - precision: 0.9369 - recall: 0.9335 - val_loss: 0.4774 - val_categorical_accuracy: 0.8873 - val_auc: 0.9730 - val_precision: 0.8890 - val_recall: 0.8870
# Epoch 499/500
# 12321/12321 [==============================] - 6s 489us/sample - loss: 0.1920 - categorical_accuracy: 0.9369 - auc: 0.9911 - precision: 0.9384 - recall: 0.9360 - val_loss: 0.4709 - val_categorical_accuracy: 0.8851 - val_auc: 0.9721 - val_precision: 0.8878 - val_recall: 0.8844
# Epoch 500/500
# 12321/12321 [==============================] - 6s 512us/sample - loss: 0.2086 - categorical_accuracy: 0.9271 - auc: 0.9906 - precision: 0.9287 - recall: 0.9257 - val_loss: 0.4912 - val_categorical_accuracy: 0.8832 - val_auc: 0.9696 - val_precision: 0.8857 - val_recall: 0.8807

# %% [markdown]
# ### $\textbf{Metrics vs. Training Epoch}$

# %%
# %matplotlib notebook

# Text legend labels for training set curves
train_set_lbl = ('Training Set (' + 
    str(int(100 * (1 - pct_validation))) + '%)');
    
# Text legend labels for validation set curves
val_set_lbl = ('Training Set (' + 
    str(int(100 * (1 - pct_validation))) + '%)');

# New figure
loss_fig = plt.figure(figsize=(9.9,12));

#############
# Loss plot #
#############
ax1 = plt.subplot(5,1,1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Linear grid of training epochs
epochs = arange(0,N_epoch);

# Cross-entropy error (dB) - training set
plt.plot(epochs,10 * log10(
    model.history.history['loss']),
    '.-',c='g',alpha=0.5,
    label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,10 * log10(
    model.history.history['val_loss']),
    '.-',c='k',alpha=0.5,
    label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Cross-Entropy Error vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Error${}_{\varepsilon}$ (dB)',fontsize=14);

# Legend
plt.legend();

#################
# Accuracy plot #
#################
plt.subplot(5,1,2,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['categorical_accuracy'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_categorical_accuracy'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Categorical Accuracy vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Accuracy${}_{\varepsilon}$ ($\times100\%$)',fontsize=14);

# Legend
plt.legend();

##################
# Precision plot #
##################
plt.subplot(5,1,3,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['precision'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_precision'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]); 

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Precision${}_{\varepsilon}$',fontsize=14);

# Legend
plt.legend();

###############
# Recall plot #
###############
plt.subplot(5,1,4,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['recall'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_recall'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Recall vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'Recall${}_{\varepsilon}$',fontsize=14);

# Legend
plt.legend();

############
# AUC plot #
############
plt.subplot(5,1,5,sharex=ax1);

# Add grid to axes
plt.grid(color='k',alpha=0.25);

# Cross-entropy error (dB) - training set
plt.plot(epochs,model.history.history['auc'],
    '.-',c='g',alpha=0.5,label=train_set_lbl);

# Cross-entropy error (dB) - validation set
plt.plot(epochs,model.history.history['val_auc'],
    '.-',c='k',alpha=0.5,label=val_set_lbl);

# Set x-axis limits
plt.xlim([epochs[0],epochs[-1]]);

# Title
plt.title(r'Area Under ROC Curve vs. Training Epoch $\varepsilon$',
          fontsize=16,weight='bold');

# x-axis label
plt.xlabel(r'Epoch $\varepsilon$',fontsize=14);

# y-axis label
plt.ylabel(r'AUC${}_{\varepsilon}$',fontsize=14);

# Legend
plt.legend();

# Optimize layout
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="989.9">

# %% [markdown]
# ### $\textbf{Pass Entire Dataset (i.e., Train }\cup\textbf{ Validation) to Model}$

# %%
# C x 1 class prediction for entire dataset
Y_hat = model.predict(
    X,                        # Input data
    batch_size=N_batch,       # Batch size
);

# Cast 1-hot class labels as ordinal labels
y_hat = argmax(Y_hat,axis=1); # Predictions
y_true = argmax(Y,axis=1);    # Ground truth

# %% [markdown]
# ### $\textbf{Confusion Matrix Using Predictions Output Above}$

# %%
#########################
#    Compute Matrix:    #
#########################

# Use the sklearn confusion matrix function
confusion_mat = confusion_matrix(y_true,y_hat,
    labels=[c for c in range(C)],sample_weight=None);

#########################
#   Confusion Plotter:  # - adapated from online example
#########################

def plot_confusion_matrix(C,classes,normalize=False,
            title='Confusion matrix',cmap=plt.cm.Greens):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    
    # Let epsilon > 0 be small...
    epsilon = 1e-7;
    
    # Normalization of confusion matrix C
    if normalize:
        C = C.astype('float') / (epsilon + C.sum(axis=1)[:, newaxis]);

    # Print the matrix C
    print(C);
    
    # Image representation
    ax = plt.gca();   # <-- grab current axes
    C = flipud(C);    # <-- flip horizontally for visualization
    im = ax.imshow(C,cmap=cmap);
    
    # Colorbar
    colorbar(im);
    
    # Title
    plt.title(title,fontsize=20,weight="bold");
    
    # Tick labels
    tick_marks = arange(len(classes));
    plt.xticks(tick_marks, classes, rotation=45,fontweight="bold");
    
    # Overwrite default y-axis limits
    plt.ylim([-0.5,len(classes)-0.5]);

    # Text labels in tiles (i.e., elements)
    fmt = '.2f' if normalize else 'd'
    thresh = C.max() / 2.
    for i, j in iter_prod(range(C.shape[0]), range(C.shape[1])):
        plt.text(j, i, format(C[i, j], fmt),
                 horizontalalignment="center",weight="bold",
                 color="white" if C[i, j] > thresh else "black")

    # x-axis labels
    plt.ylabel('True label',fontsize=16,weight="bold");
    
    # y-axis labels
    plt.xlabel('Predicted label',fontsize=16,weight="bold");
    
    # Set axis layout
    plt.tight_layout();
    
#########################
#    Scale Colorbar:    # - found this online
#########################

def colorbar(mappable):
    last_axes = plt.gca()
    ax = mappable.axes
    fig = ax.figure
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    cbar = fig.colorbar(mappable, cax=cax)
    plt.sca(last_axes)
    return cbar

#########################
#    Visualization:     #
#########################

conf_fig = plt.figure(figsize=(9.9,9.9));
plot_confusion_matrix(
    confusion_mat, 
    classes=[clss for clss in class_table],
    normalize=True,
    title='Confusion Matrix',
    cmap=plt.cm.Greens);
# Out:
# <img src="data:image/png;base64,..." width="989.9">
# [[0.97950111 0.00716226 0.01061991 0.00271672]
#  [0.02706767 0.95969925 0.00781955 0.00541353]
#  [0.00690506 0.00591862 0.86510481 0.12207152]
#  [0.015      0.0072     0.0714     0.9064    ]]
